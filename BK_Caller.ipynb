# %%
from bk import bk
import pandas as pd
import dataframe_image as dfi
from slugify import slugify
from pathlib import Path

overview = pd.DataFrame()
overview.name='Monatliche Kosten im Verlgeich'

def df_style(val):
    return "font-weight: bold; background-color: yellow"

# %%
# Aktueller Dieselpreis 3.1.2022: 1.52
# Aktueller Benzinpreis 3.1.2022: 1.56
# Aktueller Strompreis 3.1.2022: 0.31 €/kWh

d_6 = 1.65  # Durschnittlicher Dieselpreis geschätzt bis 2028
b_4 = 1.70  # Durschnittlicher Benzinpreis geschätzt bis 2026
b_6 = 1.80  # Durschnittlicher Benzinpreis geschätzt bis 2028
b_10 = 2.0  # Durschnittlicher Benzinpreis geschätzt bis 2032
e_10 = 0.30 # Durschnittlicher Strompreis geschätzt bis 2032

cars = [{'label': 'BMW 318d 2011',
         'acquisition_cost': 16903,
         'car_year': 2011,
         'delivery_time': 0,
         'interest_rate': 0.,
         'rest_value': 1500,
         'insurance_yearly': 775,
         'taxes_yearly': 230,
         'consumption': 6.38,
         'fuel_price': 1.19,  # Durchschnittlicher Dieselpreis seit 2015
         'fuel_type': 'Diesel',
         'repairs_yearly': 2016.32,
         'millage_yearly': 26000,
         'holding_period': 6.85,
         'image_url': 'cars/bmw-3er-maximus.png',
         'web_url': 'https://de.wikipedia.org/wiki/BMW_E90'
        }]
cars.append({'label': 'Nissan Micra 2010',
             'acquisition_cost': 3300,
             'car_year': 2011,
             'delivery_time': 0,
             'interest_rate': 0.,
             'rest_value': 200,
             'insurance_yearly': 361.76,
             'taxes_yearly': 64,
             'consumption': 6.6,
             'fuel_price': 1.36,  # Durchschnittlicher Dieselpreis seit 2016
             'fuel_type': 'Benzin',
             'repairs_yearly': 395.40,
             'millage_yearly': 3216,
             'holding_period': 5.5,  
             'image_url': 'cars/nissan-micra.jpg',
             'web_url': 'https://de.wikipedia.org/wiki/Nissan_Micra#Micra_(K12,_2003%E2%80%932010)'
})
cars.append({'label': 'Mercedes C 220d',
             'acquisition_cost': 28890,
             'car_year': 2019,
             'delivery_time': 0,
             'interest_rate': 3.,
             'rest_value': 5000,
             'insurance_yearly': 775,
             'taxes_yearly': 230,
             'consumption': 6.,
             'fuel_price': d_6,
             'fuel_type': 'Diesel',
             'repairs_yearly': 1800,
             'millage_yearly': 18000,
             'holding_period': 6.0,  
             'image_url': 'cars/mercedes-c-220d-t.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?action=parkItem&id=336723447'
})
cars.append({'label': 'Mercedes C 200',
             'acquisition_cost': 29970,
             'car_year': 2019,
             'delivery_time': 0,
             'interest_rate': 3.,
             'rest_value': 7000,
             'insurance_yearly': 545.79,
             'taxes_yearly': 136,
             'consumption': 8.,
             'fuel_price': b_6,
             'fuel_type': 'Benzin',
             'repairs_yearly': 900,
             'millage_yearly': 18000,
             'holding_period': 6.0,  
             'image_url': 'cars/mercedes-c-200-t.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?action=parkItem&id=327113608'
})
cars.append({'label': 'Mercedes C 180',
             'acquisition_cost': 42755.83,
             'car_year': 2022,
             'delivery_time': 60,
             'interest_rate': 3.,
             'rest_value': 7000,
             'insurance_yearly': 678.24,
             'taxes_yearly': 136,
             'consumption': 7.,
             'fuel_price': b_10,
             'fuel_type': 'Benzin',
             'repairs_yearly': 900,
             'millage_yearly': 18000,
             'holding_period': 10.0,  
             'image_url': 'cars/mercedes-c-180-t.png',
             'web_url': 'https://konfigurator.meinauto.de/mercedes/neuwagen/c-klasse/angebote/c-klasse-t-modell/konfigurator/#!/preisvergleich/-/8866563/2,47,74,81/private/43735-7309-290394/349/61d36ce4c3067/cash-purchase/73169--190162/48,0,10000,0,0,0,0,0,'
})             
cars.append({'label': 'Tesla Model Y',
             'acquisition_cost': 51000,
             'car_year': 2022,
             'delivery_time': 8,
             'interest_rate': 3.,
             'rest_value': 5000,
             'insurance_yearly': 541.02,
             'taxes_yearly': 0,
             'consumption': 16.,
             'fuel_price': e_10,
             'fuel_type': 'Strom',
             'repairs_yearly': 500,
             'millage_yearly': 18000,
             'holding_period': 10.0,   
             'image_url': 'cars/tesla-model-y.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview'
})
cars.append({'label': 'Mazda 6 geb.',
             'acquisition_cost': 22980,
             'car_year': 2017,
             'delivery_time': 0,
             'interest_rate': 3.,
             'rest_value': 4000,
             'insurance_yearly': 691.51,
             'taxes_yearly': 136,
             'consumption': 8.,
             'fuel_price': b_4,
             'fuel_type': 'Benzin',
             'repairs_yearly': 900,
             'millage_yearly': 18000,
             'holding_period': 4.0,  
             'image_url': 'cars/mazda-6-alt.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?action=parkItem&id=332186075'
})
cars.append({'label': 'Mazda 6 neu',
             'acquisition_cost': 29692,
             'car_year': 2022,
             'delivery_time': 60,
             'interest_rate': 3.,
             'rest_value': 3000,
             'insurance_yearly': 601.16,
             'taxes_yearly': 136,
             'consumption': 8.,
             'fuel_price': b_10,
             'fuel_type': 'Benzin',
             'repairs_yearly': 900,
             'millage_yearly': 18000,
             'holding_period': 10.0,  
             'image_url': 'cars/mazda-6-neu.png',
             'web_url': 'https://konfigurator.meinauto.de/mazda/neuwagen/48-6/angebote/6-kombi/konfigurator/#!/extras/exclusive-line/8846370/10,11/private/65352-5416-204698/984/61c9aa657e74c/cash-purchase/32545--287374/48,0,10000,0,0,0,0,0,'
})
cars.append({'label': 'Kia ceed',
             'acquisition_cost': 26992.36,
             'car_year': 2022,
             'delivery_time': 52,
             'interest_rate': 3.,
             'rest_value': 3000,
             'insurance_yearly': 381.08,
             'taxes_yearly': 136,
             'consumption': 7.,
             'fuel_price': b_10,
             'fuel_type': 'Benzin',
             'repairs_yearly': 900,
             'millage_yearly': 18000,
             'holding_period': 10.0,
             'image_url': 'cars/kia-ceed-sportswagon.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/preisvergleich/platinum/8867329/3,7,18/private/109347-4167-291321/1321/61d21ce73c5db/cash-purchase/109348-8088-291322/48,0,10000,0,0,0,0,0,'
})
cars.append({'label': 'Skoda Superb',
             'acquisition_cost': 26890,
             'car_year': 2019,
             'delivery_time': 0,
             'interest_rate': 3.,
             'rest_value': 8000,
             'insurance_yearly': 601.26,
             'taxes_yearly': 230,
             'consumption': 6.5,
             'fuel_price': d_6,
             'fuel_type': 'Diesel',
             'repairs_yearly': 1200,
             'millage_yearly': 18000,
             'holding_period': 6.0,
             'image_url': 'cars/skoda-superb.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?id=336967099'
})
cars.append({'label': 'Skoda Octavia',
             'acquisition_cost': 16250,
             'car_year': 2019,
             'delivery_time': 0,
             'interest_rate': 3.,
             'rest_value': 4000,
             'insurance_yearly': 458.92,
             'taxes_yearly': 230,
             'consumption': 6.0,
             'fuel_price': d_6,
             'fuel_type': 'Diesel',
             'repairs_yearly': 1200,
             'millage_yearly': 18000,
             'holding_period': 6.0,
             'image_url': 'cars/skoda-octavia.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?id=333524150'
})
cars.append({'label': 'BMW Gran Tourer',
             'acquisition_cost': 28990,
             'car_year': 2019,
             'delivery_time': 0,
             'interest_rate': 3.,
             'rest_value': 7000,
             'insurance_yearly': 586.82,
             'taxes_yearly': 130,
             'consumption': 8.21,
             'fuel_price': b_6,
             'fuel_type': 'Benzin',
             'repairs_yearly': 900,
             'millage_yearly': 18000,
             'holding_period': 6.0,
             'image_url': 'cars/bmw-gran-tourer.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?id=336851737'
})
cars.append({'label': 'Skoda Kodiaq 2.0 TSI',
             'acquisition_cost': 29950,
             'car_year': 2019,
             'delivery_time': 0,
             'interest_rate': 3.,
             'rest_value': 7000,
             'insurance_yearly': 479.25,
             'taxes_yearly': 130,
             'consumption': 9.24,
             'fuel_price': b_6,
             'fuel_type': 'Benzin',
             'repairs_yearly': 900,
             'millage_yearly': 18000,
             'holding_period': 6.0,
             'image_url': 'cars/skoda-kodiaq-2p0-tsi.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?id=336695573'
})
cars.append({'label': 'Skoda Kodiaq 2.0 TDI',
             'acquisition_cost': 34890,
             'car_year': 2019,
             'delivery_time': 0,
             'interest_rate': 3.,
             'rest_value': 7000,
             'insurance_yearly': 486.05,
             'taxes_yearly': 230,
             'consumption': 7.95,
             'fuel_price': d_6,
             'fuel_type': 'Diesel',
             'repairs_yearly': 1200,
             'millage_yearly': 18000,
             'holding_period': 6.0,
             'image_url': 'cars/skoda-kodiaq-2p0-tdi.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?id=319879014'
})

#cars

# %%
latex = ''
for car in cars:
    label=car['label']
    bk_inputs = a_subset = {key: car[key] for key in ['acquisition_cost', 
                                                      'holding_period',
                                                      'millage_yearly',
                                                      'consumption',
                                                      'fuel_price',
                                                      'repairs_yearly',  # bis hierher Hauptkosten
                                                      'interest_rate',
                                                      'taxes_yearly',
                                                      'insurance_yearly',
                                                      'rest_value']}
    (input_values, calc_values) = bk(**bk_inputs)
    
    input_values_path = 'images/' + slugify(label) + '-boundaries.png'
    calc_df_path = 'images/' + slugify(label) + '-calc_df.png'
    
    latex = r"""%s
\twocolumn

\section*{%s}
\begin{center}
\includegraphics[width=0.9\columnwidth]{%s}
\null
\vspace{0.5cm}
\includegraphics[width=0.9\columnwidth]{%s}
\end{center}

\pagebreak
\null
\vspace{2cm}
\begin{center}
\includegraphics[width=0.9\columnwidth]{%s}

# %s, Laufzeit: %.0f Jahre, \href{%s}{Weblink}

Spritpreis \"uber Haltedauer: %.2f \euro{}/l

\end{center}

\pagebreak

""" %(latex,
      label,
      input_values_path,
      calc_df_path,
      car['image_url'],
      label,
      car['holding_period'],
      car['web_url'].replace('#', '\#'),
      car['fuel_price']
     )

    # calc_values.loc['Lieferzeit', :] = car['delivery_time']
    # calc_values.loc['Kraftstoffsorte', :] = car['fuel_type']
    # calc_values = calc_values.reindex(index = ['Lieferzeit',
    #                                            'Kraftstoffsorte',
    #                                            'Anschaffungskosten',
    #                                            'Zinsen',
    #                                            'Versicherung',
    #                                            'Steuern',
    #                                            'Reparaturen',
    #                                            'Verbrauch',
    #                                            'SUMME',
    #                                            'Restwert',
    #                                            'Summe mit Restwert'
    #                                           ])
    overview[label] = calc_values['Monatlich']
    
    
    sum_row = pd.IndexSlice[calc_values.index[calc_values.index == "SUMME"], :]
    dfi.export(input_values.round(2), input_values_path)
    dfi.export(calc_values.style.applymap(df_style, subset=sum_row).set_precision(2), calc_df_path)
    #display(input_values.round(2))
    #display(calc_values.style.applymap(df_style, subset=sum_row).set_precision(2))
# Out:
# <ipython-input-75-ea1b55fae70a>:74: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(calc_values.style.applymap(df_style, subset=sum_row).set_precision(2), calc_df_path)

# %%
overview_path = 'images/overview.png'

sum_row = pd.IndexSlice[calc_values.index[calc_values.index == "SUMME"], :]
dfi.export(overview.style.applymap(df_style, subset=sum_row).set_precision(2), overview_path)
display(overview.style.applymap(df_style, subset=sum_row).set_precision(2))
latex = r"""%s

\pagebreak

\onecolumn
\null
\vfill 
\begin{center}
\includegraphics[width=0.95\columnwidth]{%s}
\end{center}
\vfill 
""" % (latex,
      overview_path)
# Out:
# <ipython-input-76-b3ce38627c91>:4: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(overview.style.applymap(df_style, subset=sum_row).set_precision(2), overview_path)
# <ipython-input-76-b3ce38627c91>:5: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(overview.style.applymap(df_style, subset=sum_row).set_precision(2))
# <style type="text/css">
# #T_57302_row6_col0, #T_57302_row6_col1, #T_57302_row6_col2, #T_57302_row6_col3, #T_57302_row6_col4, #T_57302_row6_col5, #T_57302_row6_col6, #T_57302_row6_col7, #T_57302_row6_col8, #T_57302_row6_col9, #T_57302_row6_col10, #T_57302_row6_col11, #T_57302_row6_col12, #T_57302_row6_col13 {
#   font-weight: bold;
#   background-color: yellow;
# }
# </style>
# <table id="T_57302_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >BMW 318d 2011</th>
#       <th class="col_heading level0 col1" >Nissan Micra 2010</th>
#       <th class="col_heading level0 col2" >Mercedes C 220d</th>
#       <th class="col_heading level0 col3" >Mercedes C 200</th>
#       <th class="col_heading level0 col4" >Mercedes C 180</th>
#       <th class="col_heading level0 col5" >Tesla Model Y</th>
#       <th class="col_heading level0 col6" >Mazda 6 geb.</th>
#       <th class="col_heading level0 col7" >Mazda 6 neu</th>
#       <th class="col_heading level0 col8" >Kia ceed</th>
#       <th class="col_heading level0 col9" >Skoda Superb</th>
#       <th class="col_heading level0 col10" >Skoda Octavia</th>
#       <th class="col_heading level0 col11" >BMW Gran Tourer</th>
#       <th class="col_heading level0 col12" >Skoda Kodiaq 2.0 TSI</th>
#       <th class="col_heading level0 col13" >Skoda Kodiaq 2.0 TDI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57302_level0_row0" class="row_heading level0 row0" >Anschaffungskosten</th>
#       <td id="T_57302_row0_col0" class="data row0 col0" >205.63</td>
#       <td id="T_57302_row0_col1" class="data row0 col1" >50.00</td>
#       <td id="T_57302_row0_col2" class="data row0 col2" >401.25</td>
#       <td id="T_57302_row0_col3" class="data row0 col3" >416.25</td>
#       <td id="T_57302_row0_col4" class="data row0 col4" >356.30</td>
#       <td id="T_57302_row0_col5" class="data row0 col5" >425.00</td>
#       <td id="T_57302_row0_col6" class="data row0 col6" >478.75</td>
#       <td id="T_57302_row0_col7" class="data row0 col7" >247.43</td>
#       <td id="T_57302_row0_col8" class="data row0 col8" >224.94</td>
#       <td id="T_57302_row0_col9" class="data row0 col9" >373.47</td>
#       <td id="T_57302_row0_col10" class="data row0 col10" >225.69</td>
#       <td id="T_57302_row0_col11" class="data row0 col11" >402.64</td>
#       <td id="T_57302_row0_col12" class="data row0 col12" >415.97</td>
#       <td id="T_57302_row0_col13" class="data row0 col13" >484.58</td>
#     </tr>
#     <tr>
#       <th id="T_57302_level0_row1" class="row_heading level0 row1" >Zinsen</th>
#       <td id="T_57302_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_57302_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_57302_row1_col2" class="data row1 col2" >37.70</td>
#       <td id="T_57302_row1_col3" class="data row1 col3" >39.10</td>
#       <td id="T_57302_row1_col4" class="data row1 col4" >56.55</td>
#       <td id="T_57302_row1_col5" class="data row1 col5" >67.46</td>
#       <td id="T_57302_row1_col6" class="data row1 col6" >29.90</td>
#       <td id="T_57302_row1_col7" class="data row1 col7" >39.27</td>
#       <td id="T_57302_row1_col8" class="data row1 col8" >35.70</td>
#       <td id="T_57302_row1_col9" class="data row1 col9" >35.09</td>
#       <td id="T_57302_row1_col10" class="data row1 col10" >21.20</td>
#       <td id="T_57302_row1_col11" class="data row1 col11" >37.83</td>
#       <td id="T_57302_row1_col12" class="data row1 col12" >39.08</td>
#       <td id="T_57302_row1_col13" class="data row1 col13" >45.52</td>
#     </tr>
#     <tr>
#       <th id="T_57302_level0_row2" class="row_heading level0 row2" >Versicherung</th>
#       <td id="T_57302_row2_col0" class="data row2 col0" >64.58</td>
#       <td id="T_57302_row2_col1" class="data row2 col1" >30.15</td>
#       <td id="T_57302_row2_col2" class="data row2 col2" >64.58</td>
#       <td id="T_57302_row2_col3" class="data row2 col3" >45.48</td>
#       <td id="T_57302_row2_col4" class="data row2 col4" >56.52</td>
#       <td id="T_57302_row2_col5" class="data row2 col5" >45.09</td>
#       <td id="T_57302_row2_col6" class="data row2 col6" >57.63</td>
#       <td id="T_57302_row2_col7" class="data row2 col7" >50.10</td>
#       <td id="T_57302_row2_col8" class="data row2 col8" >31.76</td>
#       <td id="T_57302_row2_col9" class="data row2 col9" >50.10</td>
#       <td id="T_57302_row2_col10" class="data row2 col10" >38.24</td>
#       <td id="T_57302_row2_col11" class="data row2 col11" >48.90</td>
#       <td id="T_57302_row2_col12" class="data row2 col12" >39.94</td>
#       <td id="T_57302_row2_col13" class="data row2 col13" >40.50</td>
#     </tr>
#     <tr>
#       <th id="T_57302_level0_row3" class="row_heading level0 row3" >Steuern</th>
#       <td id="T_57302_row3_col0" class="data row3 col0" >19.17</td>
#       <td id="T_57302_row3_col1" class="data row3 col1" >5.33</td>
#       <td id="T_57302_row3_col2" class="data row3 col2" >19.17</td>
#       <td id="T_57302_row3_col3" class="data row3 col3" >11.33</td>
#       <td id="T_57302_row3_col4" class="data row3 col4" >11.33</td>
#       <td id="T_57302_row3_col5" class="data row3 col5" >0.00</td>
#       <td id="T_57302_row3_col6" class="data row3 col6" >11.33</td>
#       <td id="T_57302_row3_col7" class="data row3 col7" >11.33</td>
#       <td id="T_57302_row3_col8" class="data row3 col8" >11.33</td>
#       <td id="T_57302_row3_col9" class="data row3 col9" >19.17</td>
#       <td id="T_57302_row3_col10" class="data row3 col10" >19.17</td>
#       <td id="T_57302_row3_col11" class="data row3 col11" >10.83</td>
#       <td id="T_57302_row3_col12" class="data row3 col12" >10.83</td>
#       <td id="T_57302_row3_col13" class="data row3 col13" >19.17</td>
#     </tr>
#     <tr>
#       <th id="T_57302_level0_row4" class="row_heading level0 row4" >Reparaturen</th>
#       <td id="T_57302_row4_col0" class="data row4 col0" >168.03</td>
#       <td id="T_57302_row4_col1" class="data row4 col1" >32.95</td>
#       <td id="T_57302_row4_col2" class="data row4 col2" >150.00</td>
#       <td id="T_57302_row4_col3" class="data row4 col3" >75.00</td>
#       <td id="T_57302_row4_col4" class="data row4 col4" >75.00</td>
#       <td id="T_57302_row4_col5" class="data row4 col5" >41.67</td>
#       <td id="T_57302_row4_col6" class="data row4 col6" >75.00</td>
#       <td id="T_57302_row4_col7" class="data row4 col7" >75.00</td>
#       <td id="T_57302_row4_col8" class="data row4 col8" >75.00</td>
#       <td id="T_57302_row4_col9" class="data row4 col9" >100.00</td>
#       <td id="T_57302_row4_col10" class="data row4 col10" >100.00</td>
#       <td id="T_57302_row4_col11" class="data row4 col11" >75.00</td>
#       <td id="T_57302_row4_col12" class="data row4 col12" >75.00</td>
#       <td id="T_57302_row4_col13" class="data row4 col13" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_57302_level0_row5" class="row_heading level0 row5" >Verbrauch</th>
#       <td id="T_57302_row5_col0" class="data row5 col0" >164.50</td>
#       <td id="T_57302_row5_col1" class="data row5 col1" >24.06</td>
#       <td id="T_57302_row5_col2" class="data row5 col2" >148.50</td>
#       <td id="T_57302_row5_col3" class="data row5 col3" >216.00</td>
#       <td id="T_57302_row5_col4" class="data row5 col4" >210.00</td>
#       <td id="T_57302_row5_col5" class="data row5 col5" >72.00</td>
#       <td id="T_57302_row5_col6" class="data row5 col6" >204.00</td>
#       <td id="T_57302_row5_col7" class="data row5 col7" >240.00</td>
#       <td id="T_57302_row5_col8" class="data row5 col8" >210.00</td>
#       <td id="T_57302_row5_col9" class="data row5 col9" >160.88</td>
#       <td id="T_57302_row5_col10" class="data row5 col10" >148.50</td>
#       <td id="T_57302_row5_col11" class="data row5 col11" >221.67</td>
#       <td id="T_57302_row5_col12" class="data row5 col12" >249.48</td>
#       <td id="T_57302_row5_col13" class="data row5 col13" >196.76</td>
#     </tr>
#     <tr>
#       <th id="T_57302_level0_row6" class="row_heading level0 row6" >SUMME</th>
#       <td id="T_57302_row6_col0" class="data row6 col0" >621.91</td>
#       <td id="T_57302_row6_col1" class="data row6 col1" >142.49<

# %%
with open('report.tex', 'w') as fid:
    fid.write(r"""
\documentclass[landscape, DIV=99, 14pt]{scrartcl}

\renewcommand*{\familydefault}{\sfdefault}

\RequirePackage{graphicx}
\RequirePackage{hyperref}
\RequirePackage[gen]{eurosym}

\begin{document}

\twocolumn
\includegraphics[width=1.1\columnwidth]{images/kosten_verteilung.png}
\includegraphics[width=1.4\columnwidth]{images/kosten_maximus.png}

\pagebreak

\begin{itemize}
    \item Wertverlust
    \begin{itemize}
        \item Kaufpreis minus Verkaufspreis
        \item Kraftstoffe
        \item Summe aller Tankstellenbesuche
    \end{itemize}
    \item Wartung und Reparatur
    \begin{itemize}
        \item Regul\"are Wartungsarbeiten (\"Olwechsel, etc)
        \item Reparaturen Aufgrund technischer Defekte
        \item Unfallsch\"aden
    \end{itemize}
    \item Versicherung
    \begin{itemize}
        \item J\"ahrlicher Versicherungsbeitrag
        \item Mobilit\"ats-Service
    \end{itemize}
    \item Steuern
    \begin{itemize}
            \item J\"ahrliche KFZ-Steuer
    \end{itemize}
\end{itemize}

# %s

\end{document}
""" % (latex))
