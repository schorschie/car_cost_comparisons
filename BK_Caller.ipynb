# %%
from bk import bk
import pandas as pd
import dataframe_image as dfi
from slugify import slugify
from pathlib import Path

overview = pd.DataFrame()
overview.name='Monatliche Kosten im Verlgeich'

def df_style(val):
    return "font-weight: bold; background-color: yellow"

# %%
cars = [{'label': 'BMW D 2011',
         'acquisition_cost': 16903,
         'car_year': 2011,
         'interest_rate': 0.,
         'rest_value': 1500,
         'insurance_yearly': 775,
         'taxes_yearly': 230,
         'consumption': 6.38,
         'fuel_price': 1.19,
         'repairs_yearly': 2016.32,
         'millage_yearly': 26000,
         'holding_period': 6.85,
         'image_url': 'cars/bmw-3er-maximus.png',
         'web_url': 'https://de.wikipedia.org/wiki/BMW_E90'
        }]
cars.append({'label': 'Micra B 2010',
             'acquisition_cost': 3300,
             'car_year': 2011,
             'interest_rate': 0.,
             'rest_value': 200,
             'insurance_yearly': 361.76,
             'taxes_yearly': 64,
             'consumption': 6.6,
             'fuel_price': 1.36,
             'repairs_yearly': 395.40,
             'millage_yearly': 3216,
             'holding_period': 5.5,  
             'image_url': 'cars/nissan-micra.jpg',
             'web_url': 'https://de.wikipedia.org/wiki/Nissan_Micra#Micra_(K12,_2003%E2%80%932010)'
})
cars.append({'label': 'Mercedes D 2019',
             'acquisition_cost': 28890,
             'car_year': 2019,
             'interest_rate': 3.,
             'rest_value': 5000,
             'insurance_yearly': 775,
             'taxes_yearly': 230,
             'consumption': 6.,
             'fuel_price': 1.65,
             'repairs_yearly': 1800,
             'millage_yearly': 18000,
             'holding_period': 6.0,  
             'image_url': 'cars/mercedes-c-220d-t.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?action=parkItem&id=336723447'
})
cars.append({'label': 'Mercedes B 2019',
             'acquisition_cost': 29970,
             'car_year': 2019,
             'interest_rate': 3.,
             'rest_value': 7000,
             'insurance_yearly': 775,
             'taxes_yearly': 136,
             'consumption': 8.,
             'fuel_price': 1.85,
             'repairs_yearly': 900,
             'millage_yearly': 18000,
             'holding_period': 6.0,  
             'image_url': 'cars/mercedes-c-200-t.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?action=parkItem&id=327113608'
})
cars.append({'label': 'Tesla E 2022',
             'acquisition_cost': 51000,
             'car_year': 2022,
             'interest_rate': 3.,
             'rest_value': 5000,
             'insurance_yearly': 775,
             'taxes_yearly': 0,
             'consumption': 16.,
             'fuel_price': .3,
             'repairs_yearly': 500,
             'millage_yearly': 18000,
             'holding_period': 10.0,   
             'image_url': 'cars/tesla-model-y.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview'
})
cars.append({'label': 'Mazda B 2017',
             'acquisition_cost': 22980,
             'car_year': 2017,
             'interest_rate': 3.,
             'rest_value': 4000,
             'insurance_yearly': 775,
             'taxes_yearly': 136,
             'consumption': 8.,
             'fuel_price': 1.85,
             'repairs_yearly': 900,
             'millage_yearly': 18000,
             'holding_period': 4.0,  
             'image_url': 'cars/mazda-6-alt.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?action=parkItem&id=332186075'
})
cars.append({'label': 'Mazda B 2022',
             'acquisition_cost': 29692,
             'car_year': 2022,
             'interest_rate': 3.,
             'rest_value': 3000,
             'insurance_yearly': 775,
             'taxes_yearly': 136,
             'consumption': 8.,
             'fuel_price': 2.00,
             'repairs_yearly': 900,
             'millage_yearly': 18000,
             'holding_period': 10.0,  
             'image_url': 'cars/mazda-6-neu.png',
             'web_url': 'https://konfigurator.meinauto.de/mazda/neuwagen/48-6/angebote/6-kombi/konfigurator/#!/extras/exclusive-line/8846370/10,11/private/65352-5416-204698/984/61c9aa657e74c/cash-purchase/32545--287374/48,0,10000,0,0,0,0,0,'
})
cars.append({'label': 'Kia B 2022',
             'acquisition_cost': 26992.36,
             'car_year': 2022,
             'interest_rate': 3.,
             'rest_value': 3000,
             'insurance_yearly': 775,
             'taxes_yearly': 136,
             'consumption': 7.,
             'fuel_price': 2.00,
             'repairs_yearly': 900,
             'millage_yearly': 18000,
             'holding_period': 10.0,
             'image_url': 'cars/kia-ceed-sportswagon.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/preisvergleich/platinum/8867329/3,7,18/private/109347-4167-291321/1321/61d21ce73c5db/cash-purchase/109348-8088-291322/48,0,10000,0,0,0,0,0,'
})
cars.append({'label': 'Superb D 2018',
             'acquisition_cost': 29460,
             'car_year': 2018,
             'interest_rate': 3.,
             'rest_value': 8000,
             'insurance_yearly': 775,
             'taxes_yearly': 230,
             'consumption': 6.5,
             'fuel_price': 1.65,
             'repairs_yearly': 1200,
             'millage_yearly': 18000,
             'holding_period': 6.0,
             'image_url': 'cars/skoda-superb.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?id=336967099'
})
cars.append({'label': 'Octavia D 2019',
             'acquisition_cost': 16250,
             'car_year': 2019,
             'interest_rate': 3.,
             'rest_value': 4000,
             'insurance_yearly': 775,
             'taxes_yearly': 230,
             'consumption': 6.0,
             'fuel_price': 1.65,
             'repairs_yearly': 1200,
             'millage_yearly': 18000,
             'holding_period': 6.0,
             'image_url': 'cars/skoda-octavia.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?id=333524150'
})

#cars

# %%
latex = ''
for car in cars:
    label=car['label']
    bk_inputs = a_subset = {key: car[key] for key in ['acquisition_cost', 
                                                      'holding_period',
                                                      'millage_yearly',
                                                      'consumption',
                                                      'fuel_price',
                                                      'repairs_yearly',  # bis hierher Hauptkosten
                                                      'interest_rate',
                                                      'taxes_yearly',
                                                      'insurance_yearly',
                                                      'rest_value']}
    (input_values, calc_values) = bk(**bk_inputs)
    
    input_values_path = 'images/' + slugify(label) + '-boundaries.png'
    calc_df_path = 'images/' + slugify(label) + '-calc_df.png'
    
    latex = r"""%s
\twocolumn

\section*{%s}
\begin{center}
\includegraphics[width=0.9\columnwidth]{%s}
\null
\vspace{0.5cm}
\includegraphics[width=0.9\columnwidth]{%s}
\end{center}

\pagebreak
\null
\vspace{2cm}
\begin{center}
\includegraphics[width=0.9\columnwidth]{%s}

# %s, %d, Laufzeit: %.0f Jahre, \href{%s}{Weblink}
\end{center}

\pagebreak

""" %(latex,
      label,
      input_values_path,
      calc_df_path,
      car['image_url'],
      label,
      car['car_year'],
      car['holding_period'],
      car['web_url'].replace('#', '\#')
     )

    overview[label] = calc_values['Monatlich']
    
    
    sum_row = pd.IndexSlice[calc_values.index[calc_values.index == "SUMME"], :]
    #dfi.export(input_values.round(2), input_values_path)
    #dfi.export(calc_values.style.applymap(df_style, subset=sum_row).set_precision(2), calc_df_path)
    #display(input_values.round(2))
    #display(calc_values.style.applymap(df_style, subset=sum_row).set_precision(2))

# %%
overview_path = 'images/overview.png'

sum_row = pd.IndexSlice[calc_values.index[calc_values.index == "SUMME"], :]
#dfi.export(overview.style.applymap(df_style, subset=sum_row).set_precision(2), overview_path)
display(overview.style.applymap(df_style, subset=sum_row).set_precision(2))
latex = r"""%s

\pagebreak

\onecolumn
\null
\vfill 
\begin{center}
\includegraphics[width=0.95\columnwidth]{%s}
\end{center}
\vfill 
""" % (latex,
      overview_path)
# Out:
# C:\Users\lgi1sgm\.conda\envs\grzegorz\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   """
# <style type="text/css">
# #T_491e0_row6_col0, #T_491e0_row6_col1, #T_491e0_row6_col2, #T_491e0_row6_col3, #T_491e0_row6_col4, #T_491e0_row6_col5, #T_491e0_row6_col6, #T_491e0_row6_col7, #T_491e0_row6_col8, #T_491e0_row6_col9 {
#   font-weight: bold;
#   background-color: yellow;
# }
# </style>
# <table id="T_491e0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >BMW D 2011</th>
#       <th class="col_heading level0 col1" >Micra B 2010</th>
#       <th class="col_heading level0 col2" >Mercedes D 2019</th>
#       <th class="col_heading level0 col3" >Mercedes B 2019</th>
#       <th class="col_heading level0 col4" >Tesla E 2022</th>
#       <th class="col_heading level0 col5" >Mazda B 2017</th>
#       <th class="col_heading level0 col6" >Mazda B 2022</th>
#       <th class="col_heading level0 col7" >Kia B 2022</th>
#       <th class="col_heading level0 col8" >Superb D 2018</th>
#       <th class="col_heading level0 col9" >Octavia D 2019</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_491e0_level0_row0" class="row_heading level0 row0" >Anschaffungskosten</th>
#       <td id="T_491e0_row0_col0" class="data row0 col0" >205.63</td>
#       <td id="T_491e0_row0_col1" class="data row0 col1" >50.00</td>
#       <td id="T_491e0_row0_col2" class="data row0 col2" >401.25</td>
#       <td id="T_491e0_row0_col3" class="data row0 col3" >416.25</td>
#       <td id="T_491e0_row0_col4" class="data row0 col4" >425.00</td>
#       <td id="T_491e0_row0_col5" class="data row0 col5" >478.75</td>
#       <td id="T_491e0_row0_col6" class="data row0 col6" >247.43</td>
#       <td id="T_491e0_row0_col7" class="data row0 col7" >224.94</td>
#       <td id="T_491e0_row0_col8" class="data row0 col8" >409.17</td>
#       <td id="T_491e0_row0_col9" class="data row0 col9" >225.69</td>
#     </tr>
#     <tr>
#       <th id="T_491e0_level0_row1" class="row_heading level0 row1" >Zinsen</th>
#       <td id="T_491e0_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_491e0_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_491e0_row1_col2" class="data row1 col2" >37.70</td>
#       <td id="T_491e0_row1_col3" class="data row1 col3" >39.10</td>
#       <td id="T_491e0_row1_col4" class="data row1 col4" >67.46</td>
#       <td id="T_491e0_row1_col5" class="data row1 col5" >29.90</td>
#       <td id="T_491e0_row1_col6" class="data row1 col6" >39.27</td>
#       <td id="T_491e0_row1_col7" class="data row1 col7" >35.70</td>
#       <td id="T_491e0_row1_col8" class="data row1 col8" >38.44</td>
#       <td id="T_491e0_row1_col9" class="data row1 col9" >21.20</td>
#     </tr>
#     <tr>
#       <th id="T_491e0_level0_row2" class="row_heading level0 row2" >Versicherung</th>
#       <td id="T_491e0_row2_col0" class="data row2 col0" >64.58</td>
#       <td id="T_491e0_row2_col1" class="data row2 col1" >30.15</td>
#       <td id="T_491e0_row2_col2" class="data row2 col2" >64.58</td>
#       <td id="T_491e0_row2_col3" class="data row2 col3" >64.58</td>
#       <td id="T_491e0_row2_col4" class="data row2 col4" >64.58</td>
#       <td id="T_491e0_row2_col5" class="data row2 col5" >64.58</td>
#       <td id="T_491e0_row2_col6" class="data row2 col6" >64.58</td>
#       <td id="T_491e0_row2_col7" class="data row2 col7" >64.58</td>
#       <td id="T_491e0_row2_col8" class="data row2 col8" >64.58</td>
#       <td id="T_491e0_row2_col9" class="data row2 col9" >64.58</td>
#     </tr>
#     <tr>
#       <th id="T_491e0_level0_row3" class="row_heading level0 row3" >Steuern</th>
#       <td id="T_491e0_row3_col0" class="data row3 col0" >19.17</td>
#       <td id="T_491e0_row3_col1" class="data row3 col1" >5.33</td>
#       <td id="T_491e0_row3_col2" class="data row3 col2" >19.17</td>
#       <td id="T_491e0_row3_col3" class="data row3 col3" >11.33</td>
#       <td id="T_491e0_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_491e0_row3_col5" class="data row3 col5" >11.33</td>
#       <td id="T_491e0_row3_col6" class="data row3 col6" >11.33</td>
#       <td id="T_491e0_row3_col7" class="data row3 col7" >11.33</td>
#       <td id="T_491e0_row3_col8" class="data row3 col8" >19.17</td>
#       <td id="T_491e0_row3_col9" class="data row3 col9" >19.17</td>
#     </tr>
#     <tr>
#       <th id="T_491e0_level0_row4" class="row_heading level0 row4" >Reparaturen</th>
#       <td id="T_491e0_row4_col0" class="data row4 col0" >168.03</td>
#       <td id="T_491e0_row4_col1" class="data row4 col1" >32.95</td>
#       <td id="T_491e0_row4_col2" class="data row4 col2" >150.00</td>
#       <td id="T_491e0_row4_col3" class="data row4 col3" >75.00</td>
#       <td id="T_491e0_row4_col4" class="data row4 col4" >41.67</td>
#       <td id="T_491e0_row4_col5" class="data row4 col5" >75.00</td>
#       <td id="T_491e0_row4_col6" class="data row4 col6" >75.00</td>
#       <td id="T_491e0_row4_col7" class="data row4 col7" >75.00</td>
#       <td id="T_491e0_row4_col8" class="data row4 col8" >100.00</td>
#       <td id="T_491e0_row4_col9" class="data row4 col9" >100.00</td>
#     </tr>
#     <tr>
#       <th id="T_491e0_level0_row5" class="row_heading level0 row5" >Verbrauch</th>
#       <td id="T_491e0_row5_col0" class="data row5 col0" >164.50</td>
#       <td id="T_491e0_row5_col1" class="data row5 col1" >24.06</td>
#       <td id="T_491e0_row5_col2" class="data row5 col2" >148.50</td>
#       <td id="T_491e0_row5_col3" class="data row5 col3" >222.00</td>
#       <td id="T_491e0_row5_col4" class="data row5 col4" >72.00</td>
#       <td id="T_491e0_row5_col5" class="data row5 col5" >222.00</td>
#       <td id="T_491e0_row5_col6" class="data row5 col6" >240.00</td>
#       <td id="T_491e0_row5_col7" class="data row5 col7" >210.00</td>
#       <td id="T_491e0_row5_col8" class="data row5 col8" >160.88</td>
#       <td id="T_491e0_row5_col9" class="data row5 col9" >148.50</td>
#     </tr>
#     <tr>
#       <th id="T_491e0_level0_row6" class="row_heading level0 row6" >SUMME</th>
#       <td id="T_491e0_row6_col0" class="data row6 col0" >621.91</td>
#       <td id="T_491e0_row6_col1" class="data row6 col1" >142.49</td>
#       <td id="T_491e0_row6_col2" class="data row6 col2" >821.20</td>
#       <td id="T_491e0_row6_col3" class="data row6 col3" >828.27</td>
#       <td id="T_491e0_row6_col4" class="data row6 col4" >670.71</td>
#       <td id="T_491e0_row6_col5" class="data row6 col5" >881.56</td>
#       <td id="T_491e0_row6_col6" class="data row6 col6" >677.62</td>
#       <td id="T_491e0_row6_col7" class="data row6 col7" >621.56</td>
#       <td id="T_491e0_row6_col8" class="data row6 col8" >792.23</td>
#       <td id="T_491e0_row6_col9" class="data row6 col9" >579.15</td>
#     </tr>
#     <tr>
#       <th id="T_491e0_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_491e0_row7_col0" class="data row7 col0" >-18.25</td>
#       <td id="T_491e0_row7_col1" class="data row7 col1" >-3.03</td>
#       <td id="T_491e0_row7_col2" class="data row7 col2" >-69.44</td>
#       <td id="T_491e0_row7_col3" class="data row7 col3" >-97.22</td>
#       <td id="T_491e0_row7_col4" class="data row7 col4" >-41.67</td>
#       <td id="T_491e0_row7_col5" class="data row7 col5" >-83.33</td>
#       <td id="T_491e0_row7_col6" class="data row7 col6" >-25.00</td>
#       <td id="T_491e0_row7_col7" class="data row7 col7" >-25.00</td>
#       <td id="T_491e0_row7_col8" class="data row7 col8" >-111.11</td>
#       <td id="T_491e0_row7_col9" class="data row7 col9" >-55.56</td>
#     </tr>
#     <tr>
#       <th id="T_491e0_level0_row8" class="row_heading level0 row8" >Summe mit Restwert</th>
#       <td id="T_491e0_row8_col0" class="data row8 col0" >603.66</td>
#       <td id="T_491e0_row8_col1" class="data row8 col1" >139.46</td>
#       <td id="T_491e0_row8_col2" class="data row8 col2" >751.75</td>
#       <td id="T_491e0_row8_col3" class="data row8 col3" >731.05</td>
#       <td id="T_491e0_row8_col4" class="data row8 col4" >629.04</td>
#       <td id="T_491e0_row8_col5" class="data row8 col5" >798.23</td>
#       <td id="T_491e0_row8_col6" class="data row8 col6" >652.62</td>
#       <td id="T_491e0_row8_col7" class="data row8 col7" >596.56</td>
#       <td id="T_491e0_row8_col8" c

# %%
with open('report.tex', 'w') as fid:
    fid.write(r"""
\documentclass[landscape, DIV=99, 14pt]{scrartcl}

\renewcommand*{\familydefault}{\sfdefault}

\RequirePackage{graphicx}
\RequirePackage{hyperref}

\begin{document}

\twocolumn
\includegraphics[width=1.1\columnwidth]{images/kosten_verteilung.png}
\includegraphics[width=1.4\columnwidth]{images/kosten_maximus.png}

\pagebreak

\begin{itemize}
    \item Wertverlust
    \begin{itemize}
        \item Kaufpreis minus Verkaufspreis
        \item Kraftstoffe
        \item Summe aller Tankstellenbesuche
    \end{itemize}
    \item Wartung und Reparatur
    \begin{itemize}
        \item Regul\"are Wartungsarbeiten (\"Olwechsel, etc)
        \item Reparaturen Aufgrund technischer Defekte
        \item Unfallsch\"aden
    \end{itemize}
    \item Versicherung
    \begin{itemize}
        \item J\"ahrlicher Versicherungsbeitrag
        \item Mobilit\"ats-Service
    \end{itemize}
    \item Steuern
    \begin{itemize}
            \item J\"ahrliche KFZ-Steuer
    \end{itemize}
\end{itemize}

# %s

\end{document}
""" % (latex))
