# %%
import os
import pandas as pd
import dataframe_image as dfi
from slugify import slugify
from pathlib import Path
from bk import Operating_Cost

overview = pd.DataFrame()
overview.name='Monatliche Kosten im Verlgeich'

def df_style(val):
    # return "font-weight: bold; background: yellow"
    return "font-weight: bold;"

def light_style(val):
    return "color: grey"

# %%
#d_0 = 1.52  # Aktueller Dieselpreis 3.1.2022: 1.52
b_0 = 1.70  # Aktueller Benzinpreis 3.1.2022: 1.56
e_0 = 0.31  # Aktueller Strompreis 3.1.2022: 0.31 €/kWh

cars = []       
cars.append({'label': 'BMW 318d 2011',
             'acquisition_cost': 16903,
             'government_funding': 0,
             'down_payment': 0,
             'car_year': 2011,
             'delivery_time': 0,
             'interest_rate': 0.,
             'rest_value': 3000,
             'insurance_yearly': 775,
             'taxes_yearly': 230,
             'consumption': 6.38,
             'power': 137,
             'fuel_price': 1.19,  # Durchschnittlicher Dieselpreis seit 2015
             'fuel_type': 'Diesel',
             'fuel_unit': 'l',
             'repairs_yearly': 2016.32,
             'millage_yearly': 26000,
             'holding_period': 6.85,
             'image_url': 'cars/bmw-3er-maximus.png',
             'web_url': 'https://de.wikipedia.org/wiki/BMW_E90',
             'buy': True,  # else lease
             'estimate': False
            }
           )
cars.append({'label': 'Nissan Micra 2010',
             'acquisition_cost': 3300,
             'government_funding': 0,
             'down_payment': 3300,
             'car_year': 2011,
             'delivery_time': 0,
             'interest_rate': 0.,
             'rest_value': 2000,
             'insurance_yearly': 361.76,
             'taxes_yearly': 64,
             'consumption': 6.6,
             'power': 65,
             'fuel_price': 1.36,  # Durchschnittlicher Dieselpreis seit 2016
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 395.40,
             'millage_yearly': 3216,
             'holding_period': 5.5,  
             'image_url': 'cars/nissan-micra.jpg',
             'web_url': 'https://de.wikipedia.org/wiki/Nissan_Micra#Micra_(K12,_2003%E2%80%932010)',
             'buy': True,  # else lease
             'estimate': False
            }
           )
cars.append({'label': 'Tesla Model Y',
             'acquisition_cost': 52970,
             'government_funding': 5000,
             'down_payment': 15000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 10000,
             'insurance_yearly': 459.78,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-y.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Tesla Model Y',
             'instalment': 533,
             'government_funding': 5000,
             'down_payment': 8000,
             'car_year': 2022,
             'delivery_time': 4,
             'rest_value': 9000,
             'insurance_yearly': 566.90,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 4.0,   
             'image_url': 'cars/tesla-model-y-leasing.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Tesla Model 3',
             'acquisition_cost': 43970,
             'government_funding': 6000,
             'down_payment': 16000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 8500,
             'insurance_yearly': 544,
             'taxes_yearly': 0,
             'consumption': 15.,
             'power': 325,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-3.jpg',
             'web_url': 'https://www.tesla.com/de_de/model3/design#overview',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Tesla Model 3',
             'instalment': 360,
             'government_funding': 6000,
             'down_payment': 9000,
             'car_year': 2022,
             'delivery_time': 4,
             'rest_value': 8500,
             'insurance_yearly': 673.60,
             'taxes_yearly': 0,
             'consumption': 15.,
             'power': 325,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 4.0,   
             'image_url': 'cars/tesla-model-3-leasing.jpg',
             'web_url': 'https://www.tesla.com/de_de/model3/design#overview',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Mazda 6',
             'acquisition_cost': 30643.19,
             'government_funding': 0,
             'down_payment': 10000,
             'car_year': 2022,
             'delivery_time': 20,
             'interest_rate': 2.,
             'rest_value': 6000,
             'insurance_yearly': 510.90,
             'taxes_yearly': 156,
             'consumption': 8.,
             'power': 192,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,  
             'image_url': 'cars/mazda-6-neu.png',
             'web_url': 'https://konfigurator.meinauto.de/mazda/neuwagen/48-6/angebote/6-kombi/konfigurator/#!/extras/exclusive-line/8846370/10,11/private/65352-5416-204698/984/61c9aa657e74c/cash-purchase/32545--287374/48,0,10000,0,0,0,0,0,',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Mazda 6',
             'instalment': 284.70,
             'government_funding': 0,
             'down_payment': 3000,
             'car_year': 2022,
             'delivery_time': 60,
             'rest_value': 3000,
             'insurance_yearly': 629.91,
             'taxes_yearly': 156,
             'consumption': 8.,
             'power': 192,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3,  
             'image_url': 'cars/mazda-6-leasing.png',
             'web_url': 'https://konfigurator.meinauto.de/mazda/neuwagen/48-6/angebote/6-kombi/konfigurator/#!/extras/exclusive-line/8846370/10,11,15/private/65352-5416-204698/984/61c9aa657e74c/leasing/16040--249432/36,3000,15000,0,0,0,0,0,',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Kia ceed',
             'acquisition_cost': 25209.43,
             'government_funding': 0,
             'down_payment': 10000,
             'car_year': 2022,
             'delivery_time': 52,
             'interest_rate': 2.,
             'rest_value': 5000,
             'insurance_yearly': 325.99,
             'taxes_yearly': 107,
             'consumption': 7.,
             'power': 160,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,
             'image_url': 'cars/kia-ceed-sportswagon.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/extras/spirit/8865371/3,11,27/private/109347-4167-291321/1321/61d21ce73c5db/cash-purchase/109348-8088-291322/48,0,10000,0,0,0,0,0,',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Kia ceed',
             'instalment': 227.42,
             'government_funding': 0,
             'down_payment': 3000,
             'car_year': 2022,
             'delivery_time': 52,
             'rest_value': 3000,
             'insurance_yearly': 395.58,
             'taxes_yearly': 107,
             'consumption': 7.,
             'power': 160,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3.0,
             'image_url': 'cars/kia-ceed-sportswagon-leasing.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/extras/spirit/8865371/3,11,27/private/109347-4167-291321/1321/61d21ce73c5db/leasing/109348-8088-291322/36,3000,15000,0,0,0,0,0,',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'VW Passat',
             'acquisition_cost': 30230.0,
             'government_funding': 0,
             'down_payment': 10000,
             'car_year': 2021,
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 6000,
             'insurance_yearly': 351.35,
             'taxes_yearly': 98,
             'consumption': 7.5,
             'power': 150,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,
             'image_url': 'cars/vw-passat.jpg',
             'web_url': 'https://www.autosuche.de/auto/REVVNDQ3NjgwMjc5NzI=?t_manuf=BQ&t_petr=B&t_model=BQBM&t_gear=A&t_ez_fr=2020&t_pe_fr=35000&sort=PRICE_SALE&sortdirection=ASC&viewMode=tile',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'VW Passat',
             'instalment': 194.18 + 4557.50/36,
             'government_funding': 0,
             'down_payment': 3000,
             'car_year': 2022,
             'delivery_time': 0,
             'rest_value': 3000,
             'insurance_yearly': 423.07,
             'taxes_yearly': 98,
             'consumption': 7.5,
             'power': 150,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3.0,
             'image_url': 'cars/vw-passat-leasing.jpg',
             'web_url': 'https://www.autosuche.de/auto/REVVNDQ3NjgwMjc5NzI=?t_manuf=BQ&t_petr=B&t_model=BQBM&t_gear=A&t_ez_fr=2020&t_pe_fr=35000&sort=PRICE_SALE&sortdirection=ASC&viewMode=tile',
             'buy': False,  # else lease
             'estimate': True
            }
           )

cars.append({'label': 'Mercedes C 180',
             'acquisition_cost': 42755.83,
             'government_funding': 0,
             'down_payment': 10000,
             'car_year': 2022,
             'delivery_time': 60,
             'interest_rate': 3.,
             'rest_value': 8000,
             'insurance_yearly': 678.24,
             'taxes_yearly': 136,
             'consumption': 7.,
             'power': 170,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,  
             'image_url': 'cars/mercedes-c-180-t.png',
             'web_url': 'https://konfigurator.meinauto.de/mercedes/neuwagen/c-klasse/angebote/c-klasse-t-modell/konfigurator/#!/preisvergleich/-/8866563/2,47,74,81/private/43735-7309-290394/349/61d36ce4c3067/cash-purchase/73169--190162/48,0,10000,0,0,0,0,0,',
             'buy': True,  # else lease
             'estimate': True
            }
           )  
for car in cars:
    if car['buy']:
        factor = .5**(car['holding_period']/3)
        car['rest_value_thumb_value'] = r'Restwert nach Faustformel (Neupreis $\times$ %.1f\%%): %.2f \euro{}' % \
        (factor*100, car['acquisition_cost'] * factor)
    else:
        car['rest_value_thumb_value'] = r'Kein Restwert, da Leasingfahrzeug'

# %%
latex = ''
for car in cars:
    if car['estimate']:
        estimate_string = r'\emph{Gesch\"atzter}'
    else:
        estimate_string = r'\emph{Realer}'
        
    if car['buy']:
        label=car['label'] + ' Kaufen'
        bk_inputs = {key: car[key] for key in ['acquisition_cost', 
                                               'government_funding',
                                               'down_payment',
                                               'holding_period',
                                               'millage_yearly',
                                               'consumption',
                                               'fuel_price',
                                               'repairs_yearly',  # bis hierher Hauptkosten
                                               'interest_rate',
                                               'taxes_yearly',
                                               'insurance_yearly',
                                               'rest_value']}
        (input_values, calc_values) = Operating_Cost.buy(**bk_inputs).get_frames()
    else:
        label=car['label'] + ' Leasing'
        bk_inputs = {key: car[key] for key in ['instalment', 
                                               'government_funding',
                                               'down_payment',
                                               'holding_period',
                                               'millage_yearly',
                                               'consumption',
                                               'fuel_price',
                                               'repairs_yearly',  # bis hierher Hauptkosten
                                               'taxes_yearly',
                                               'insurance_yearly']}
        (input_values, calc_values) = Operating_Cost.lease(**bk_inputs).get_frames()
        
    input_values_path = Path('images/' + slugify(label) + '-boundaries.png')
    calc_df_path = Path('images/' + slugify(label) + '-calc_df.png')
    
    latex = r"""%s
\twocolumn

\section*{%s}
\begin{center}
\includegraphics[width=0.5\textheight]{%s}
\null
\vspace{0.5cm}
\includegraphics[width=0.5\textheight]{%s}
\end{center}

\pagebreak
\null
\vspace{2cm}
\begin{center}
\includegraphics[width=0.9\columnwidth]{%s}

# %s
\end{center}

\begin{itemize}
    \item Baujahr: %d $\rightarrow$ Laufzeit: %.0f Jahre
    \item \href{%s}{Weblink}
    \item %s Spritpreis \"uber Haltedauer: %.2f \euro{}/%s
    \item Antrieb: %s, mit %d PS
    \item %s
\end{itemize}

\pagebreak

""" %(latex,
      label,
      input_values_path.as_posix(),
      calc_df_path.as_posix(),
      car['image_url'],
      label,
      car['car_year'],
      car['holding_period'],
      car['web_url'].replace('#', '\#'),
      estimate_string,
      car['fuel_price'],
      car['fuel_unit'],
      car['fuel_type'],
      car['power'],
      car['rest_value_thumb_value']
     )

    # calc_values.loc['Lieferzeit', :] = car['delivery_time']
    # calc_values.loc['Kraftstoffsorte', :] = car['fuel_type']
    # calc_values = calc_values.reindex(index = ['Lieferzeit',
    #                                            'Kraftstoffsorte',
    #                                            'Anschaffungskosten',
    #                                            'Zinsen',
    #                                            'Versicherung',
    #                                            'Steuern',
    #                                            'Reparaturen',
    #                                            'Verbrauch',
    #                                            'SUMME',
    #                                            'Restwert',
    #                                            'Summe mit Restwert'
    #                                           ])
    
    overview[label] = calc_values['Monatlich']
    
    input_values_path.parent.mkdir(parents=True, exist_ok=True)
    
    bold_row = pd.IndexSlice[calc_values.index[(calc_values.index == "Summe") | (calc_values.index == "Gesamtsumme")], :]
    light_row = pd.IndexSlice[calc_values.index[6:], :]
    
    dfi.export(input_values.round(2), str(input_values_path))
    dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
    display(input_values.round(2))
    display(calc_values.style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2))
# Out:
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     16903.00
# Anzahlung [€]                                                  0.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                            0.00
# Finanzierungszins [%]                                          0.00
# Restwert [€]                                                3000.00
# Versicherungskosten [€/a]                                    775.00
# Steuern [€/a]                                                230.00
# Verbrauch in l/100 km                                          6.38
# Durchschnittlicher Spritpreis über Haltedauer [...             1.19
# Reparatur und Wartungskosten [€/a]                          2016.32
# Jahreslaufleistung [km]                                    26000.00
# Haltedauer [a]                                                 6.85
# Gesamtlaufleistung [km]                                   178100.00
# Finanzierungsbetrag [€]                                    16903.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_7bbfb_row5_col0, #T_7bbfb_row5_col1, #T_7bbfb_row5_col2, #T_7bbfb_row5_col3 {
#   font-weight: bold;
# }
# #T_7bbfb_row6_col0, #T_7bbfb_row6_col1, #T_7bbfb_row6_col2, #T_7bbfb_row6_col3, #T_7bbfb_row7_col0, #T_7bbfb_row7_col1, #T_7bbfb_row7_col2, #T_7bbfb_row7_col3 {
#   color: grey;
# }
# #T_7bbfb_row8_col0, #T_7bbfb_row8_col1, #T_7bbfb_row8_col2, #T_7bbfb_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_7bbfb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bbfb_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_7bbfb_row0_col0" class="data row0 col0" >16903.00</td>
#       <td id="T_7bbfb_row0_col1" class="data row0 col1" >2467.59</td>
#       <td id="T_7bbfb_row0_col2" class="data row0 col2" >205.63</td>
#       <td id="T_7bbfb_row0_col3" class="data row0 col3" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_7bbfb_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_7bbfb_row1_col0" class="data row1 col0" >5308.75</td>
#       <td id="T_7bbfb_row1_col1" class="data row1 col1" >775.00</td>
#       <td id="T_7bbfb_row1_col2" class="data row1 col2" >64.58</td>
#       <td id="T_7bbfb_row1_col3" class="data row1 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_7bbfb_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_7bbfb_row2_col0" class="data row2 col0" >1575.50</td>
#       <td id="T_7bbfb_row2_col1" class="data row2 col1" >230.00</td>
#       <td id="T_7bbfb_row2_col2" class="data row2 col2" >19.17</td>
#       <td id="T_7bbfb_row2_col3" class="data row2 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_7bbfb_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_7bbfb_row3_col0" class="data row3 col0" >13811.79</td>
#       <td id="T_7bbfb_row3_col1" class="data row3 col1" >2016.32</td>
#       <td id="T_7bbfb_row3_col2" class="data row3 col2" >168.03</td>
#       <td id="T_7bbfb_row3_col3" class="data row3 col3" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_7bbfb_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_7bbfb_row4_col0" class="data row4 col0" >13521.71</td>
#       <td id="T_7bbfb_row4_col1" class="data row4 col1" >1973.97</td>
#       <td id="T_7bbfb_row4_col2" class="data row4 col2" >164.50</td>
#       <td id="T_7bbfb_row4_col3" class="data row4 col3" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_7bbfb_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_7bbfb_row5_col0" class="data row5 col0" >51120.75</td>
#       <td id="T_7bbfb_row5_col1" class="data row5 col1" >7462.88</td>
#       <td id="T_7bbfb_row5_col2" class="data row5 col2" >621.91</td>
#       <td id="T_7bbfb_row5_col3" class="data row5 col3" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_7bbfb_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_7bbfb_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_7bbfb_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_7bbfb_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_7bbfb_row6_col3" class="data row6 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_7bbfb_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_7bbfb_row7_col0" class="data row7 col0" >-3000.00</td>
#       <td id="T_7bbfb_row7_col1" class="data row7 col1" >-437.96</td>
#       <td id="T_7bbfb_row7_col2" class="data row7 col2" >-36.50</td>
#       <td id="T_7bbfb_row7_col3" class="data row7 col3" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_7bbfb_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_7bbfb_row8_col0" class="data row8 col0" >48120.75</td>
#       <td id="T_7bbfb_row8_col1" class="data row8 col1" >7024.93</td>
#       <td id="T_7bbfb_row8_col2" class="data row8 col2" >585.41</td>
#       <td id="T_7bbfb_row8_col3" class="data row8 col3" >0.27</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                      3300.00
# Anzahlung [€]                                               3300.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                         3300.00
# Finanzierungszins [%]                                          0.00
# Restwert [€]                                                2000.00
# Versicherungskosten [€/a]                                    361.76
# Steuern [€/a]                                                 64.00
# Verbrauch in l/100 km                                          6.60
# Durchschnittlicher Spritpreis über Haltedauer [...             1.36
# Reparatur und Wartungskosten [€/a]                           395.40
# Jahreslaufleistung [km]                                     3216.00
# Haltedauer [a]                                                 5.50
# Gesamtlaufleistung [km]                                    17688.00
# Finanzierungsbetrag [€]                                        0.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_4d850_row5_col0, #T_4d850_row5_col1, #T_4d850_row5_col2, #T_4d850_row5_col3 {
#   font-weight: bold;
# }
# #T_4d850_row6_col0, #T_4d850_row6_col1, #T_4d850_row6_col2, #T_4d850_row6_col3, #T_4d850_row7_col0, #T_4d850_row7_col1, #T_4d850_row7_col2, #T_4d850_row7_col3 {
#   color: grey;
# }
# #T_4d850_row8_col0, #T_4d850_row8_col1, #T_4d850_row8_col2, #T_4d850_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_4d850_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d850_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_4d850_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_4d850_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_4d850_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_4d850_row0_col3" class="data row0 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_4d850_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_4d850_row1_col0" class="data row1 col0" >1989.68</td>
#       <td id="T_4d850_row1_col1" class="data row1 col1" >361.76</td>
#       <td id="T_4d850_row1_col2" class="data row1 col2" >30.15</td>
#       <td id="T_4d850_row1_col3" class="data row1 col3" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_4d850_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_4d850_row2_col0" class="data row2 col0" >352.00</td>
#       <td id="T_4d850_row2_col1" class="data row2 col1" >64.00</td>
#       <td id="T_4d850_row2_col2" class="data row2 col2" >5.33</td>
#       <td id="T_4d850_row2_col3" class="data row2 col3" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_4d850_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_4d850_row3_col0" class="data row3 col0" >2174.70</td>
#       <td id="T_4d850_row3_col1" class="data row3 col1" >395.40</td>
#       <td id="T_4d850_row3_col2" class="data row3 col2" >32.95</td>
#       <td id="T_4d850_row3_col3" class="data row3 col3" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_4d850_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_4d850_row4_col0" class="data row4 col0" >1587.67</td>
#       <td id="T_4d850_row4_col1" class="data row4 col1" >288.67</td>
#       <td id="T_4d850_row4_col2" class="data row4 col2" >24.06</td>
#       <td id="T_4d850_row4_col3" class="data row4 col3" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_4d850_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_4d850_row5_col0" class="data row5 col0" >6104.05</td>
#       <td id="T_4d850_row5_col1" class="data row5 col1" >1109.83</td>
#       <td id="T_4d850_row5_col2" class="data row5 col2" >92.49</td>
#       <td id="T_4d850_row5_col3" class="data row5 col3" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_4d850_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_4d850_row6_col0" class="data row6 col0" >3300.00</td>
#       <td id="T_4d850_row6_col1" class="data row6 col1" >600.00</td>
#       <td id="T_4d850_row6_col2" class="data row6 col2" >50.00</td>
#       <td id="T_4d850_row6_col3" class="data row6 col3" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_4d850_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_4d850_row7_col0" class="data row7 col0" >-2000.00</td>
#       <td id="T_4d850_row7_col1" class="data row7 col1" >-363.64</td>
#       <td id="T_4d850_row7_col2" class="data row7 col2" >-30.30</td>
#       <td id="T_4d850_row7_col3" class="data row7 col3" >-0.11</td>
#     </tr>
#     <tr>
#       <th id="T_4d850_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_4d850_row8_col0" class="data row8 col0" >7404.05</td>
#       <td id="T_4d850_row8_col1" class="data row8 col1" >1346.19</td>
#       <td id="T_4d850_row8_col2" class="data row8 col2" >112.18</td>
#       <td id="T_4d850_row8_col3" class="data row8 col3" >0.42</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     52970.00
# Anzahlung [€]                                              15000.00
# davon staatliche Förderung [€]                              5000.00
# Reale Anzahlung [€]                                        10000.00
# Finanzierungszins [%]                                          2.00
# Restwert [€]                                               10000.00
# Versicherungskosten [€/a]                                    459.78
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         16.00
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    37970.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_77bfa_row5_col0, #T_77bfa_row5_col1, #T_77bfa_row5_col2, #T_77bfa_row5_col3 {
#   font-weight: bold;
# }
# #T_77bfa_row6_col0, #T_77bfa_row6_col1, #T_77bfa_row6_col2, #T_77bfa_row6_col3, #T_77bfa_row7_col0, #T_77bfa_row7_col1, #T_77bfa_row7_col2, #T_77bfa_row7_col3 {
#   color: grey;
# }
# #T_77bfa_row8_col0, #T_77bfa_row8_col1, #T_77bfa_row8_col2, #T_77bfa_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_77bfa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77bfa_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_77bfa_row0_col0" class="data row0 col0" >40721.48</td>
#       <td id="T_77bfa_row0_col1" class="data row0 col1" >5817.35</td>
#       <td id="T_77bfa_row0_col2" class="data row0 col2" >484.78</td>
#       <td id="T_77bfa_row0_col3" class="data row0 col3" >0.39</td>
#     </tr>
#     <tr>
#       <th id="T_77bfa_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_77bfa_row1_col0" class="data row1 col0" >3218.46</td>
#       <td id="T_77bfa_row1_col1" class="data row1 col1" >459.78</td>
#       <td id="T_77bfa_row1_col2" class="data row1 col2" >38.32</td>
#       <td id="T_77bfa_row1_col3" class="data row1 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_77bfa_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_77bfa_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_77bfa_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_77bfa_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_77bfa_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_77bfa_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_77bfa_row3_col0" class="data row3 col0" >3500.00</td>
#       <td id="T_77bfa_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_77bfa_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_77bfa_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_77bfa_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_77bfa_row4_col0" class="data row4 col0" >5208.00</td>
#       <td id="T_77bfa_row4_col1" class="data row4 col1" >744.00</td>
#       <td id="T_77bfa_row4_col2" class="data row4 col2" >62.00</td>
#       <td id="T_77bfa_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_77bfa_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_77bfa_row5_col0" class="data row5 col0" >52647.94</td>
#       <td id="T_77bfa_row5_col1" class="data row5 col1" >7521.13</td>
#       <td id="T_77bfa_row5_col2" class="data row5 col2" >626.76</td>
#       <td id="T_77bfa_row5_col3" class="data row5 col3" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_77bfa_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_77bfa_row6_col0" class="data row6 col0" >10000.00</td>
#       <td id="T_77bfa_row6_col1" class="data row6 col1" >1428.57</td>
#       <td id="T_77bfa_row6_col2" class="data row6 col2" >119.05</td>
#       <td id="T_77bfa_row6_col3" class="data row6 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_77bfa_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_77bfa_row7_col0" class="data row7 col0" >-10000.00</td>
#       <td id="T_77bfa_row7_col1" class="data row7 col1" >-1428.57</td>
#       <td id="T_77bfa_row7_col2" class="data row7 col2" >-119.05</td>
#       <td id="T_77bfa_row7_col3" class="data row7 col3" >-0.10</td>
#     </tr>
#     <tr>
#       <th id="T_77bfa_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_77bfa_row8_col0" class="data row8 col0" >52647.94</td>
#       <td id="T_77bfa_row8_col1" class="data row8 col1" >7521.13</td>
#       <td id="T_77bfa_row8_col2" class="data row8 col2" >626.76</td>
#       <td id="T_77bfa_row8_col3" class="data row8 col3" >0.50</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Leasingrate [€]                                              533.00
# Anzahlung [€]                                               8000.00
# davon staatliche Förderung [€]                              5000.00
# Reale Anzahlung [€]                                         3000.00
# Versicherungskosten [€/a]                                    566.90
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         16.00
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 4.00
# Gesamtlaufleistung [km]                                    60000.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_bc67e_row5_col0, #T_bc67e_row5_col1, #T_bc67e_row5_col2, #T_bc67e_row5_col3 {
#   font-weight: bold;
# }
# #T_bc67e_row6_col0, #T_bc67e_row6_col1, #T_bc67e_row6_col2, #T_bc67e_row6_col3, #T_bc67e_row7_col0, #T_bc67e_row7_col1, #T_bc67e_row7_col2, #T_bc67e_row7_col3 {
#   color: grey;
# }
# #T_bc67e_row8_col0, #T_bc67e_row8_col1, #T_bc67e_row8_col2, #T_bc67e_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_bc67e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc67e_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_bc67e_row0_col0" class="data row0 col0" >25584.00</td>
#       <td id="T_bc67e_row0_col1" class="data row0 col1" >6396.00</td>
#       <td id="T_bc67e_row0_col2" class="data row0 col2" >533.00</td>
#       <td id="T_bc67e_row0_col3" class="data row0 col3" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_bc67e_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_bc67e_row1_col0" class="data row1 col0" >2267.60</td>
#       <td id="T_bc67e_row1_col1" class="data row1 col1" >566.90</td>
#       <td id="T_bc67e_row1_col2" class="data row1 col2" >47.24</td>
#       <td id="T_bc67e_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_bc67e_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_bc67e_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_bc67e_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_bc67e_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_bc67e_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_bc67e_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_bc67e_row3_col0" class="data row3 col0" >2000.00</td>
#       <td id="T_bc67e_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_bc67e_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_bc67e_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_bc67e_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_bc67e_row4_col0" class="data row4 col0" >2976.00</td>
#       <td id="T_bc67e_row4_col1" class="data row4 col1" >744.00</td>
#       <td id="T_bc67e_row4_col2" class="data row4 col2" >62.00</td>
#       <td id="T_bc67e_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_bc67e_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_bc67e_row5_col0" class="data row5 col0" >32827.60</td>
#       <td id="T_bc67e_row5_col1" class="data row5 col1" >8206.90</td>
#       <td id="T_bc67e_row5_col2" class="data row5 col2" >683.91</td>
#       <td id="T_bc67e_row5_col3" class="data row5 col3" >0.55</td>
#     </tr>
#     <tr>
#       <th id="T_bc67e_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_bc67e_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_bc67e_row6_col1" class="data row6 col1" >750.00</td>
#       <td id="T_bc67e_row6_col2" class="data row6 col2" >62.50</td>
#       <td id="T_bc67e_row6_col3" class="data row6 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_bc67e_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_bc67e_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_bc67e_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_bc67e_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_bc67e_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_bc67e_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_bc67e_row8_col0" class="data row8 col0" >35827.60</td>
#       <td id="T_bc67e_row8_col1" class="data row8 col1" >8956.90</td>
#       <td id="T_bc67e_row8_col2" class="data row8 col2" >746.41</td>
#       <td id="T_bc67e_row8_col3" class="data row8 col3" >0.60</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     43970.00
# Anzahlung [€]                                              16000.00
# davon staatliche Förderung [€]                              6000.00
# Reale Anzahlung [€]                                        10000.00
# Finanzierungszins [%]                                          2.00
# Restwert [€]                                                8500.00
# Versicherungskosten [€/a]                                    544.00
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         15.00
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    27970.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_6da9f_row5_col0, #T_6da9f_row5_col1, #T_6da9f_row5_col2, #T_6da9f_row5_col3 {
#   font-weight: bold;
# }
# #T_6da9f_row6_col0, #T_6da9f_row6_col1, #T_6da9f_row6_col2, #T_6da9f_row6_col3, #T_6da9f_row7_col0, #T_6da9f_row7_col1, #T_6da9f_row7_col2, #T_6da9f_row7_col3 {
#   color: grey;
# }
# #T_6da9f_row8_col0, #T_6da9f_row8_col1, #T_6da9f_row8_col2, #T_6da9f_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_6da9f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6da9f_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_6da9f_row0_col0" class="data row0 col0" >29996.83</td>
#       <td id="T_6da9f_row0_col1" class="data row0 col1" >4285.26</td>
#       <td id="T_6da9f_row0_col2" class="data row0 col2" >357.11</td>
#       <td id="T_6da9f_row0_col3" class="data row0 col3" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_6da9f_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_6da9f_row1_col0" class="data row1 col0" >3808.00</td>
#       <td id="T_6da9f_row1_col1" class="data row1 col1" >544.00</td>
#       <td id="T_6da9f_row1_col2" class="data row1 col2" >45.33</td>
#       <td id="T_6da9f_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_6da9f_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_6da9f_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_6da9f_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_6da9f_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_6da9f_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6da9f_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_6da9f_row3_col0" class="data row3 col0" >3500.00</td>
#       <td id="T_6da9f_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_6da9f_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_6da9f_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_6da9f_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_6da9f_row4_col0" class="data row4 col0" >4882.50</td>
#       <td id="T_6da9f_row4_col1" class="data row4 col1" >697.50</td>
#       <td id="T_6da9f_row4_col2" class="data row4 col2" >58.12</td>
#       <td id="T_6da9f_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_6da9f_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_6da9f_row5_col0" class="data row5 col0" >42187.33</td>
#       <td id="T_6da9f_row5_col1" class="data row5 col1" >6026.76</td>
#       <td id="T_6da9f_row5_col2" class="data row5 col2" >502.23</td>
#       <td id="T_6da9f_row5_col3" class="data row5 col3" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_6da9f_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_6da9f_row6_col0" class="data row6 col0" >10000.00</td>
#       <td id="T_6da9f_row6_col1" class="data row6 col1" >1428.57</td>
#       <td id="T_6da9f_row6_col2" class="data row6 col2" >119.05</td>
#       <td id="T_6da9f_row6_col3" class="data row6 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_6da9f_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_6da9f_row7_col0" class="data row7 col0" >-8500.00</td>
#       <td id="T_6da9f_row7_col1" class="data row7 col1" >-1214.29</td>
#       <td id="T_6da9f_row7_col2" class="data row7 col2" >-101.19</td>
#       <td id="T_6da9f_row7_col3" class="data row7 col3" >-0.08</td>
#     </tr>
#     <tr>
#       <th id="T_6da9f_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_6da9f_row8_col0" class="data row8 col0" >43687.33</td>
#       <td id="T_6da9f_row8_col1" class="data row8 col1" >6241.05</td>
#       <td id="T_6da9f_row8_col2" class="data row8 col2" >520.09</td>
#       <td id="T_6da9f_row8_col3" class="data row8 col3" >0.42</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Leasingrate [€]                                              360.00
# Anzahlung [€]                                               9000.00
# davon staatliche Förderung [€]                              6000.00
# Reale Anzahlung [€]                                         3000.00
# Versicherungskosten [€/a]                                    673.60
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         15.00
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 4.00
# Gesamtlaufleistung [km]                                    60000.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_4abc5_row5_col0, #T_4abc5_row5_col1, #T_4abc5_row5_col2, #T_4abc5_row5_col3 {
#   font-weight: bold;
# }
# #T_4abc5_row6_col0, #T_4abc5_row6_col1, #T_4abc5_row6_col2, #T_4abc5_row6_col3, #T_4abc5_row7_col0, #T_4abc5_row7_col1, #T_4abc5_row7_col2, #T_4abc5_row7_col3 {
#   color: grey;
# }
# #T_4abc5_row8_col0, #T_4abc5_row8_col1, #T_4abc5_row8_col2, #T_4abc5_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_4abc5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4abc5_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_4abc5_row0_col0" class="data row0 col0" >17280.00</td>
#       <td id="T_4abc5_row0_col1" class="data row0 col1" >4320.00</td>
#       <td id="T_4abc5_row0_col2" class="data row0 col2" >360.00</td>
#       <td id="T_4abc5_row0_col3" class="data row0 col3" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_4abc5_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_4abc5_row1_col0" class="data row1 col0" >2694.40</td>
#       <td id="T_4abc5_row1_col1" class="data row1 col1" >673.60</td>
#       <td id="T_4abc5_row1_col2" class="data row1 col2" >56.13</td>
#       <td id="T_4abc5_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_4abc5_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_4abc5_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_4abc5_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_4abc5_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_4abc5_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_4abc5_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_4abc5_row3_col0" class="data row3 col0" >2000.00</td>
#       <td id="T_4abc5_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_4abc5_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_4abc5_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_4abc5_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_4abc5_row4_col0" class="data row4 col0" >2790.00</td>
#       <td id="T_4abc5_row4_col1" class="data row4 col1" >697.50</td>
#       <td id="T_4abc5_row4_col2" class="data row4 col2" >58.12</td>
#       <td id="T_4abc5_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_4abc5_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_4abc5_row5_col0" class="data row5 col0" >24764.40</td>
#       <td id="T_4abc5_row5_col1" class="data row5 col1" >6191.10</td>
#       <td id="T_4abc5_row5_col2" class="data row5 col2" >515.93</td>
#       <td id="T_4abc5_row5_col3" class="data row5 col3" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_4abc5_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_4abc5_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_4abc5_row6_col1" class="data row6 col1" >750.00</td>
#       <td id="T_4abc5_row6_col2" class="data row6 col2" >62.50</td>
#       <td id="T_4abc5_row6_col3" class="data row6 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_4abc5_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_4abc5_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_4abc5_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_4abc5_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_4abc5_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_4abc5_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_4abc5_row8_col0" class="data row8 col0" >27764.40</td>
#       <td id="T_4abc5_row8_col1" class="data row8 col1" >6941.10</td>
#       <td id="T_4abc5_row8_col2" class="data row8 col2" >578.43</td>
#       <td id="T_4abc5_row8_col3" class="data row8 col3" >0.46</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     30643.19
# Anzahlung [€]                                              10000.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                        10000.00
# Finanzierungszins [%]                                          2.00
# Restwert [€]                                                6000.00
# Versicherungskosten [€/a]                                    510.90
# Steuern [€/a]                                                156.00
# Verbrauch in l/100 km                                          8.00
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    20643.19
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_cb247_row5_col0, #T_cb247_row5_col1, #T_cb247_row5_col2, #T_cb247_row5_col3 {
#   font-weight: bold;
# }
# #T_cb247_row6_col0, #T_cb247_row6_col1, #T_cb247_row6_col2, #T_cb247_row6_col3, #T_cb247_row7_col0, #T_cb247_row7_col1, #T_cb247_row7_col2, #T_cb247_row7_col3 {
#   color: grey;
# }
# #T_cb247_row8_col0, #T_cb247_row8_col1, #T_cb247_row8_col2, #T_cb247_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_cb247_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb247_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_cb247_row0_col0" class="data row0 col0" >22139.09</td>
#       <td id="T_cb247_row0_col1" class="data row0 col1" >3162.73</td>
#       <td id="T_cb247_row0_col2" class="data row0 col2" >263.56</td>
#       <td id="T_cb247_row0_col3" class="data row0 col3" >0.21</td>
#     </tr>
#     <tr>
#       <th id="T_cb247_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_cb247_row1_col0" class="data row1 col0" >3576.30</td>
#       <td id="T_cb247_row1_col1" class="data row1 col1" >510.90</td>
#       <td id="T_cb247_row1_col2" class="data row1 col2" >42.57</td>
#       <td id="T_cb247_row1_col3" class="data row1 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_cb247_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_cb247_row2_col0" class="data row2 col0" >1092.00</td>
#       <td id="T_cb247_row2_col1" class="data row2 col1" >156.00</td>
#       <td id="T_cb247_row2_col2" class="data row2 col2" >13.00</td>
#       <td id="T_cb247_row2_col3" class="data row2 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_cb247_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_cb247_row3_col0" class="data row3 col0" >6300.00</td>
#       <td id="T_cb247_row3_col1" class="data row3 col1" >900.00</td>
#       <td id="T_cb247_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_cb247_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_cb247_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_cb247_row4_col0" class="data row4 col0" >14280.00</td>
#       <td id="T_cb247_row4_col1" class="data row4 col1" >2040.00</td>
#       <td id="T_cb247_row4_col2" class="data row4 col2" >170.00</td>
#       <td id="T_cb247_row4_col3" class="data row4 col3" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_cb247_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_cb247_row5_col0" class="data row5 col0" >47387.39</td>
#       <td id="T_cb247_row5_col1" class="data row5 col1" >6769.63</td>
#       <td id="T_cb247_row5_col2" class="data row5 col2" >564.14</td>
#       <td id="T_cb247_row5_col3" class="data row5 col3" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_cb247_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_cb247_row6_col0" class="data row6 col0" >10000.00</td>
#       <td id="T_cb247_row6_col1" class="data row6 col1" >1428.57</td>
#       <td id="T_cb247_row6_col2" class="data row6 col2" >119.05</td>
#       <td id="T_cb247_row6_col3" class="data row6 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_cb247_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_cb247_row7_col0" class="data row7 col0" >-6000.00</td>
#       <td id="T_cb247_row7_col1" class="data row7 col1" >-857.14</td>
#       <td id="T_cb247_row7_col2" class="data row7 col2" >-71.43</td>
#       <td id="T_cb247_row7_col3" class="data row7 col3" >-0.06</td>
#     </tr>
#     <tr>
#       <th id="T_cb247_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_cb247_row8_col0" class="data row8 col0" >51387.39</td>
#       <td id="T_cb247_row8_col1" class="data row8 col1" >7341.06</td>
#       <td id="T_cb247_row8_col2" class="data row8 col2" >611.75</td>
#       <td id="T_cb247_row8_col3" class="data row8 col3" >0.49</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Leasingrate [€]                                              284.70
# Anzahlung [€]                                               3000.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                         3000.00
# Versicherungskosten [€/a]                                    629.91
# Steuern [€/a]                                                156.00
# Verbrauch in l/100 km                                          8.00
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 3.00
# Gesamtlaufleistung [km]                                    45000.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_76069_row5_col0, #T_76069_row5_col1, #T_76069_row5_col2, #T_76069_row5_col3 {
#   font-weight: bold;
# }
# #T_76069_row6_col0, #T_76069_row6_col1, #T_76069_row6_col2, #T_76069_row6_col3, #T_76069_row7_col0, #T_76069_row7_col1, #T_76069_row7_col2, #T_76069_row7_col3 {
#   color: grey;
# }
# #T_76069_row8_col0, #T_76069_row8_col1, #T_76069_row8_col2, #T_76069_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_76069_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76069_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_76069_row0_col0" class="data row0 col0" >10249.20</td>
#       <td id="T_76069_row0_col1" class="data row0 col1" >3416.40</td>
#       <td id="T_76069_row0_col2" class="data row0 col2" >284.70</td>
#       <td id="T_76069_row0_col3" class="data row0 col3" >0.23</td>
#     </tr>
#     <tr>
#       <th id="T_76069_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_76069_row1_col0" class="data row1 col0" >1889.73</td>
#       <td id="T_76069_row1_col1" class="data row1 col1" >629.91</td>
#       <td id="T_76069_row1_col2" class="data row1 col2" >52.49</td>
#       <td id="T_76069_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_76069_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_76069_row2_col0" class="data row2 col0" >468.00</td>
#       <td id="T_76069_row2_col1" class="data row2 col1" >156.00</td>
#       <td id="T_76069_row2_col2" class="data row2 col2" >13.00</td>
#       <td id="T_76069_row2_col3" class="data row2 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_76069_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_76069_row3_col0" class="data row3 col0" >2700.00</td>
#       <td id="T_76069_row3_col1" class="data row3 col1" >900.00</td>
#       <td id="T_76069_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_76069_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_76069_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_76069_row4_col0" class="data row4 col0" >6120.00</td>
#       <td id="T_76069_row4_col1" class="data row4 col1" >2040.00</td>
#       <td id="T_76069_row4_col2" class="data row4 col2" >170.00</td>
#       <td id="T_76069_row4_col3" class="data row4 col3" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_76069_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_76069_row5_col0" class="data row5 col0" >21426.93</td>
#       <td id="T_76069_row5_col1" class="data row5 col1" >7142.31</td>
#       <td id="T_76069_row5_col2" class="data row5 col2" >595.19</td>
#       <td id="T_76069_row5_col3" class="data row5 col3" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_76069_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_76069_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_76069_row6_col1" class="data row6 col1" >1000.00</td>
#       <td id="T_76069_row6_col2" class="data row6 col2" >83.33</td>
#       <td id="T_76069_row6_col3" class="data row6 col3" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_76069_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_76069_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_76069_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_76069_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_76069_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_76069_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_76069_row8_col0" class="data row8 col0" >24426.93</td>
#       <td id="T_76069_row8_col1" class="data row8 col1" >8142.31</td>
#       <td id="T_76069_row8_col2" class="data row8 col2" >678.53</td>
#       <td id="T_76069_row8_col3" class="data row8 col3" >0.54</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     25209.43
# Anzahlung [€]                                              10000.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                        10000.00
# Finanzierungszins [%]                                          2.00
# Restwert [€]                                                5000.00
# Versicherungskosten [€/a]                                    325.99
# Steuern [€/a]                                                107.00
# Verbrauch in l/100 km                                          7.00
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    15209.43
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_df89e_row5_col0, #T_df89e_row5_col1, #T_df89e_row5_col2, #T_df89e_row5_col3 {
#   font-weight: bold;
# }
# #T_df89e_row6_col0, #T_df89e_row6_col1, #T_df89e_row6_col2, #T_df89e_row6_col3, #T_df89e_row7_col0, #T_df89e_row7_col1, #T_df89e_row7_col2, #T_df89e_row7_col3 {
#   color: grey;
# }
# #T_df89e_row8_col0, #T_df89e_row8_col1, #T_df89e_row8_col2, #T_df89e_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_df89e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df89e_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_df89e_row0_col0" class="data row0 col0" >16311.57</td>
#       <td id="T_df89e_row0_col1" class="data row0 col1" >2330.22</td>
#       <td id="T_df89e_row0_col2" class="data row0 col2" >194.19</td>
#       <td id="T_df89e_row0_col3" class="data row0 col3" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_df89e_level0_row1" class="row_heading level0 row1" >Versicherung</th>
# ...
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    20230.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_6fdda_row5_col0, #T_6fdda_row5_col1, #T_6fdda_row5_col2, #T_6fdda_row5_col3 {
#   font-weight: bold;
# }
# #T_6fdda_row6_col0, #T_6fdda_row6_col1, #T_6fdda_row6_col2, #T_6fdda_row6_col3, #T_6fdda_row7_col0, #T_6fdda_row7_col1, #T_6fdda_row7_col2, #T_6fdda_row7_col3 {
#   color: grey;
# }
# #T_6fdda_row8_col0, #T_6fdda_row8_col1, #T_6fdda_row8_col2, #T_6fdda_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_6fdda_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fdda_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_6fdda_row0_col0" class="data row0 col0" >21695.96</td>
#       <td id="T_6fdda_row0_col1" class="data row0 col1" >3099.42</td>
#       <td id="T_6fdda_row0_col2" class="data row0 col2" >258.29</td>
#       <td id="T_6fdda_row0_col3" class="data row0 col3" >0.21</td>
#     </tr>
#     <tr>
#       <th id="T_6fdda_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_6fdda_row1_col0" class="data row1 col0" >2459.45</td>
#       <td id="T_6fdda_row1_col1" class="data row1 col1" >351.35</td>
#       <td id="T_6fdda_row1_col2" class="data row1 col2" >29.28</td>
#       <td id="T_6fdda_row1_col3" class="data row1 col3" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_6fdda_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_6fdda_row2_col0" class="data row2 col0" >686.00</td>
#       <td id="T_6fdda_row2_col1" class="data row2 col1" >98.00</td>
#       <td id="T_6fdda_row2_col2" class="data row2 col2" >8.17</td>
#       <td id="T_6fdda_row2_col3" class="data row2 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_6fdda_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_6fdda_row3_col0" class="data row3 col0" >6300.00</td>
#       <td id="T_6fdda_row3_col1" class="data row3 col1" >900.00</td>
#       <td id="T_6fdda_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_6fdda_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_6fdda_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_6fdda_row4_col0" class="data row4 col0" >13387.50</td>
#       <td id="T_6fdda_row4_col1" class="data row4 col1" >1912.50</td>
#       <td id="T_6fdda_row4_col2" class="data row4 col2" >159.38</td>
#       <td id="T_6fdda_row4_col3" class="data row4 col3" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_6fdda_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_6fdda_row5_col0" class="data row5 col0" >44528.91</td>
#       <td id="T_6fdda_row5_col1" class="data row5 col1" >6361.27</td>
#       <td id="T_6fdda_row5_col2" class="data row5 col2" >530.11</td>
#       <td id="T_6fdda_row5_col3" class="data row5 col3" >0.42</td>
#     </tr>
#     <tr>
#       <th id="T_6fdda_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_6fdda_row6_col0" class="data row6 col0" >10000.00</td>
#       <td id="T_6fdda_row6_col1" class="data row6 col1" >1428.57</td>
#       <td id="T_6fdda_row6_col2" class="data row6 col2" >119.05</td>
#       <td id="T_6fdda_row6_col3" class="data row6 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_6fdda_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_6fdda_row7_col0" class="data row7 col0" >-6000.00</td>
#       <td id="T_6fdda_row7_col1" class="data row7 col1" >-857.14</td>
#       <td id="T_6fdda_row7_col2" class="data row7 col2" >-71.43</td>
#       <td id="T_6fdda_row7_col3" class="data row7 col3" >-0.06</td>
#     </tr>
#     <tr>
#       <th id="T_6fdda_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_6fdda_row8_col0" class="data row8 col0" >48528.91</td>
#       <td id="T_6fdda_row8_col1" class="data row8 col1" >6932.70</td>
#       <td id="T_6fdda_row8_col2" class="data row8 col2" >577.73</td>
#       <td id="T_6fdda_row8_col3" class="data row8 col3" >0.46</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Leasingrate [€]                                              320.78
# Anzahlung [€]                                               3000.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                         3000.00
# Versicherungskosten [€/a]                                    423.07
# Steuern [€/a]                                                 98.00
# Verbrauch in l/100 km                                          7.50
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 3.00
# Gesamtlaufleistung [km]                                    45000.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_bbc26_row5_col0, #T_bbc26_row5_col1, #T_bbc26_row5_col2, #T_bbc26_row5_col3 {
#   font-weight: bold;
# }
# #T_bbc26_row6_col0, #T_bbc26_row6_col1, #T_bbc26_row6_col2, #T_bbc26_row6_col3, #T_bbc26_row7_col0, #T_bbc26_row7_col1, #T_bbc26_row7_col2, #T_bbc26_row7_col3 {
#   color: grey;
# }
# #T_bbc26_row8_col0, #T_bbc26_row8_col1, #T_bbc26_row8_col2, #T_bbc26_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_bbc26_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bbc26_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_bbc26_row0_col0" class="data row0 col0" >11547.98</td>
#       <td id="T_bbc26_row0_col1" class="data row0 col1" >3849.33</td>
#       <td id="T_bbc26_row0_col2" class="data row0 col2" >320.78</td>
#       <td id="T_bbc26_row0_col3" class="data row0 col3" >0.26</td>
#     </tr>
#     <tr>
#       <th id="T_bbc26_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_bbc26_row1_col0" class="data row1 col0" >1269.21</td>
#       <td id="T_bbc26_row1_col1" class="data row1 col1" >423.07</td>
#       <td id="T_bbc26_row1_col2" class="data row1 col2" >35.26</td>
#       <td id="T_bbc26_row1_col3" class="data row1 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_bbc26_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_bbc26_row2_col0" class="data row2 col0" >294.00</td>
#       <td id="T_bbc26_row2_col1" class="data row2 col1" >98.00</td>
#       <td id="T_bbc26_row2_col2" class="data row2 col2" >8.17</td>
#       <td id="T_bbc26_row2_col3" class="data row2 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_bbc26_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_bbc26_row3_col0" class="data row3 col0" >2700.00</td>
#       <td id="T_bbc26_row3_col1" class="data row3 col1" >900.00</td>
#       <td id="T_bbc26_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_bbc26_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_bbc26_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_bbc26_row4_col0" class="data row4 col0" >5737.50</td>
#       <td id="T_bbc26_row4_col1" class="data row4 col1" >1912.50</td>
#       <td id="T_bbc26_row4_col2" class="data row4 col2" >159.38</td>
#       <td id="T_bbc26_row4_col3" class="data row4 col3" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_bbc26_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_bbc26_row5_col0" class="data row5 col0" >21548.69</td>
#       <td id="T_bbc26_row5_col1" class="data row5 col1" >7182.90</td>
#       <td id="T_bbc26_row5_col2" class="data row5 col2" >598.57</td>
#       <td id="T_bbc26_row5_col3" class="data row5 col3" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_bbc26_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_bbc26_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_bbc26_row6_col1" class="data row6 col1" >1000.00</td>
#       <td id="T_bbc26_row6_col2" class="data row6 col2" >83.33</td>
#       <td id="T_bbc26_row6_col3" class="data row6 col3" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_bbc26_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_bbc26_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_bbc26_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_bbc26_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_bbc26_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_bbc26_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_bbc26_row8_col0" class="data row8 col0" >24548.69</td>
#       <td id="T_bbc26_row8_col1" class="data row8 col1" >8182.90</td>
#       <td id="T_bbc26_row8_col2" class="data row8 col2" >681.91</td>
#       <td id="T_bbc26_row8_col3" class="data row8 col3" >0.55</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     42755.83
# Anzahlung [€]                                              10000.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                        10000.00
# Finanzierungszins [%]                                          3.00
# Restwert [€]                                                8000.00
# Versicherungskosten [€/a]                                    678.24
# Steuern [€/a]                                                136.00
# Verbrauch in l/100 km                                          7.00
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    32755.83
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_e843f_row5_col0, #T_e843f_row5_col1, #T_e843f_row5_col2, #T_e843f_row5_col3 {
#   font-weight: bold;
# }
# #T_e843f_row6_col0, #T_e843f_row6_col1, #T_e843f_row6_col2, #T_e843f_row6_col3, #T_e843f_row7_col0, #T_e843f_row7_col1, #T_e843f_row7_col2, #T_e843f_row7_col3 {
#   color: grey;
# }
# #T_e843f_row8_col0, #T_e843f_row8_col1, #T_e843f_row8_col2, #T_e843f_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_e843f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e843f_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_e843f_row0_col0" class="data row0 col0" >36356.26</td>
#       <td id="T_e843f_row0_col1" class="data row0 col1" >5193.75</td>
#       <td id="T_e843f_row0_col2" class="data row0 col2" >432.81</td>
#       <td id="T_e843f_row0_col3" class="data row0 col3" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_e843f_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_e843f_row1_col0" class="data row1 col0" >4747.68</td>
#       <td id="T_e843f_row1_col1" class="data row1 col1" >678.24</td>
#       <td id="T_e843f_row1_col2" class="data row1 col2" >56.52</td>
#       <td id="T_e843f_row1_col3" class="data row1 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_e843f_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_e843f_row2_col0" class="data row2 col0" >952.00</td>
#       <td id="T_e843f_row2_col1" class="data row2 col1" >136.00</td>
#       <td id="T_e843f_row2_col2" class="data row2 col2" >11.33</td>
#       <td id="T_e843f_row2_col3" class="data row2 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_e843f_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_e843f_row3_col0" class="data row3 col0" >6300.00</td>
#       <td id="T_e843f_row3_col1" class="data row3 col1" >900.00</td>
#       <td id="T_e843f_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_e843f_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_e843f_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_e843f_row4_col0" class="data row4 col0" >12495.00</td>
#       <td id="T_e843f_row4_col1" class="data row4 col1" >1785.00</td>
#       <td id="T_e843f_row4_col2" class="data row4 col2" >148.75</td>
#       <td id="T_e843f_row4_col3" class="data row4 col3" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_e843f_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_e843f_row5_col0" class="data row5 col0" >60850.94</td>
#       <td id="T_e843f_row5_col1" class="data row5 col1" >8692.99</td>
#       <td id="T_e843f_row5_col2" class="data row5 col2" >724.42</td>
#       <td id="T_e843f_row5_col3" class="data row5 col3" >0.58</td>
#     </tr>
#     <tr>
#       <th id="T_e843f_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_e843f_row6_col0" class="data row6 col0" >10000.00</td>
#       <td id="T_e843f_row6_col1" class="data row6 col1" >1428.57</td>
#       <td id="T_e843f_row6_col2" class="data row6 col2" >119.05</td>
#       <td id="T_e843f_row6_col3" class="data row6 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_e843f_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_e843f_row7_col0" class="data row7 col0" >-8000.00</td>
#       <td id="T_e843f_row7_col1" class="data row7 col1" >-1142.86</td>
#       <td id="T_e843f_row7_col2" class="data row7 col2" >-95.24</td>
#       <td id="T_e843f_row7_col3" class="data row7 col3" >-0.08</td>
#     </tr>
#     <tr>
#       <th id="T_e843f_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_e843f_row8_col0" class="data row8 col0" >62850.94</td>
#       <td id="T_e843f_row8_col1" class="data row8 col1" >8978.71</td>
#       <td id="T_e843f_row8_col2" class="data row8 col2" >748.23</td>
#       <td id="T_e843f_row8_col3" class="data row8 col3" >0.60</td>
#     </tr>
#   </tbody>
# </table>

# %%
brk = 8

overview_path_1 = 'images/overview1.png'
overview_path_2 = 'images/overview2.png'

# sum_row = pd.IndexSlice[calc_values.index[(calc_values.index == "Summe") | (calc_values.index == "Gesamtsumme")], :]

dfi.export(overview.iloc[:, 0:brk ].style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2), overview_path_1)
dfi.export(overview.iloc[:, brk: ].style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2), overview_path_2)

display(overview.iloc[:, 0:brk ].style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2))
display(overview.iloc[:, brk: ].style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2))

latex = r"""%s

\pagebreak

\onecolumn
\null
\vfill 
\includegraphics[height=6cm]{%s}

\null
\vspace{0.8cm}
\includegraphics[height=6cm]{%s}
\vfill 
""" % (latex,
      overview_path_1,
      overview_path_2)
# Out:
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/58010651.py:9: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2).set_precision(2), overview_path_1)
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/58010651.py:11: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2).set_precision(2), overview_path_2)
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/58010651.py:14: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2).set_precision(2))
# <style type="text/css">
# #T_8e2d1_row5_col0, #T_8e2d1_row5_col1, #T_8e2d1_row5_col2, #T_8e2d1_row5_col3, #T_8e2d1_row5_col4, #T_8e2d1_row5_col5, #T_8e2d1_row5_col6, #T_8e2d1_row5_col7 {
#   font-weight: bold;
# }
# #T_8e2d1_row6_col0, #T_8e2d1_row6_col1, #T_8e2d1_row6_col2, #T_8e2d1_row6_col3, #T_8e2d1_row6_col4, #T_8e2d1_row6_col5, #T_8e2d1_row6_col6, #T_8e2d1_row6_col7, #T_8e2d1_row7_col0, #T_8e2d1_row7_col1, #T_8e2d1_row7_col2, #T_8e2d1_row7_col3, #T_8e2d1_row7_col4, #T_8e2d1_row7_col5, #T_8e2d1_row7_col6, #T_8e2d1_row7_col7 {
#   color: grey;
# }
# #T_8e2d1_row8_col0, #T_8e2d1_row8_col1, #T_8e2d1_row8_col2, #T_8e2d1_row8_col3, #T_8e2d1_row8_col4, #T_8e2d1_row8_col5, #T_8e2d1_row8_col6, #T_8e2d1_row8_col7 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_8e2d1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >BMW 318d 2011 Kaufen</th>
#       <th class="col_heading level0 col1" >Nissan Micra 2010 Kaufen</th>
#       <th class="col_heading level0 col2" >Tesla Model Y Kaufen</th>
#       <th class="col_heading level0 col3" >Tesla Model Y Leasing</th>
#       <th class="col_heading level0 col4" >Tesla Model 3 Kaufen</th>
#       <th class="col_heading level0 col5" >Tesla Model 3 Leasing</th>
#       <th class="col_heading level0 col6" >Mazda 6 Kaufen</th>
#       <th class="col_heading level0 col7" >Mazda 6 Leasing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e2d1_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_8e2d1_row0_col0" class="data row0 col0" >205.63</td>
#       <td id="T_8e2d1_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_8e2d1_row0_col2" class="data row0 col2" >484.78</td>
#       <td id="T_8e2d1_row0_col3" class="data row0 col3" >533.00</td>
#       <td id="T_8e2d1_row0_col4" class="data row0 col4" >357.11</td>
#       <td id="T_8e2d1_row0_col5" class="data row0 col5" >360.00</td>
#       <td id="T_8e2d1_row0_col6" class="data row0 col6" >263.56</td>
#       <td id="T_8e2d1_row0_col7" class="data row0 col7" >284.70</td>
#     </tr>
#     <tr>
#       <th id="T_8e2d1_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_8e2d1_row1_col0" class="data row1 col0" >64.58</td>
#       <td id="T_8e2d1_row1_col1" class="data row1 col1" >30.15</td>
#       <td id="T_8e2d1_row1_col2" class="data row1 col2" >38.32</td>
#       <td id="T_8e2d1_row1_col3" class="data row1 col3" >47.24</td>
#       <td id="T_8e2d1_row1_col4" class="data row1 col4" >45.33</td>
#       <td id="T_8e2d1_row1_col5" class="data row1 col5" >56.13</td>
#       <td id="T_8e2d1_row1_col6" class="data row1 col6" >42.57</td>
#       <td id="T_8e2d1_row1_col7" class="data row1 col7" >52.49</td>
#     </tr>
#     <tr>
#       <th id="T_8e2d1_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_8e2d1_row2_col0" class="data row2 col0" >19.17</td>
#       <td id="T_8e2d1_row2_col1" class="data row2 col1" >5.33</td>
#       <td id="T_8e2d1_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_8e2d1_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_8e2d1_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_8e2d1_row2_col5" class="data row2 col5" >0.00</td>
#       <td id="T_8e2d1_row2_col6" class="data row2 col6" >13.00</td>
#       <td id="T_8e2d1_row2_col7" class="data row2 col7" >13.00</td>
#     </tr>
#     <tr>
#       <th id="T_8e2d1_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_8e2d1_row3_col0" class="data row3 col0" >168.03</td>
#       <td id="T_8e2d1_row3_col1" class="data row3 col1" >32.95</td>
#       <td id="T_8e2d1_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_8e2d1_row3_col3" class="data row3 col3" >41.67</td>
#       <td id="T_8e2d1_row3_col4" class="data row3 col4" >41.67</td>
#       <td id="T_8e2d1_row3_col5" class="data row3 col5" >41.67</td>
#       <td id="T_8e2d1_row3_col6" class="data row3 col6" >75.00</td>
#       <td id="T_8e2d1_row3_col7" class="data row3 col7" >75.00</td>
#     </tr>
#     <tr>
#       <th id="T_8e2d1_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_8e2d1_row4_col0" class="data row4 col0" >164.50</td>
#       <td id="T_8e2d1_row4_col1" class="data row4 col1" >24.06</td>
#       <td id="T_8e2d1_row4_col2" class="data row4 col2" >62.00</td>
#       <td id="T_8e2d1_row4_col3" class="data row4 col3" >62.00</td>
#       <td id="T_8e2d1_row4_col4" class="data row4 col4" >58.12</td>
#       <td id="T_8e2d1_row4_col5" class="data row4 col5" >58.12</td>
#       <td id="T_8e2d1_row4_col6" class="data row4 col6" >170.00</td>
#       <td id="T_8e2d1_row4_col7" class="data row4 col7" >170.00</td>
#     </tr>
#     <tr>
#       <th id="T_8e2d1_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_8e2d1_row5_col0" class="data row5 col0" >621.91</td>
#       <td id="T_8e2d1_row5_col1" class="data row5 col1" >92.49</td>
#       <td id="T_8e2d1_row5_col2" class="data row5 col2" >626.76</td>
#       <td id="T_8e2d1_row5_col3" class="data row5 col3" >683.91</td>
#       <td id="T_8e2d1_row5_col4" class="data row5 col4" >502.23</td>
#       <td id="T_8e2d1_row5_col5" class="data row5 col5" >515.93</td>
#       <td id="T_8e2d1_row5_col6" class="data row5 col6" >564.14</td>
#       <td id="T_8e2d1_row5_col7" class="data row5 col7" >595.19</td>
#     </tr>
#     <tr>
#       <th id="T_8e2d1_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_8e2d1_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_8e2d1_row6_col1" class="data row6 col1" >50.00</td>
#       <td id="T_8e2d1_row6_col2" class="data row6 col2" >119.05</td>
#       <td id="T_8e2d1_row6_col3" class="data row6 col3" >62.50</td>
#       <td id="T_8e2d1_row6_col4" class="data row6 col4" >119.05</td>
#       <td id="T_8e2d1_row6_col5" class="data row6 col5" >62.50</td>
#       <td id="T_8e2d1_row6_col6" class="data row6 col6" >119.05</td>
#       <td id="T_8e2d1_row6_col7" class="data row6 col7" >83.33</td>
#     </tr>
#     <tr>
#       <th id="T_8e2d1_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_8e2d1_row7_col0" class="data row7 col0" >-36.50</td>
#       <td id="T_8e2d1_row7_col1" class="data row7 col1" >-30.30</td>
#       <td id="T_8e2d1_row7_col2" class="data row7 col2" >-119.05</td>
#       <td id="T_8e2d1_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_8e2d1_row7_col4" class="data row7 col4" >-101.19</td>
#       <td id="T_8e2d1_row7_col5" class="data row7 col5" >0.00</td>
#       <td id="T_8e2d1_row7_col6" class="data row7 col6" >-71.43</td>
#       <td id="T_8e2d1_row7_col7" class="data row7 col7" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_8e2d1_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_8e2d1_row8_col0" class="data row8 col0" >585.41</td>
#       <td id="T_8e2d1_row8_col1" class="data row8 col1" >112.18</td>
#       <td id="T_8e2d1_row8_col2" class="data row8 col2" >626.76</td>
#       <td id="T_8e2d1_row8_col3" class="data row8 col3" >746.41</td>
#       <td id="T_8e2d1_row8_col4" class="data row8 col4" >520.09</td>
#       <td id="T_8e2d1_row8_col5" class="data row8 col5" >578.43</td>
#       <td id="T_8e2d1_row8_col6" class="data row8 col6" >611.75</td>
#       <td id="T_8e2d1_row8_col7" class="data row8 col7" >678.53</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_16644/58010651.py:16: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2).set_precision(2))
# <style type="text/css">
# #T_89db9_row5_col0, #T_89db9_row5_col1, #T_89db9_row5_col2, #T_89db9_row5_col3, #T_89db9_row5_col4 {
#   font-weight: bold;
# }
# #T_89db9_row6_col0, #T_89db9_row6_col1, #T_89db9_row6_col2, #T_89db9_row6_col3, #T_89db9_row6_col4, #T_89db9_row7_col0, #T_89db9_row7_col1, #T_89db9_row7_col2, #T_89db9_row7_col3, #T_89db9_row7_col4 {
#   color: grey;
# }
# #T_89db9_row8_col0, #T_89db9_row8_col1, #T_89db9_row8_col2, #T_89db9_row8_col3, #T_89db9_row8_col4 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_89db9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Kia ceed Kaufen</th>
#       <th class="col_heading level0 col1" >Kia ceed Leasing</th>
#       <th class="col_heading level0 col2" >VW Passat Kaufen</th>
#       <th class="col_heading level0 col3" >VW Passat Leasing</th>
#       <th class="col_heading level0 col4" >Mercedes C 180 Kaufen</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89db9_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_89db9_row0_col0" class="data row0 col0" >194.19</td>
#       <td id="T_89db9_row0_col1" class="data row0 col1" >227.42</td>
#       <td id="T_89db9_row0_col2" class="data row0 col2" >258.29</td>
#       <td id="T_89db9_row0_col3" class="data row0 col3" >320.78</td>
#       <td id="T_89db9_row0_col4" class="data row0 col4" >432.81</td>
#     </tr>
#     <tr>
#       <th id="T_89db9_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_89db9_row1_col0" class="data row1 col0" >27.17</td>
#       <td id="T_89db9_row1_col1" class="data row1 col1" >32.96</td>
#       <td id="T_89db9_row1_col2" class="data row1 col2" >29.28</td>
#       <td id="T_89db9_row1_col3" class="data row1 col3" >35.26</td>
#       <td id="T_89db9_row1_col4" class="data row1 col4" >56.52</td>
#     </tr>
#     <tr>
#       <th id="T_89db9_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_89db9_row2_col0" class="data row2 col0" >8.92</td>
#       <td id="T_89db9_row2_col1" class="data row2 col1" >8.92</td>
#       <td id="T_89db9_row2_col2" class="data row2 col2" >8.17</td>
#       <td id="T_89db9_row2_col3" class="data row2 col3" >8.17</td>
#       <td id="T_89db9_row2_col4" class="data row2 col4" >11.33</td>
#     </tr>
#     <tr>
#       <th id="T_89db9_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_89db9_row3_col0" class="data row3 col0" >75.00</td>
#       <td id="T_89db9_row3_col1" class="data row3 col1" >75.00</td>
#       <td id="T_89db9_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_89db9_row3_col3" class="data row3 col3" >75.00</td>
#       <td id="T_89db9_row3_col4" class="data row3 col4" >75.00</td>
#     </tr>
#     <tr>
#       <th id="T_89db9_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_89db9_row4_col0" class="data row4 col0" >148.75</td>
#       <td id="T_89db9_row4_col1" class="data row4 col1" >148.75</td>
#       <td id="T_89db9_row4_col2" class="data row4 col2" >159.38</td>
#       <td id="T_89db9_row4_col3" class="data row4 col3" >159.38</td>
#       <td id="T_89db9_row4_col4" class="data row4 col4" >148.75</td>
#     </tr>
#     <tr>
#       <th id="T_89db9_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_89db9_row5_col0" class="data row5 col0" >454.02</td>
#       <td id="T_89db9_row5_col1" class="data row5 col1" >493.05</td>
#       <td id="T_89db9_row5_col2" class="data row5 col2" >530.11</td>
#       <td id="T_89db9_row5_col3" class="data row5 col3" >598.57</td>
#       <td id="T_89db9_row5_col4" class="data row5 col4" >724.42</td>
#     </tr>
#     <tr>
#       <th id="T_89db9_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_89db9_row6_col0" class="data row6 col0" >119.05</td>
#       <td id="T_89db9_row6_col1" class="data row6 col1" >83.33</td>
#       <td id="T_89db9_row6_col2" class="data row6 col2" >119.05</td>
#       <td id="T_89db9_row6_col3" class="data row6 col3" >83.33</td>
#       <td id="T_89db9_row6_col4" class="data row6 col4" >119.05</td>
#     </tr>
#     <tr>
#       <th id="T_89db9_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_89db9_row7_col0" class="data row7 col0" >-59.52</td>
#       <td id="T_89db9_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_89db9_row7_col2" class="data row7 col2" >-71.43</td>
#       <td id="T_89db9_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_89db9_row7_col4" class="data row7 col4" >-95.24</td>
#     </tr>
#     <tr>
#       <th id="T_89db9_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_89db9_row8_col0" class="data row8 col0" >513.54</td>
#       <td id="T_89db9_row8_col1" class="data row8 col1" >576.38</td>
#       <td id="T_89db9_row8_col2" class="data row8 col2" >577.73</td>
#       <td id="T_89db9_row8_col3" class="data row8 col3" >681.91</td>
#       <td id="T_89db9_row8_col4" class="data row8 col4" >748.23</td>
#     </tr>
#   </tbody>
# </table>

# %%
tex_file = 'report_l.tex'
with open(tex_file, 'w') as fid:
    fid.write(r"""
\documentclass[landscape, DIV=99, 14pt]{scrartcl}

\renewcommand*{\familydefault}{\sfdefault}

\RequirePackage{graphicx}
\RequirePackage{hyperref}
\RequirePackage[gen]{eurosym}

\begin{document}

\twocolumn
\section*{Zusammenfassung BMW Kosten}
\null
\vspace{1cm}
\begin{center}
%%                           trim={<left> <lower> <right> <upper>}
\includegraphics[width=10cm, trim={4cm 0 4cm 5cm}]{images/kosten_verteilung.png}
\end{center}

\includegraphics[width=1.4\columnwidth]{images/kosten_maximus.png}

\pagebreak

\begin{itemize}
    \item Wertverlust
    \begin{itemize}
        \item Kaufpreis minus Verkaufspreis
        \item Kraftstoffe
        \item Summe aller Tankstellenbesuche
    \end{itemize}
    \item Wartung und Reparatur
    \begin{itemize}
        \item Regul\"are Wartungsarbeiten (\"Olwechsel, etc)
        \item Reparaturen Aufgrund technischer Defekte
        \item Unfallsch\"aden
    \end{itemize}
    \item Versicherung
    \begin{itemize}
        \item J\"ahrlicher Versicherungsbeitrag
        \item Mobilit\"ats-Service
    \end{itemize}
    \item Steuern
    \begin{itemize}
            \item J\"ahrliche KFZ-Steuer
    \end{itemize}
\end{itemize}

# %s

\end{document}
""" % (latex))

# %%
os.system('pdflatex.exe .\%s' % (tex_file))
os.system('pdflatex.exe .\%s' % (tex_file))
os.system('start .\%spdf' % (tex_file[:-3]))
# Out:
# 0
