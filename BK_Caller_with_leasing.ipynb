# %%
from bk import Operating_Cost
import pandas as pd
import dataframe_image as dfi
from slugify import slugify
from pathlib import Path

overview = pd.DataFrame()
overview.name='Monatliche Kosten im Verlgeich'

def df_style(val):
    # return "font-weight: bold; background: yellow"
    return "font-weight: bold;"

def light_style(val):
    return "color: grey"

# %%
#d_0 = 1.52  # Aktueller Dieselpreis 3.1.2022: 1.52
b_0 = 1.70  # Aktueller Benzinpreis 3.1.2022: 1.56
e_0 = 0.31  # Aktueller Strompreis 3.1.2022: 0.31 €/kWh

cars = []          
cars.append({'label': 'Tesla Model Y',
             'acquisition_cost': 52970,
             'government_funding': 5000,
             'down_payment': 15000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 10000,
             'insurance_yearly': 459.78,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-y.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': True  # else lease
})             
cars.append({'label': 'Tesla Model Y',
             'instalment': 533,
             'government_funding': 5000,
             'down_payment': 8000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 9000,
             'insurance_yearly': 566.90,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 4.0,   
             'image_url': 'cars/tesla-model-y-leasing.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': False  # else lease
})             
cars.append({'label': 'Tesla Model 3',
             'acquisition_cost': 43970,
             'government_funding': 6000,
             'down_payment': 16000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 8500,
             'insurance_yearly': 544,
             'taxes_yearly': 0,
             'consumption': 15.,
             'power': 325,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-3.jpg',
             'web_url': 'https://www.tesla.com/de_de/model3/design#overview',
             'buy': True  # else lease
})          
cars.append({'label': 'Tesla Model 3',
             'instalment': 360,
             'government_funding': 6000,
             'down_payment': 9000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 8500,
             'insurance_yearly': 673.60,
             'taxes_yearly': 0,
             'consumption': 15.,
             'power': 325,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 4.0,   
             'image_url': 'cars/tesla-model-3-leasing.jpg',
             'web_url': 'https://www.tesla.com/de_de/model3/design#overview',
             'buy': False  # else lease
})
cars.append({'label': 'Mazda 6',
             'acquisition_cost': 30643.19,
             'government_funding': 0,
             'down_payment': 10000,
             'car_year': 2022,
             'delivery_time': 20,
             'interest_rate': 2.,
             'rest_value': 6000,
             'insurance_yearly': 510.90,
             'taxes_yearly': 156,
             'consumption': 8.,
             'power': 192,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,  
             'image_url': 'cars/mazda-6-neu.png',
             'web_url': 'https://konfigurator.meinauto.de/mazda/neuwagen/48-6/angebote/6-kombi/konfigurator/#!/extras/exclusive-line/8846370/10,11/private/65352-5416-204698/984/61c9aa657e74c/cash-purchase/32545--287374/48,0,10000,0,0,0,0,0,',
             'buy': True  # else lease
})
cars.append({'label': 'Mazda 6',
             'instalment': 284.70,
             'government_funding': 0,
             'down_payment': 3000,
             'car_year': 2022,
             'delivery_time': 60,
             'interest_rate': 3.,
             'rest_value': 3000,
             'insurance_yearly': 629.91,
             'taxes_yearly': 156,
             'consumption': 8.,
             'power': 192,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3,  
             'image_url': 'cars/mazda-6-leasing.png',
             'web_url': 'https://konfigurator.meinauto.de/mazda/neuwagen/48-6/angebote/6-kombi/konfigurator/#!/extras/exclusive-line/8846370/10,11,15/private/65352-5416-204698/984/61c9aa657e74c/leasing/16040--249432/36,3000,15000,0,0,0,0,0,',
             'buy': False  # else lease
})
cars.append({'label': 'Kia ceed',
             'acquisition_cost': 25209.43,
             'government_funding': 0,
             'down_payment': 10000,
             'car_year': 2022,
             'delivery_time': 52,
             'interest_rate': 3.,
             'rest_value': 5000,
             'insurance_yearly': 325.99,
             'taxes_yearly': 107,
             'consumption': 7.,
             'power': 160,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,
             'image_url': 'cars/kia-ceed-sportswagon.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/extras/spirit/8865371/3,11,27/private/109347-4167-291321/1321/61d21ce73c5db/cash-purchase/109348-8088-291322/48,0,10000,0,0,0,0,0,',
             'buy': True  # else lease
})
cars.append({'label': 'Kia ceed',
             'instalment': 227.42,
             'government_funding': 0,
             'down_payment': 3000,
             'car_year': 2022,
             'delivery_time': 52,
             'interest_rate': 3.,
             'rest_value': 3000,
             'insurance_yearly': 395.58,
             'taxes_yearly': 107,
             'consumption': 7.,
             'power': 160,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3.0,
             'image_url': 'cars/kia-ceed-sportswagon-leasing.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/extras/spirit/8865371/3,11,27/private/109347-4167-291321/1321/61d21ce73c5db/leasing/109348-8088-291322/36,3000,15000,0,0,0,0,0,',
             'buy': False  # else lease
})
for car in cars:
    if car['buy']:
        factor = .5**(car['holding_period']/3)
        car['rest_value_thumb_value'] = r'Restwert nach Faustformel (Neupreis $\times$ %.1f\%%): %.2f \euro{}' % \
        (factor*100, car['acquisition_cost'] * factor)
    else:
        car['rest_value_thumb_value'] = r'Kein Restwert, da Leasingfahrzeug'

# %%
latex = ''
for car in cars:
    if car['buy']:
        label=car['label'] + ' Kaufen'
        bk_inputs = {key: car[key] for key in ['acquisition_cost', 
                                               'government_funding',
                                               'down_payment',
                                               'holding_period',
                                               'millage_yearly',
                                               'consumption',
                                               'fuel_price',
                                               'repairs_yearly',  # bis hierher Hauptkosten
                                               'interest_rate',
                                               'taxes_yearly',
                                               'insurance_yearly',
                                               'rest_value']}
        (input_values, calc_values) = Operating_Cost.buy(**bk_inputs).get_frames()
    else:
        label=car['label'] + ' Leasing'
        bk_inputs = {key: car[key] for key in ['instalment', 
                                               'government_funding',
                                               'down_payment',
                                               'holding_period',
                                               'millage_yearly',
                                               'consumption',
                                               'fuel_price',
                                               'repairs_yearly',  # bis hierher Hauptkosten
                                               'taxes_yearly',
                                               'insurance_yearly']}
        (input_values, calc_values) = Operating_Cost.lease(**bk_inputs).get_frames()
        
    input_values_path = Path('images/' + slugify(label) + '-boundaries.png')
    calc_df_path = Path('images/' + slugify(label) + '-calc_df.png')
    
    latex = r"""%s
\twocolumn

\section*{%s}
\begin{center}
\includegraphics[width=0.5\textheight]{%s}
\null
\vspace{0.5cm}
\includegraphics[width=0.5\textheight]{%s}
\end{center}

\pagebreak
\null
\vspace{2cm}
\begin{center}
\includegraphics[width=0.9\columnwidth]{%s}

# %s
\end{center}

\begin{itemize}
    \item Baujahr: %d $\rightarrow$ Laufzeit: %.0f Jahre
    \item \href{%s}{Weblink}
    \item \emph{Gesch\"atzter} Spritpreis \"uber Haltedauer: %.2f \euro{}/%s
    \item Antrieb: %s, mit %d PS
    \item %s
\end{itemize}

\pagebreak

""" %(latex,
      label,
      input_values_path.as_posix(),
      calc_df_path.as_posix(),
      car['image_url'],
      label,
      car['car_year'],
      car['holding_period'],
      car['web_url'].replace('#', '\#'),
      car['fuel_price'],
      car['fuel_unit'],
      car['fuel_type'],
      car['power'],
      car['rest_value_thumb_value']
     )

    # calc_values.loc['Lieferzeit', :] = car['delivery_time']
    # calc_values.loc['Kraftstoffsorte', :] = car['fuel_type']
    # calc_values = calc_values.reindex(index = ['Lieferzeit',
    #                                            'Kraftstoffsorte',
    #                                            'Anschaffungskosten',
    #                                            'Zinsen',
    #                                            'Versicherung',
    #                                            'Steuern',
    #                                            'Reparaturen',
    #                                            'Verbrauch',
    #                                            'SUMME',
    #                                            'Restwert',
    #                                            'Summe mit Restwert'
    #                                           ])
    
    overview[label] = calc_values['Monatlich']
    
    input_values_path.parent.mkdir(parents=True, exist_ok=True)
    
    bold_row = pd.IndexSlice[calc_values.index[(calc_values.index == "Summe") | (calc_values.index == "Gesamtsumme")], :]
    light_row = pd.IndexSlice[calc_values.index[6:], :]
    
    dfi.export(input_values.round(2), str(input_values_path))
    dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
    display(input_values.round(2))
    display(calc_values.style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2))
# Out:
# <ipython-input-64-236278801422>:104: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     52970.00
# Anzahlung [€]                                              15000.00
# davon staatliche Förderung [€]                              5000.00
# Reale Anzahlung [€]                                        10000.00
# Finanzierungszins [%]                                          2.00
# Restwert [€]                                               10000.00
# Versicherungskosten [€/a]                                    459.78
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         16.00
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    37970.00
# <ipython-input-64-236278801422>:107: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(calc_values.style.applymap(df_style, subset=bold_row)\
# <style type="text/css">
# #T_1b4a0_row5_col0, #T_1b4a0_row5_col1, #T_1b4a0_row5_col2, #T_1b4a0_row5_col3 {
#   font-weight: bold;
# }
# #T_1b4a0_row6_col0, #T_1b4a0_row6_col1, #T_1b4a0_row6_col2, #T_1b4a0_row6_col3, #T_1b4a0_row7_col0, #T_1b4a0_row7_col1, #T_1b4a0_row7_col2, #T_1b4a0_row7_col3 {
#   color: grey;
# }
# #T_1b4a0_row8_col0, #T_1b4a0_row8_col1, #T_1b4a0_row8_col2, #T_1b4a0_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_1b4a0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b4a0_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_1b4a0_row0_col0" class="data row0 col0" >40721.48</td>
#       <td id="T_1b4a0_row0_col1" class="data row0 col1" >5817.35</td>
#       <td id="T_1b4a0_row0_col2" class="data row0 col2" >484.78</td>
#       <td id="T_1b4a0_row0_col3" class="data row0 col3" >0.39</td>
#     </tr>
#     <tr>
#       <th id="T_1b4a0_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_1b4a0_row1_col0" class="data row1 col0" >3218.46</td>
#       <td id="T_1b4a0_row1_col1" class="data row1 col1" >459.78</td>
#       <td id="T_1b4a0_row1_col2" class="data row1 col2" >38.32</td>
#       <td id="T_1b4a0_row1_col3" class="data row1 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_1b4a0_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_1b4a0_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_1b4a0_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_1b4a0_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_1b4a0_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1b4a0_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_1b4a0_row3_col0" class="data row3 col0" >3500.00</td>
#       <td id="T_1b4a0_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_1b4a0_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_1b4a0_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_1b4a0_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_1b4a0_row4_col0" class="data row4 col0" >5208.00</td>
#       <td id="T_1b4a0_row4_col1" class="data row4 col1" >744.00</td>
#       <td id="T_1b4a0_row4_col2" class="data row4 col2" >62.00</td>
#       <td id="T_1b4a0_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_1b4a0_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_1b4a0_row5_col0" class="data row5 col0" >52647.94</td>
#       <td id="T_1b4a0_row5_col1" class="data row5 col1" >7521.13</td>
#       <td id="T_1b4a0_row5_col2" class="data row5 col2" >626.76</td>
#       <td id="T_1b4a0_row5_col3" class="data row5 col3" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_1b4a0_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_1b4a0_row6_col0" class="data row6 col0" >10000.00</td>
#       <td id="T_1b4a0_row6_col1" class="data row6 col1" >1428.57</td>
#       <td id="T_1b4a0_row6_col2" class="data row6 col2" >119.05</td>
#       <td id="T_1b4a0_row6_col3" class="data row6 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_1b4a0_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_1b4a0_row7_col0" class="data row7 col0" >-10000.00</td>
#       <td id="T_1b4a0_row7_col1" class="data row7 col1" >-1428.57</td>
#       <td id="T_1b4a0_row7_col2" class="data row7 col2" >-119.05</td>
#       <td id="T_1b4a0_row7_col3" class="data row7 col3" >-0.10</td>
#     </tr>
#     <tr>
#       <th id="T_1b4a0_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_1b4a0_row8_col0" class="data row8 col0" >52647.94</td>
#       <td id="T_1b4a0_row8_col1" class="data row8 col1" >7521.13</td>
#       <td id="T_1b4a0_row8_col2" class="data row8 col2" >626.76</td>
#       <td id="T_1b4a0_row8_col3" class="data row8 col3" >0.50</td>
#     </tr>
#   </tbody>
# </table>
# <ipython-input-64-236278801422>:104: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
#                                                     Randbedingungen
# Leasingrate [€]                                              533.00
# Anzahlung [€]                                               8000.00
# davon staatliche Förderung [€]                              5000.00
# Reale Anzahlung [€]                                         3000.00
# Versicherungskosten [€/a]                                    566.90
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         16.00
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 4.00
# Gesamtlaufleistung [km]                                    60000.00
# <ipython-input-64-236278801422>:107: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(calc_values.style.applymap(df_style, subset=bold_row)\
# <style type="text/css">
# #T_dcda7_row5_col0, #T_dcda7_row5_col1, #T_dcda7_row5_col2, #T_dcda7_row5_col3 {
#   font-weight: bold;
# }
# #T_dcda7_row6_col0, #T_dcda7_row6_col1, #T_dcda7_row6_col2, #T_dcda7_row6_col3, #T_dcda7_row7_col0, #T_dcda7_row7_col1, #T_dcda7_row7_col2, #T_dcda7_row7_col3 {
#   color: grey;
# }
# #T_dcda7_row8_col0, #T_dcda7_row8_col1, #T_dcda7_row8_col2, #T_dcda7_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_dcda7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcda7_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_dcda7_row0_col0" class="data row0 col0" >25584.00</td>
#       <td id="T_dcda7_row0_col1" class="data row0 col1" >6396.00</td>
#       <td id="T_dcda7_row0_col2" class="data row0 col2" >533.00</td>
#       <td id="T_dcda7_row0_col3" class="data row0 col3" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_dcda7_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_dcda7_row1_col0" class="data row1 col0" >2267.60</td>
#       <td id="T_dcda7_row1_col1" class="data row1 col1" >566.90</td>
#       <td id="T_dcda7_row1_col2" class="data row1 col2" >47.24</td>
#       <td id="T_dcda7_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_dcda7_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_dcda7_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_dcda7_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_dcda7_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_dcda7_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_dcda7_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_dcda7_row3_col0" class="data row3 col0" >2000.00</td>
#       <td id="T_dcda7_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_dcda7_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_dcda7_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_dcda7_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_dcda7_row4_col0" class="data row4 col0" >2976.00</td>
#       <td id="T_dcda7_row4_col1" class="data row4 col1" >744.00</td>
#       <td id="T_dcda7_row4_col2" class="data row4 col2" >62.00</td>
#       <td id="T_dcda7_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_dcda7_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_dcda7_row5_col0" class="data row5 col0" >32827.60</td>
#       <td id="T_dcda7_row5_col1" class="data row5 col1" >8206.90</td>
#       <td id="T_dcda7_row5_col2" class="data row5 col2" >683.91</td>
#       <td id="T_dcda7_row5_col3" class="data row5 col3" >0.55</td>
#     </tr>
#     <tr>
#       <th id="T_dcda7_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_dcda7_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_dcda7_row6_col1" class="data row6 col1" >750.00</td>
#       <td id="T_dcda7_row6_col2" class="data row6 col2" >62.50</td>
#       <td id="T_dcda7_row6_col3" class="data row6 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_dcda7_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_dcda7_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_dcda7_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_dcda7_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_dcda7_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_dcda7_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_dcda7_row8_col0" class="data row8 col0" >35827.60</td>
#       <td id="T_dcda7_row8_col1" class="data row8 col1" >8956.90</td>
#       <td id="T_dcda7_row8_col2" class="data row8 col2" >746.41</td>
#       <td id="T_dcda7_row8_col3" class="data row8 col3" >0.60</td>
#     </tr>
#   </tbody>
# </table>
# <ipython-input-64-236278801422>:104: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     43970.00
# Anzahlung [€]                                              16000.00
# davon staatliche Förderung [€]                              6000.00
# Reale Anzahlung [€]                                        10000.00
# Finanzierungszins [%]                                          2.00
# Restwert [€]                                                8500.00
# Versicherungskosten [€/a]                                    544.00
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         15.00
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    27970.00
# <ipython-input-64-236278801422>:107: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(calc_values.style.applymap(df_style, subset=bold_row)\
# <style type="text/css">
# #T_ee650_row5_col0, #T_ee650_row5_col1, #T_ee650_row5_col2, #T_ee650_row5_col3 {
#   font-weight: bold;
# }
# #T_ee650_row6_col0, #T_ee650_row6_col1, #T_ee650_row6_col2, #T_ee650_row6_col3, #T_ee650_row7_col0, #T_ee650_row7_col1, #T_ee650_row7_col2, #T_ee650_row7_col3 {
#   color: grey;
# }
# #T_ee650_row8_col0, #T_ee650_row8_col1, #T_ee650_row8_col2, #T_ee650_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_ee650_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee650_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_ee650_row0_col0" class="data row0 col0" >29996.83</td>
#       <td id="T_ee650_row0_col1" class="data row0 col1" >4285.26</td>
#       <td id="T_ee650_row0_col2" class="data row0 col2" >357.11</td>
#       <td id="T_ee650_row0_col3" class="data row0 col3" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_ee650_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_ee650_row1_col0" class="data row1 col0" >3808.00</td>
#       <td id="T_ee650_row1_col1" class="data row1 col1" >544.00</td>
#       <td id="T_ee650_row1_col2" class="data row1 col2" >45.33</td>
#       <td id="T_ee650_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_ee650_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_ee650_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_ee650_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_ee650_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_ee650_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ee650_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_ee650_row3_col0" class="data row3 col0" >3500.00</td>
#       <td id="T_ee650_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_ee650_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_ee650_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_ee650_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_ee650_row4_col0" class="data row4 col0" >4882.50</td>
#       <td id="T_ee650_row4_col1" class="data row4 col1" >697.50</td>
#       <td id="T_ee650_row4_col2" class="data row4 col2" >58.12</td>
#       <td id="T_ee650_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_ee650_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_ee650_row5_col0" class="data row5 col0" >42187.33</td>
#       <td id="T_ee650_row5_col1" class="data row5 col1" >6026.76</td>
#       <td id="T_ee650_row5_col2" class="data row5 col2" >502.23</td>
#       <td id="T_ee650_row5_col3" class="data row5 col3" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_ee650_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_ee650_row6_col0" class="data row6 col0" >10000.00</td>
#       <td id="T_ee650_row6_col1" class="data row6 col1" >1428.57</td>
#       <td id="T_ee650_row6_col2" class="data row6 col2" >119.05</td>
#       <td id="T_ee650_row6_col3" class="data row6 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_ee650_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_ee650_row7_col0" class="data row7 col0" >-8500.00</td>
#       <td id="T_ee650_row7_col1" class="data row7 col1" >-1214.29</td>
#       <td id="T_ee650_row7_col2" class="data row7 col2" >-101.19</td>
#       <td id="T_ee650_row7_col3" class="data row7 col3" >-0.08</td>
#     </tr>
#     <tr>
#       <th id="T_ee650_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_ee650_row8_col0" class="data row8 col0" >43687.33</td>
#       <td id="T_ee650_row8_col1" class="data row8 col1" >6241.05</td>
#       <td id="T_ee650_row8_col2" class="data row8 col2" >520.09</td>
#       <td id="T_ee650_row8_col3" class="data row8 col3" >0.42</td>
#     </tr>
#   </tbody>
# </table>
# <ipython-input-64-236278801422>:104: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
#                                                     Randbedingungen
# Leasingrate [€]                                              360.00
# Anzahlung [€]                                               9000.00
# davon staatliche Förderung [€]                              6000.00
# Reale Anzahlung [€]                                         3000.00
# Versicherungskosten [€/a]                                    673.60
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         15.00
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 4.00
# Gesamtlaufleistung [km]                                    60000.00
# <ipython-input-64-236278801422>:107: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(calc_values.style.applymap(df_style, subset=bold_row)\
# <style type="text/css">
# #T_b3130_row5_col0, #T_b3130_row5_col1, #T_b3130_row5_col2, #T_b3130_row5_col3 {
#   font-weight: bold;
# }
# #T_b3130_row6_col0, #T_b3130_row6_col1, #T_b3130_row6_col2, #T_b3130_row6_col3, #T_b3130_row7_col0, #T_b3130_row7_col1, #T_b3130_row7_col2, #T_b3130_row7_col3 {
#   color: grey;
# }
# #T_b3130_row8_col0, #T_b3130_row8_col1, #T_b3130_row8_col2, #T_b3130_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_b3130_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3130_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_b3130_row0_col0" class="data row0 col0" >17280.00</td>
#       <td id="T_b3130_row0_col1" class="data row0 col1" >4320.00</td>
#       <td id="T_b3130_row0_col2" class="data row0 col2" >360.00</td>
#       <td id="T_b3130_row0_col3" class="data row0 col3" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_b3130_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_b3130_row1_col0" class="data row1 col0" >2694.40</td>
#       <td id="T_b3130_row1_col1" class="data row1 col1" >673.60</td>
#       <td id="T_b3130_row1_col2" class="data row1 col2" >56.13</td>
#       <td id="T_b3130_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_b3130_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_b3130_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_b3130_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_b3130_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_b3130_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_b3130_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_b3130_row3_col0" class="data row3 col0" >2000.00</td>
#       <td id="T_b3130_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_b3130_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_b3130_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_b3130_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_b3130_row4_col0" class="data row4 col0" >2790.00</td>
#       <td id="T_b3130_row4_col1" class="data row4 col1" >697.50</td>
#       <td id="T_b3130_row4_col2" class="data row4 col2" >58.12</td>
#       <td id="T_b3130_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_b3130_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_b3130_row5_col0" class="data row5 col0" >24764.40</td>
#       <td id="T_b3130_row5_col1" class="data row5 col1" >6191.10</td>
#       <td id="T_b3130_row5_col2" class="data row5 col2" >515.93</td>
#       <td id="T_b3130_row5_col3" class="data row5 col3" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_b3130_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_b3130_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_b3130_row6_col1" class="data row6 col1" >750.00</td>
#       <td id="T_b3130_row6_col2" class="data row6 col2" >62.50</td>
#       <td id="T_b3130_row6_col3" class="data row6 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_b3130_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_b3130_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_b3130_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_b3130_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_b3130_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_b3130_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_b3130_row8_col0" class="data row8 col0" >27764.40</td>
#       <td id="T_b3130_row8_col1" class="data row8 col1" >6941.10</td>
#       <td id="T_b3130_row8_col2" class="data row8 col2" >578.43</td>
#       <td id="T_b3130_row8_col3" class="data row8 col3" >0.46</td>
#     </tr>
#   </tbody>
# </table>
# <ipython-input-64-236278801422>:104: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     30643.19
# Anzahlung [€]                                              10000.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                        10000.00
# Finanzierungszins [%]                                          2.00
# Restwert [€]                                                6000.00
# Versicherungskosten [€/a]                                    510.90
# Steuern [€/a]                                                156.00
# Verbrauch in l/100 km                                          8.00
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    20643.19
# <ipython-input-64-236278801422>:107: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(calc_values.style.applymap(df_style, subset=bold_row)\
# <style type="text/css">
# #T_e3785_row5_col0, #T_e3785_row5_col1, #T_e3785_row5_col2, #T_e3785_row5_col3 {
#   font-weight: bold;
# }
# #T_e3785_row6_col0, #T_e3785_row6_col1, #T_e3785_row6_col2, #T_e3785_row6_col3, #T_e3785_row7_col0, #T_e3785_row7_col1, #T_e3785_row7_col2, #T_e3785_row7_col3 {
#   color: grey;
# }
# #T_e3785_row8_col0, #T_e3785_row8_col1, #T_e3785_row8_col2, #T_e3785_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_e3785_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3785_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_e3785_row0_col0" class="data row0 col0" >22139.09</td>
#       <td id="T_e3785_row0_col1" class="data row0 col1" >3162.73</td>
#       <td id="T_e3785_row0_col2" class="data row0 col2" >263.56</td>
#       <td id="T_e3785_row0_col3" class="data row0 col3" >0.21</td>
#     </tr>
#     <tr>
#       <th id="T_e3785_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_e3785_row1_col0" class="data row1 col0" >3576.30</td>
#       <td id="T_e3785_row1_col1" class="data row1 col1" >510.90</td>
#       <td id="T_e3785_row1_col2" class="data row1 col2" >42.57</td>
#       <td id="T_e3785_row1_col3" class="data row1 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_e3785_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_e3785_row2_col0" class="data row2 col0" >1092.00</td>
#       <td id="T_e3785_row2_col1" class="data row2 col1" >156.00</td>
#       <td id="T_e3785_row2_col2" class="data row2 col2" >13.00</td>
#       <td id="T_e3785_row2_col3" class="data row2 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_e3785_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_e3785_row3_col0" class="data row3 col0" >6300.00</td>
#       <td id="T_e3785_row3_col1" class="data row3 col1" >900.00</td>
#       <td id="T_e3785_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_e3785_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_e3785_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_e3785_row4_col0" class="data row4 col0" >14280.00</td>
#       <td id="T_e3785_row4_col1" class="data row4 col1" >2040.00</td>
#       <td id="T_e3785_row4_col2" class="data row4 col2" >170.00</td>
#       <td id="T_e3785_row4_col3" class="data row4 col3" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_e3785_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_e3785_row5_col0" class="data row5 col0" >47387.39</td>
#       <td id="T_e3785_row5_col1" class="data row5 col1" >6769.63</td>
#       <td id="T_e3785_row5_col2" class="data row5 col2" >564.14</td>
#       <td id="T_e3785_row5_col3" class="data row5 col3" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_e3785_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_e3785_row6_col0" class="data row6 col0" >10000.00</td>
#       <td id="T_e3785_row6_col1" class="data row6 col1" >1428.57</td>
#       <td id="T_e3785_row6_col2" class="data row6 col2" >119.05</td>
#       <td id="T_e3785_row6_col3" class="data row6 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_e3785_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_e3785_row7_col0" class="data row7 col0" >-6000.00</td>
#       <td id="T_e3785_row7_col1" class="data row7 col1" >-857.14</td>
#       <td id="T_e3785_row7_col2" class="data row7 col2" >-71.43</td>
#       <td id="T_e3785_row7_col3" class="data row7 col3" >-0.06</td>
#     </tr>
#     <tr>
#       <th id="T_e3785_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_e3785_row8_col0" class="data row8 col0" >51387.39</td>
#       <td id="T_e3785_row8_col1" class="data row8 col1" >7341.06</td>
#       <td id="T_e3785_row8_col2" class="data row8 col2" >611.75</td>
#       <td id="T_e3785_row8_col3" class="data row8 col3" >0.49</td>
#     </tr>
#   </tbody>
# </table>
# <ipython-input-64-236278801422>:104: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
#                                                     Randbedingungen
# Leasingrate [€]                                              284.70
# Anzahlung [€]                                               3000.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                         3000.00
# Versicherungskosten [€/a]                                    629.91
# Steuern [€/a]                                                156.00
# Verbrauch in l/100 km                                          8.00
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 3.00
# Gesamtlaufleistung [km]                                    45000.00
# <ipython-input-64-236278801422>:107: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(calc_values.style.applymap(df_style, subset=bold_row)\
# <style type="text/css">
# #T_fd431_row5_col0, #T_fd431_row5_col1, #T_fd431_row5_col2, #T_fd431_row5_col3 {
#   font-weight: bold;
# }
# #T_fd431_row6_col0, #T_fd431_row6_col1, #T_fd431_row6_col2, #T_fd431_row6_col3, #T_fd431_row7_col0, #T_fd431_row7_col1, #T_fd431_row7_col2, #T_fd431_row7_col3 {
#   color: grey;
# }
# #T_fd431_row8_col0, #T_fd431_row8_col1, #T_fd431_row8_col2, #T_fd431_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_fd431_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd431_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_fd431_row0_col0" class="data row0 col0" >10249.20</td>
#       <td id="T_fd431_row0_col1" class="data row0 col1" >3416.40</td>
#       <td id="T_fd431_row0_col2" class="data row0 col2" >284.70</td>
#       <td id="T_fd431_row0_col3" class="data row0 col3" >0.23</td>
#     </tr>
#     <tr>
#       <th id="T_fd431_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_fd431_row1_col0" class="data row1 col0" >1889.73</td>
#       <td id="T_fd431_row1_col1" class="data row1 col1" >629.91</td>
#       <td id="T_fd431_row1_col2" class="data row1 col2" >52.49</td>
#       <td id="T_fd431_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_fd431_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_fd431_row2_col0" class="data row2 col0" >468.00</td>
#       <td id="T_fd431_row2_col1" class="data row2 col1" >156.00</td>
#       <td id="T_fd431_row2_col2" class="data row2 col2" >13.00</td>
#       <td id="T_fd431_row2_col3" class="data row2 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_fd431_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_fd431_row3_col0" class="data row3 col0" >2700.00</td>
#       <td id="T_fd431_row3_col1" class="data row3 col1" >900.00</td>
#       <td id="T_fd431_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_fd431_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_fd431_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_fd431_row4_col0" class="data row4 col0" >6120.00</td>
#       <td id="T_fd431_row4_col1" class="data row4 col1" >2040.00</td>
#       <td id="T_fd431_row4_col2" class="data row4 col2" >170.00</td>
#       <td id="T_fd431_row4_col3" class="data row4 col3" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_fd431_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_fd431_row5_col0" class="data row5 col0" >21426.93</td>
#       <td id="T_fd431_row5_col1" class="data row5 col1" >7142.31</td>
#       <td id="T_fd431_row5_col2" class="data row5 col2" >595.19</td>
#       <td id="T_fd431_row5_col3" class="data row5 col3" >0.48</td>
#     </tr>
#     <tr>
#       <th id="T_fd431_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_fd431_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_fd431_row6_col1" class="data row6 col1" >1000.00</td>
#       <td id="T_fd431_row6_col2" class="data row6 col2" >83.33</td>
#       <td id="T_fd431_row6_col3" class="data row6 col3" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_fd431_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_fd431_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_fd431_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_fd431_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_fd431_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fd431_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_fd431_row8_col0" class="data row8 col0" >24426.93</td>
#       <td id="T_fd431_row8_col1" class="data row8 col1" >8142.31</td>
#       <td id="T_fd431_row8_col2" class="data row8 col2" >678.53</td>
#       <td id="T_fd431_row8_col3" class="data row8 col3" >0.54</td>
#     </tr>
#   </tbody>
# </table>
# <ipython-input-64-236278801422>:104: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     25209.43
# Anzahlung [€]                                              10000.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                        10000.00
# Finanzierungszins [%]                                          3.00
# Restwert [€]                                                5000.00
# Versicherungskosten [€/a]                                    325.99
# Steuern [€/a]                                                107.00
# Verbrauch in l/100 km                                          7.00
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    15209.43
# <ipython-input-64-236278801422>:107: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(calc_values.style.applymap(df_style, subset=bold_row)\
# <style type="text/css">
# #T_001c8_row5_col0, #T_001c8_row5_col1, #T_001c8_row5_col2, #T_001c8_row5_col3 {
#   font-weight: bold;
# }
# #T_001c8_row6_col0, #T_001c8_row6_col1, #T_001c8_row6_col2, #T_001c8_row6_col3, #T_001c8_row7_col0, #T_001c8_row7_col1, #T_001c8_row7_col2, #T_001c8_row7_col3 {
#   color: grey;
# }
# #T_001c8_row8_col0, #T_001c8_row8_col1, #T_001c8_row8_col2, #T_001c8_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_001c8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_001c8_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_001c8_row0_col0" class="data row0 col0" >16881.21</td>
#       <td id="T_001c8_row0_col1" class="data row0 col1" >2411.60</td>
#       <td id="T_001c8_row0_col2" class="data row0 col2" >200.97</td>
#       <td id="T_001c8_row0_col3" class="data row0 col3" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_001c8_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_001c8_row1_col0" class="data row1 col0" >2281.93</td>
#       <td id="T_001c8_row1_col1" class="data row1 col1" >325.99</td>
#       <td id="T_001c8_row1_col2" class="data row1 col2" >27.17</td>
#       <td id="T_001c8_row1_col3" class="data row1 col3" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_001c8_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_001c8_row2_col0" class="data row2 col0" >749.00</td>
#       <td id="T_001c8_row2_col1" class="data row2 col1" >107.00</td>
#       <td id="T_001c8_row2_col2" class="data row2 col2" >8.92</td>
#       <td id="T_001c8_row2_col3" class="data row2 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_001c8_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_001c8_row3_col0" class="data row3 col0" >6300.00</td>
#       <td id="T_001c8_row3_col1" class="data row3 col1" >900.00</td>
#       <td id="T_001c8_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_001c8_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_001c8_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_001c8_row4_col0" class="data row4 col0" >12495.00</td>
#       <td id="T_001c8_row4_col1" class="data row4 col1" >1785.00</td>
#       <td id="T_001c8_row4_col2" class="data row4 col2" >148.75</td>
#       <td id="T_001c8_row4_col3" class="data row4 col3" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_001c8_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_001c8_row5_col0" class="data row5 col0" >38707.14</td>
#       <td id="T_001c8_row5_col1" class="data row5 col1" >5529.59</td>
#       <td id="T_001c8_row5_col2" class="data row5 col2" >460.80</td>
#       <td id="T_001c8_row5_col3" class="data row5 col3" >0.37</td>
#     </tr>
#     <tr>
#       <th id="T_001c8_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_001c8_row6_col0" class="data row6 col0" >10000.00</td>
#       <td id="T_001c8_row6_col1" class="data row6 col1" >1428.57</td>
#       <td id="T_001c8_row6_col2" class="data row6 col2" >119.05</td>
#       <td id="T_001c8_row6_col3" class="data row6 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_001c8_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_001c8_row7_col0" class="data row7 col0" >-5000.00</td>
#       <td id="T_001c8_row7_col1" class="data row7 col1" >-714.29</td>
#       <td id="T_001c8_row7_col2" class="data row7 col2" >-59.52</td>
#       <td id="T_001c8_row7_col3" class="data row7 col3" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_001c8_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_001c8_row8_col0" class="data row8 col0" >43707.14</td>
#       <td id="T_001c8_row8_col1" class="data row8 col1" >6243.88</td>
#       <td id="T_001c8_row8_col2" class="data row8 col2" >520.32</td>
#       <td id="T_001c8_row8_col3" class="data row8 col3" >0.42</td>
#     </tr>
#   </tbody>
# </table>
# <ipython-input-64-236278801422>:104: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
#                                                     Randbedingungen
# Leasingrate [€]                                              227.42
# Anzahlung [€]                                               3000.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                         3000.00
# Versicherungskosten [€/a]                                    395.58
# Steuern [€/a]                                                107.00
# Verbrauch in l/100 km                                          7.00
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 3.00
# Gesamtlaufleistung [km]                                    45000.00
# <ipython-input-64-236278801422>:107: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(calc_values.style.applymap(df_style, subset=bold_row)\
# <style type="text/css">
# #T_d0f26_row5_col0, #T_d0f26_row5_col1, #T_d0f26_row5_col2, #T_d0f26_row5_col3 {
#   font-weight: bold;
# }
# #T_d0f26_row6_col0, #T_d0f26_row6_col1, #T_d0f26_row6_col2, #T_d0f26_row6_col3, #T_d0f26_row7_col0, #T_d0f26_row7_col1, #T_d0f26_row7_col2, #T_d0f26_row7_col3 {
#   color: grey;
# }
# #T_d0f26_row8_col0, #T_d0f26_row8_col1, #T_d0f26_row8_col2, #T_d0f26_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_d0f26_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0f26_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_d0f26_row0_col0" class="data row0 col0" >8187.12</td>
#       <td id="T_d0f26_row0_col1" class="data row0 col1" >2729.04</td>
#       <td id="T_d0f26_row0_col2" class="data row0 col2" >227.42</td>
#       <td id="T_d0f26_row0_col3" class="data row0 col3" >0.18</td>
#     </tr>
#     <tr>
#       <th id="T_d0f26_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_d0f26_row1_col0" class="data row1 col0" >1186.74</td>
#       <td id="T_d0f26_row1_col1" class="data row1 col1" >395.58</td>
#       <td id="T_d0f26_row1_col2" class="data row1 col2" >32.96</td>
#       <td id="T_d0f26_row1_col3" class="data row1 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_d0f26_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_d0f26_row2_col0" class="data row2 col0" >321.00</td>
#       <td id="T_d0f26_row2_col1" class="data row2 col1" >107.00</td>
#       <td id="T_d0f26_row2_col2" class="data row2 col2" >8.92</td>
#       <td id="T_d0f26_row2_col3" class="data row2 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_d0f26_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_d0f26_row3_col0" class="data row3 col0" >2700.00</td>
#       <td id="T_d0f26_row3_col1" class="data row3 col1" >900.00</td>
#       <td id="T_d0f26_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_d0f26_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_d0f26_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_d0f26_row4_col0" class="data row4 col0" >5355.00</td>
#       <td id="T_d0f26_row4_col1" class="data row4 col1" >1785.00</td>
#       <td id="T_d0f26_row4_col2" class="data row4 col2" >148.75</td>
#       <td id="T_d0f26_row4_col3" class="data row4 col3" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_d0f26_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_d0f26_row5_col0" class="data row5 col0" >17749.86</td>
#       <td id="T_d0f26_row5_col1" class="data row5 col1" >5916.62</td>
#       <td id="T_d0f26_row5_col2" class="data row5 col2" >493.05</td>
#       <td id="T_d0f26_row5_col3" class="data row5 col3" >0.39</td>
#     </tr>
#     <tr>
#       <th id="T_d0f26_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_d0f26_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_d0f26_row6_col1" class="data row6 col1" >1000.00</td>
#       <td id="T_d0f26_row6_col2" class="data row6 col2" >83.33</td>
#       <td id="T_d0f26_row6_col3" class="data row6 col3" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_d0f26_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_d0f26_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_d0f26_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_d0f26_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_d0f26_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d0f26_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_d0f26_row8_col0" class="data row8 col0" >20749.86</td>
#       <td id="T_d0f26_row8_col1" class="data row8 col1" >6916.62</td>
#       <td id="T_d0f26_row8_col2" class="data row8 col2" >576.38</td>
#       <td id="T_d0f26_row8_col3" class="data row8 col3" >0.46</td>
#     </tr>
#   </tbody>
# </table>

# %%
brk = 8

overview_path_1 = 'images/overview1.png'
overview_path_2 = 'images/overview2.png'

# sum_row = pd.IndexSlice[calc_values.index[(calc_values.index == "Summe") | (calc_values.index == "Gesamtsumme")], :]

dfi.export(overview.iloc[:, 0:brk ].style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2), overview_path_1)
dfi.export(overview.iloc[:, brk: ].style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2), overview_path_2)

display(overview.iloc[:, 0:brk ].style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2))
display(overview.iloc[:, brk: ].style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2))

latex = r"""%s

\pagebreak

\onecolumn
\null
\vfill 
\begin{center}
\includegraphics[width=0.95\columnwidth]{%s}
\null
\vspace{0.5cm}
%% \includegraphics[width=0.95\columnwidth]{%s}
\end{center}
\vfill 
""" % (latex,
      overview_path_1,
      overview_path_2)
# Out:
# <ipython-input-65-020bbe2b6b03>:8: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(overview.iloc[:, 0:brk ].style.applymap(df_style, subset=bold_row)\
# <ipython-input-65-020bbe2b6b03>:10: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(overview.iloc[:, brk: ].style.applymap(df_style, subset=bold_row)\
# <ipython-input-65-020bbe2b6b03>:13: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(overview.iloc[:, 0:brk ].style.applymap(df_style, subset=bold_row)\
# <style type="text/css">
# #T_2bcc4_row5_col0, #T_2bcc4_row5_col1, #T_2bcc4_row5_col2, #T_2bcc4_row5_col3, #T_2bcc4_row5_col4, #T_2bcc4_row5_col5, #T_2bcc4_row5_col6, #T_2bcc4_row5_col7 {
#   font-weight: bold;
# }
# #T_2bcc4_row6_col0, #T_2bcc4_row6_col1, #T_2bcc4_row6_col2, #T_2bcc4_row6_col3, #T_2bcc4_row6_col4, #T_2bcc4_row6_col5, #T_2bcc4_row6_col6, #T_2bcc4_row6_col7, #T_2bcc4_row7_col0, #T_2bcc4_row7_col1, #T_2bcc4_row7_col2, #T_2bcc4_row7_col3, #T_2bcc4_row7_col4, #T_2bcc4_row7_col5, #T_2bcc4_row7_col6, #T_2bcc4_row7_col7 {
#   color: grey;
# }
# #T_2bcc4_row8_col0, #T_2bcc4_row8_col1, #T_2bcc4_row8_col2, #T_2bcc4_row8_col3, #T_2bcc4_row8_col4, #T_2bcc4_row8_col5, #T_2bcc4_row8_col6, #T_2bcc4_row8_col7 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_2bcc4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Tesla Model Y Kaufen</th>
#       <th class="col_heading level0 col1" >Tesla Model Y Leasing</th>
#       <th class="col_heading level0 col2" >Tesla Model 3 Kaufen</th>
#       <th class="col_heading level0 col3" >Tesla Model 3 Leasing</th>
#       <th class="col_heading level0 col4" >Mazda 6 Kaufen</th>
#       <th class="col_heading level0 col5" >Mazda 6 Leasing</th>
#       <th class="col_heading level0 col6" >Kia ceed Kaufen</th>
#       <th class="col_heading level0 col7" >Kia ceed Leasing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bcc4_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_2bcc4_row0_col0" class="data row0 col0" >484.78</td>
#       <td id="T_2bcc4_row0_col1" class="data row0 col1" >533.00</td>
#       <td id="T_2bcc4_row0_col2" class="data row0 col2" >357.11</td>
#       <td id="T_2bcc4_row0_col3" class="data row0 col3" >360.00</td>
#       <td id="T_2bcc4_row0_col4" class="data row0 col4" >263.56</td>
#       <td id="T_2bcc4_row0_col5" class="data row0 col5" >284.70</td>
#       <td id="T_2bcc4_row0_col6" class="data row0 col6" >200.97</td>
#       <td id="T_2bcc4_row0_col7" class="data row0 col7" >227.42</td>
#     </tr>
#     <tr>
#       <th id="T_2bcc4_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_2bcc4_row1_col0" class="data row1 col0" >38.32</td>
#       <td id="T_2bcc4_row1_col1" class="data row1 col1" >47.24</td>
#       <td id="T_2bcc4_row1_col2" class="data row1 col2" >45.33</td>
#       <td id="T_2bcc4_row1_col3" class="data row1 col3" >56.13</td>
#       <td id="T_2bcc4_row1_col4" class="data row1 col4" >42.57</td>
#       <td id="T_2bcc4_row1_col5" class="data row1 col5" >52.49</td>
#       <td id="T_2bcc4_row1_col6" class="data row1 col6" >27.17</td>
#       <td id="T_2bcc4_row1_col7" class="data row1 col7" >32.96</td>
#     </tr>
#     <tr>
#       <th id="T_2bcc4_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_2bcc4_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_2bcc4_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_2bcc4_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_2bcc4_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_2bcc4_row2_col4" class="data row2 col4" >13.00</td>
#       <td id="T_2bcc4_row2_col5" class="data row2 col5" >13.00</td>
#       <td id="T_2bcc4_row2_col6" class="data row2 col6" >8.92</td>
#       <td id="T_2bcc4_row2_col7" class="data row2 col7" >8.92</td>
#     </tr>
#     <tr>
#       <th id="T_2bcc4_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_2bcc4_row3_col0" class="data row3 col0" >41.67</td>
#       <td id="T_2bcc4_row3_col1" class="data row3 col1" >41.67</td>
#       <td id="T_2bcc4_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_2bcc4_row3_col3" class="data row3 col3" >41.67</td>
#       <td id="T_2bcc4_row3_col4" class="data row3 col4" >75.00</td>
#       <td id="T_2bcc4_row3_col5" class="data row3 col5" >75.00</td>
#       <td id="T_2bcc4_row3_col6" class="data row3 col6" >75.00</td>
#       <td id="T_2bcc4_row3_col7" class="data row3 col7" >75.00</td>
#     </tr>
#     <tr>
#       <th id="T_2bcc4_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_2bcc4_row4_col0" class="data row4 col0" >62.00</td>
#       <td id="T_2bcc4_row4_col1" class="data row4 col1" >62.00</td>
#       <td id="T_2bcc4_row4_col2" class="data row4 col2" >58.12</td>
#       <td id="T_2bcc4_row4_col3" class="data row4 col3" >58.12</td>
#       <td id="T_2bcc4_row4_col4" class="data row4 col4" >170.00</td>
#       <td id="T_2bcc4_row4_col5" class="data row4 col5" >170.00</td>
#       <td id="T_2bcc4_row4_col6" class="data row4 col6" >148.75</td>
#       <td id="T_2bcc4_row4_col7" class="data row4 col7" >148.75</td>
#     </tr>
#     <tr>
#       <th id="T_2bcc4_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_2bcc4_row5_col0" class="data row5 col0" >626.76</td>
#       <td id="T_2bcc4_row5_col1" class="data row5 col1" >683.91</td>
#       <td id="T_2bcc4_row5_col2" class="data row5 col2" >502.23</td>
#       <td id="T_2bcc4_row5_col3" class="data row5 col3" >515.93</td>
#       <td id="T_2bcc4_row5_col4" class="data row5 col4" >564.14</td>
#       <td id="T_2bcc4_row5_col5" class="data row5 col5" >595.19</td>
#       <td id="T_2bcc4_row5_col6" class="data row5 col6" >460.80</td>
#       <td id="T_2bcc4_row5_col7" class="data row5 col7" >493.05</td>
#     </tr>
#     <tr>
#       <th id="T_2bcc4_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_2bcc4_row6_col0" class="data row6 col0" >119.05</td>
#       <td id="T_2bcc4_row6_col1" class="data row6 col1" >62.50</td>
#       <td id="T_2bcc4_row6_col2" class="data row6 col2" >119.05</td>
#       <td id="T_2bcc4_row6_col3" class="data row6 col3" >62.50</td>
#       <td id="T_2bcc4_row6_col4" class="data row6 col4" >119.05</td>
#       <td id="T_2bcc4_row6_col5" class="data row6 col5" >83.33</td>
#       <td id="T_2bcc4_row6_col6" class="data row6 col6" >119.05</td>
#       <td id="T_2bcc4_row6_col7" class="data row6 col7" >83.33</td>
#     </tr>
#     <tr>
#       <th id="T_2bcc4_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_2bcc4_row7_col0" class="data row7 col0" >-119.05</td>
#       <td id="T_2bcc4_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_2bcc4_row7_col2" class="data row7 col2" >-101.19</td>
#       <td id="T_2bcc4_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_2bcc4_row7_col4" class="data row7 col4" >-71.43</td>
#       <td id="T_2bcc4_row7_col5" class="data row7 col5" >0.00</td>
#       <td id="T_2bcc4_row7_col6" class="data row7 col6" >-59.52</td>
#       <td id="T_2bcc4_row7_col7" class="data row7 col7" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_2bcc4_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_2bcc4_row8_col0" class="data row8 col0" >626.76</td>
#       <td id="T_2bcc4_row8_col1" class="data row8 col1" >746.41</td>
#       <td id="T_2bcc4_row8_col2" class="data row8 col2" >520.09</td>
#       <td id="T_2bcc4_row8_col3" class="data row8 col3" >578.43</td>
#       <td id="T_2bcc4_row8_col4" class="data row8 col4" >611.75</td>
#       <td id="T_2bcc4_row8_col5" class="data row8 col5" >678.53</td>
#       <td id="T_2bcc4_row8_col6" class="data row8 col6" >520.32</td>
#       <td id="T_2bcc4_row8_col7" class="data row8 col7" >576.38</td>
#     </tr>
#   </tbody>
# </table>
# <ipython-input-65-020bbe2b6b03>:15: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(overview.iloc[:, brk: ].style.applymap(df_style, subset=bold_row)\
# <style type="text/css">
# </style>
# <table id="T_11034_">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11034_level0_row0" class="row_heading level0 row0" >Raten</th>
#     </tr>
#     <tr>
#       <th id="T_11034_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#     </tr>
#     <tr>
#       <th id="T_11034_level0_row2" class="row_heading level0 row2" >Steuern</th>
#     </tr>
#     <tr>
#       <th id="T_11034_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#     </tr>
#     <tr>
#       <th id="T_11034_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#     </tr>
#     <tr>
#       <th id="T_11034_level0_row5" class="row_heading level0 row5" >Summe</th>
#     </tr>
#     <tr>
#       <th id="T_11034_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#     </tr>
#     <tr>
#       <th id="T_11034_level0_row7" class="row_heading level0 row7" >Restwert</th>
#     </tr>
#     <tr>
#       <th id="T_11034_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#     </tr>
#   </tbody>
# </table>

# %%
with open('report_l.tex', 'w') as fid:
    fid.write(r"""
\documentclass[landscape, DIV=99, 14pt]{scrartcl}

\renewcommand*{\familydefault}{\sfdefault}

\RequirePackage{graphicx}
\RequirePackage{hyperref}
\RequirePackage[gen]{eurosym}

\begin{document}

# %s

\end{document}
""" % (latex))
