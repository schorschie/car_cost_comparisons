# %%
import os

import pandas as pd
import dataframe_image as dfi

from slugify import slugify
from pathlib import Path
from bk import Operating_Cost

def df_style(val):
    # return "font-weight: bold; background: yellow"
    return "font-weight: bold;"

def index_style(val):
    # return "font-weight: bold; background: yellow"
    return "font-weight: bold; text-align: left;"

def light_style(val):
    return "color: grey"

import shutil
from pathlib import Path

images_path = Path('images1')
if images_path.exists():
    shutil.rmtree(images_path)
images_path.mkdir(parents=True, exist_ok=True)

# %%
d_0 = 1.63  # Aktueller Dieselpreis 27.1.2022: 1.63
b_0 = 1.64  # Aktueller Benzinpreis 27.1.2022: 1.64
e_0 = 0.31  # Aktueller Strompreis 27.1.2022: 0.31 €/kWh
# e_0 = 0.79  # Superchargin worst case
halte_dauer_gebraucht = 4

down_payment_buy = 15000
down_payment_lease = 3000
SHOW_ALL = False

bmw_testdrive = [(0, 7),
                 [r'', r"""Eigentlich ein super Auto: bequem, sportlich und langstreckentauglich.
                 Aber zu wenig Platz und viel zu viele Reparaturen."""]]
touran_testdrive = [(9,9),
                   [r"""Auto war ruhig. Hinten viel Platz, Auto ist nicht auf der Straße gehüpft,
                    gut gedämpft. Innen sehr hoch. Leicht zu bedienen, alles an seinem Platz. Rücksitz
                    war leichter zu erreichen als bei allen anderen. Sehr großer Kofferaum.""", 
                    r"""War leider ein Handschalter, aber hat trotzdem spaß gemacht. 
                   Leises auto, bequeme Sitze, viel Platz. Hinten drei Sitze. Dritte Sitzreihe gut nutzbar.
                   Verbrauch auf Testfahrt annehmbar (8l/100km). Leichtgängige Lenkung, Fahrwerk hat Straße 
                   gut weggefedert."""]]


cars = []       
cars.append({'label': 'BMW 318d',
             'acquisition_cost': 16903,
             'government_funding': 0,
             'down_payment': 0,
             'car_year': 2011,
             'odometer': 253640,
             'vehicle_registration': 'gebraucht',
             'delivery_time': 0,
             'interest_rate': 0.,
             'rest_value': 3000,
             'insurance_yearly': 775,
             'taxes_yearly': 230,
             'consumption': 6.38,
             'power': 137,
             'seats': '5',
             'fuel_price': 1.19,  # Durchschnittlicher Dieselpreis seit 2015
             'fuel_type': 'Diesel',
             'fuel_unit': 'l',
             'repairs_yearly': 2016.32,
             'millage_yearly': 26000,
             'holding_period': 6.85,
             'image_url': 'cars/bmw-3er-maximus.png',
             'web_url': 'https://de.wikipedia.org/wiki/BMW_E90',
             'buy': True,  # else lease
             'fuel_estimated': False,
             'price_estimated': False,
             'test_drive': bmw_testdrive,
             'hide': True
            }
           )
cars.append({'label': 'Nissan Micra',
             'acquisition_cost': 3300,
             'government_funding': 0,
             'down_payment': 3300,
             'car_year': 2011,
             'vehicle_registration': 'gebraucht',
             'odometer': 122000,
             'delivery_time': 0,
             'interest_rate': 0.,
             'rest_value': 2000,
             'insurance_yearly': 361.76,
             'taxes_yearly': 64,
             'consumption': 6.6,
             'power': 65,
             'seats': '5',
             'fuel_price': 1.36,  # Durchschnittlicher Dieselpreis seit 2016
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 395.40,
             'millage_yearly': 3216,
             'holding_period': 5.5,  
             'image_url': 'cars/nissan-micra.jpg',
             'web_url': 'https://de.wikipedia.org/wiki/Nissan_Micra#Micra_(K12,_2003%E2%80%932010)',
             'buy': True,  # else lease
             'fuel_estimated': False,
             'price_estimated': False,
             'test_drive': [(0, 6), [r'', r'Ein tolles Auto f\"ur den Preis. Sehr zuverl\"assig. Aber ein bisschen unbequem und extrem laut im Inneraum.']],
             'hide': True
            }
           )
cars.append({'label': 'VW up!',
             'acquisition_cost': 13000,
             'instalment': 105,
             'government_funding': 0,
             'down_payment': down_payment_lease ,
             'car_year': 2012,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 10,
             'insurance_yearly': 478.80,
             'taxes_yearly': 20,
             'consumption': 5.8,
             'power': 60,
             'seats': '5',
             'fuel_price': 1.54,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 647.52,
             'millage_yearly': 28280,
             'holding_period': 3.0,   
             'image_url': 'cars/vw-up.jpg',
             'web_url': 'https://www.volkswagen.de/de/modelle/up.html',
             'buy': False,  # else lease
             'fuel_estimated': False,
             'price_estimated': False,
             'test_drive': [(0, 5), [r'', r'Ich war sehr unzufrieden mit dem up. Er hat zwar ein gutes Fahrwerk und geringe Innenger\"ausche, aber ich fand den Verbrauch und die Wartungskosten viel zu hoch f\"ur so ein kleines Auto.']],
             'hide': True
            }
           )
cars.append({'label': 'Tesla Model Y',
             'acquisition_cost': 57970,
             'government_funding': 5000,
             'down_payment': down_payment_buy + 5000,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 10500,
             'insurance_yearly': 459.78,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'seats': '5',
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 2000/7 + 300*2/7,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-y.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': [(8, 8), ['Zu Teuer. Sehr viel Platz. Keine Stufe auf dem mittleren Platz. Automatisches Bremsen toll. Kofferraum groß genug. Display seltsam aufgeteilt. Display zu groß.', r'Sehr bequemes, luxuri\"oses Auto. Viel Platz, viel Leistung, gro\ss{}e Reichweite. Schlechtes Kofferraum Management, Keine Hutablage, keine Sicherung unter dem Sitz.']],
             'hide': True
            }
           )
cars.append({'label': 'Tesla Model Y Std',
             'acquisition_cost': 51970,
             'government_funding': 5000,
             'down_payment': down_payment_buy + 5000,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 10000,
             'insurance_yearly': 459.78,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'seats': '5',
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 2000/7 + 300*2/7,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-y.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': [(8, 8), ['', r'Sehr bequemes, luxuri\"oses Auto. Viel Platz, viel Leistung, gro\ss{}e Reichweite. Schlechtes Kofferraum Management, Keine Hutablage, keine Sicherung unter dem Sitz.']],
             'hide': True
            }
           )
cars.append({'label': 'Tesla Model Y',
             'acquisition_cost': 57970,
             'instalment': 533,
             'government_funding': 5000,
             'down_payment': down_payment_lease + 5000,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 4,
             'rest_value': 9000,
             'insurance_yearly': 566.90,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'seats': '5',
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 4.0,   
             'image_url': 'cars/tesla-model-y-leasing.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': False,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': cars[-1]['test_drive'],
             'hide': True
            }
           )
cars.append({'label': 'Tesla Model 3',
             'acquisition_cost': 43970,
             'government_funding': 6000,
             'down_payment': down_payment_buy + 6000,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 16,
             'interest_rate': 1.91,
             'rest_value': 8500,
             'insurance_yearly': 544,
             'taxes_yearly': 0,
             'consumption': 15.,
             'power': 325,
             'seats': '5',
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 1200/7 + 300*2/7,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-3.jpg',
             'web_url': 'https://www.tesla.com/de_de/model3/design#overview',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': [(0, 0), [r'', r'']],
             'hide': False
            }
           )
cars.append({'label': 'Tesla Model 3',
             'acquisition_cost': 43970,
             'instalment': 360,
             'government_funding': 6000,
             'down_payment': down_payment_lease + 6000,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 16,
             'insurance_yearly': 673.60,
             'taxes_yearly': 0,
             'consumption': 15.,
             'power': 325,
             'seats': '5',
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 4.0,   
             'image_url': 'cars/tesla-model-3-leasing.jpg',
             'web_url': 'https://www.tesla.com/de_de/model3/design#overview',
             'buy': False,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': cars[-1]['test_drive'],
             'hide': True
            }
           )
cars.append({'label': 'Mazda 6',
             'acquisition_cost': 30643.19,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 20,
             'interest_rate': 2.,
             'rest_value': 6000,
             'insurance_yearly': 510.90,
             'taxes_yearly': 156,
             'consumption': 8.,
             'power': 192,
             'seats': '5',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,
             'image_url': 'cars/mazda-6-neu.png',
             'web_url': 'https://konfigurator.meinauto.de/mazda/neuwagen/48-6/angebote/6-kombi/konfigurator/#!/extras/exclusive-line/8846370/10,11/private/65352-5416-204698/984/61c9aa657e74c/cash-purchase/32545--287374/48,0,10000,0,0,0,0,0,',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': [(6, 4), ['Zu laut, stinkt, ruppelig, eng vorne und hinten. Navi etwas seltsam.', r'Tolles Au\ss{}endesign, sehr sch\"oner Innenraum und gro\ss{}er Kofferaum. Motor schwach und klapprig, Innenger\"ausche laut, Sitze ohne Seitenhalt, viel Windger\"ausche, krasser Abgasgeruch im Inneraum. Hatten nach der Probefahrt Kopfschmerzen. Verbrauch leider am Ende nicht gepr\"uft, aber war w\"ahrend der Probefahrt oft Richtung 10 l/100km']],
             'hide': True
            }
           )
cars.append({'label': 'Mazda 6',
             'acquisition_cost': 30643.19,
             'instalment': 284.70,
             'government_funding': 0,
             'down_payment': down_payment_lease,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 60,
             'rest_value': 3000,
             'insurance_yearly': 629.91,
             'taxes_yearly': 156,
             'consumption': 8.,
             'power': 192,
             'seats': '5',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3,
             'image_url': 'cars/mazda-6-leasing.png',
             'web_url': 'https://konfigurator.meinauto.de/mazda/neuwagen/48-6/angebote/6-kombi/konfigurator/#!/extras/exclusive-line/8846370/10,11,15/private/65352-5416-204698/984/61c9aa657e74c/leasing/16040--249432/36,3000,15000,0,0,0,0,0,',
             'buy': False,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': cars[-1]['test_drive'],
             'hide': True
            }
           )
cars.append({'label': 'Hyundai Ioniq 5',
             'acquisition_cost': 48536.05,
             'government_funding': 6000,
             'down_payment': down_payment_buy + 6000,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 8500,
             'insurance_yearly': 497.86+9.6,
             'taxes_yearly': 0,
             'consumption': 26.1,
             'power': 231,
             'seats': '5',
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/hyundai-ioniq-5.png',
             'web_url': 'https://konfigurator.meinauto.de/hyundai/neuwagen/ioniq/angebote/ioniq-5/konfigurator/#!/extras/-/8865700/14,19,41/private/104690-6897-293274/4864/61e90b0c48e55/cash-purchase/104690-6897-293274/24,9000,15000,0,0,0,0,0,',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': [(0, 0), [r'', r'Auf die Schnelle im Autosalon keinen gute Sitzposition gefunden. Kofferaum \"uberraschend klein f\"ur die Gr\"o\ss{}e. Verbrauch soll sehr hoch sein.']],
             'hide': True
            }
           )
cars.append({'label': 'Hyundai Ioniq 5',
             'acquisition_cost': 48536.05,
             'instalment': 455.10,
             'government_funding': 6000,
             'down_payment': down_payment_lease + 6000,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 4,
             'insurance_yearly': 624.53,
             'taxes_yearly': 0,
             'consumption': 26.1,
             'power': 231,
             'seats': '5',
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 2.0,   
             'image_url': 'cars/hyundai-ioniq-5.png',
             'web_url': 'https://konfigurator.meinauto.de/hyundai/neuwagen/ioniq/angebote/ioniq-5/konfigurator/#!/extras/-/8865700/14,19,41/private/104690-6897-293274/4864/61e90b0c48e55/leasing/104690-6897-293274/24,9000,15000,0,0,0,0,0,',
             'buy': False,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': cars[-1]['test_drive'],
             'hide': True
            }
           )
cars.append({'label': 'Kia ceed SW',
             'acquisition_cost': 25209.43,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'delivery_time': 0,
             'vehicle_registration': 'neu',
             'interest_rate': 2.,
             'rest_value': 5000,
             'insurance_yearly': 325.99,
             'taxes_yearly': 107,
             'consumption': 7.,
             'power': 160,
             'seats': '5',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 500/7 + 500*3/7,
             'millage_yearly': 15000,
             'holding_period': 7.0,
             'image_url': 'cars/kia-ceed-sportswagon.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/extras/spirit/8865371/3,11,27/private/109347-4167-291321/1321/61d21ce73c5db/cash-purchase/109348-8088-291322/48,0,10000,0,0,0,0,0,',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': [(7, 7), [r'Eng auf der Rückbank und auf dem Beifahrersitz. Motor durchzugsstart. Zu kleiner Kofferraum. Fahrersitz unbequem. Hinten laut. Keine Infoleuchte bei Parkbremse.', r'Hinten laut, Vorne komfortabel aber Sitze etwas unbequem. Kein Seitenhalt. Großer Kofferraum. Gute Luft, Hinten eng, Günstig, Geringer verbrauch, Durchzugsstarker Motor. Kein Drehdrücksteller.']],
             'hide': True
            }
           )
cars.append({'label': 'Kia ceed SW',
             'acquisition_cost': 25209.43,
             'instalment': 227.42,
             'government_funding': 0,
             'down_payment': down_payment_lease,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 0,
             'rest_value': 3000,
             'insurance_yearly': 395.58,
             'taxes_yearly': 107,
             'consumption': 7.,
             'power': 160,
             'seats': '5',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 500/7 + 500*3/7,
             'millage_yearly': 15000,
             'holding_period': 3.0,
             'image_url': 'cars/kia-ceed-sportswagon-leasing.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/extras/spirit/8865371/3,11,27/private/109347-4167-291321/1321/61d21ce73c5db/leasing/109348-8088-291322/36,3000,15000,0,0,0,0,0,',
             'buy': False,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': cars[-1]['test_drive'],
             'hide': True
            }
           )
cars.append({'label': 'VW Passat',
             'acquisition_cost': 30230.0,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2021,
             'odometer': 24800,
             'vehicle_registration': 'gebraucht',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 6000,
             'insurance_yearly': 351.35,
             'taxes_yearly': 98,
             'consumption': 7.5,
             'power': 150,
             'seats': '5',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,
             'image_url': 'cars/vw-passat.jpg',
             'web_url': 'https://www.autosuche.de/auto/REVVNDQ3NjgwMjc5NzI=?t_manuf=BQ&t_petr=B&t_model=BQBM&t_gear=A&t_ez_fr=2020&t_pe_fr=35000&sort=PRICE_SALE&sortdirection=ASC&viewMode=tile',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': [(0, 0), [r'', r'']],
             'hide': True
            }
           )
cars.append({'label': 'VW Passat',
             'acquisition_cost': 30230.0,
             'instalment': 194.18 + 4557.50/36,
             'government_funding': 0,
             'down_payment': down_payment_lease,
             'car_year': 2021,
             'odometer': 24800,
             'vehicle_registration': 'gebraucht',
             'delivery_time': 0,
             'rest_value': 3000,
             'insurance_yearly': 423.07,
             'taxes_yearly': 98,
             'consumption': 7.5,
             'power': 150,
             'seats': '5',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3.0,
             'image_url': 'cars/vw-passat-leasing.jpg',
             'web_url': 'https://www.autosuche.de/auto/REVVNDQ3NjgwMjc5NzI=?t_manuf=BQ&t_petr=B&t_model=BQBM&t_gear=A&t_ez_fr=2020&t_pe_fr=35000&sort=PRICE_SALE&sortdirection=ASC&viewMode=tile',
             'buy': False,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': cars[-1]['test_drive'],
             'hide': True
            }
           )
cars.append({'label': 'Mercedes C 200',
             'acquisition_cost': 27690,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2019,
             'odometer': 54128,
             'vehicle_registration': 'gebraucht',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 5500,
             'insurance_yearly': 533.68,
             'taxes_yearly': 144,
             'consumption': 8.45,
             'power': 184,
             'seats': '5',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': halte_dauer_gebraucht,  
             'image_url': 'cars/mercedes-c-200-t-leasing.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?action=parkItem&id=327113608',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': [(0, 0), [r'', r'']],
             'hide': True
            }
           ) 
cars.append({'label': 'BMW Gran Tourer',
             'acquisition_cost': 42000,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 35,
             'interest_rate': 2.,
             'rest_value': 8500,
             'insurance_yearly': 425.83,
             'taxes_yearly': 110,
             'consumption': 8,
             'power': 192,
             'seats': '5+2',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': (1260+1200)/7,
             'millage_yearly': 15000,
             'holding_period': 7,  
             'image_url': 'cars/bmw-gran-tourer-mulfinger.png',
             'web_url': 'https://mulfinger.de/de/fahrzeugangebot/BMW/220i-GranTourer-Sport-DKG-HUD-LED-ParkAssNavi/page1/details-p5clkem9?manufacturer=5&model=2534&view=list',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': [(0, 7), [r'', r'Toller Motor, toller Sportmodus, Auto zieht richtig ab. Fahrwerk hart und tuckert. Gerade hinten nicht so toll. Sitze sehr gut, aber nicht ganz so toll wie 3er BMW. Hinten relativ laute Windgeräusche. Auto hatte Sportfahrwerk und keine Akustikverglasung.']],
             'hide': True
            }
           )     
cars.append({'label': 'BMW Gran Tourer',
             'acquisition_cost': 24890,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2019,
             'odometer': 51040,
             'vehicle_registration': 'gebraucht',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 10000,
             'insurance_yearly': 470.71,
             'taxes_yearly': 110,
             'consumption': 8,
             'power': 192,
             'seats': '5+2',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 1000,
             'millage_yearly': 15000,
             'holding_period': halte_dauer_gebraucht,  
             'image_url': 'cars/bmw-gran-tourer-mulfinger.png',
             'web_url': 'https://mulfinger.de/de/fahrzeugangebot/BMW/220i-GranTourer-Sport-DKG-HUD-LED-ParkAssNavi/page1/details-p5clkem9?manufacturer=5&model=2534&view=list',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': [(0, 0), [r'', r'']],
             'hide': True
            }
           )     
cars.append({'label': 'Skoda Kodiaq',
             'acquisition_cost': 29980,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2018,
             'odometer': 70250,
             'vehicle_registration': 'gebraucht',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 12000,
             'insurance_yearly': 384.01,
             'taxes_yearly': 211,
             'consumption': 9.5,
             'power': 192,
             'seats': '7',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 1500,
             'millage_yearly': 15000,
             'holding_period': halte_dauer_gebraucht,  
             'image_url': 'cars/skoda-kodiaq-4x4-2p0-tsi.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?action=parkItem&id=336255689',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': [(0, 0), [r'', r'']],
             'hide': True
            }
           )     
cars.append({'label': 'Skoda Kodiaq',
             'acquisition_cost': 29980,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2018,
             'odometer': 83080,
             'vehicle_registration': 'gebraucht',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 12000,
             'insurance_yearly': 388.11,
             'taxes_yearly': 258,
             'consumption': 8,
             'power': 192,
             'seats': '7',
             'fuel_price': d_0,
             'fuel_type': 'Diesel',
             'fuel_unit': 'l',
             'repairs_yearly': 1500,
             'millage_yearly': 15000,
             'holding_period': halte_dauer_gebraucht,  
             'image_url': 'cars/skoda-kodiaq-4x4-2p0-tdi.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?action=parkItem&id=336544234',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': [(0, 0), [r'', r'']],
             'hide': True
            }
           )
cars.append({'label': 'VW Touran',
             'acquisition_cost': 36572.31,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 50,
             'interest_rate': 2.,
             'rest_value': 7500,
             'insurance_yearly': 306.79,
             'taxes_yearly': 96,
             'consumption': 7.5,
             'power': 192,
             'seats': '7',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 1000,
             'millage_yearly': 15000,
             'holding_period': 7,  
             'image_url': 'cars/vw-touran.png',
             'web_url': 'https://konfigurator.meinauto.de/volkswagen/neuwagen/8-touran/angebote/touran-active/konfigurator/#!/preisvergleich/active/8864470/16,32,40,44,47,55,56,70,78,80/private/111369-2923-297336/4629/61ef049598ad9/cash-purchase/107670-6554-286080/48,0,10000,0,0,0,0,0,',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': [(0, 0), [r'', r'']],
             'hide': True
            }
           )
cars.append({'label': 'VW Touran',
             'acquisition_cost': 24990,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2018,
             'odometer': 67640,
             'vehicle_registration': 'gebraucht',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 9500,
             'insurance_yearly': 339.95,
             'taxes_yearly': 96,
             'consumption': 7.5,
             'power': 150,
             'seats': '7',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 1000,
             'millage_yearly': 15000,
             'holding_period': halte_dauer_gebraucht,  
             'image_url': 'cars/vw-touran-geb.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?id=338082714',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': touran_testdrive,
             'hide': True
            }
           )
cars.append({'label': 'VW Touran',
             'acquisition_cost': 25790,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2018,
             'odometer': 53600,
             'vehicle_registration': 'gebraucht',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 10000,
             'insurance_yearly': 339.95,
             'taxes_yearly': 124,
             'consumption': 8.3,
             'power': 179,
             'seats': '7',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 1000,
             'millage_yearly': 15000,
             'holding_period': halte_dauer_gebraucht,  
             'image_url': 'cars/vw-touran-geb2.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?id=337573342',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': touran_testdrive,
             'hide': True
            }
           )
cars.append({'label': 'VW Sharan',
             'acquisition_cost': 48653.38,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 10000,
             'insurance_yearly': 430.94,
             'taxes_yearly': 179,
             'consumption': 10.7,
             'power': 150,
             'seats': '7',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 29.85*12 + 1200/7,  # Wartungsvertrag plus Winterreifen
             'millage_yearly': 15000,
             'holding_period': 7,  
             'image_url': 'cars/vw-sharan.png',
             'web_url': 'https://www.volkswagen.de/de/konfigurator.html/__app/sharan/sharan/highline.app?buildabilityStatus-app=buildable&category-app=private&carlineId-app=31605&salesGroupId-app=32850&trimName-app=Highline&modelId-app=7N24GY%24GYOIYOI%24GYOUYOU&modelVersion-app=0&modelYear-app=2022&exteriorId-app=F14+0Q0Q&interiorId-app=F56+++++BY&options-app=GPF2PF2-GWBEWBE-GWG1WG1-GWH3WH3-GYOWYOW-MAHV1M6-MKSUKA2-MSSH4KF',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': touran_testdrive,
             'hide': True
            }
           )
cars.append({'label': 'VW Touran',
             'acquisition_cost': 39986.31,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 20,
             'interest_rate': 1.91,
             'rest_value': 7500,
             'insurance_yearly': 317.53,
             'taxes_yearly': 87,
             'consumption': 7.4,
             'power': 150,
             'seats': '7',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 500,  # Wartungsvertrag plus Winterreifen
             'millage_yearly': 15000,
             'holding_period': 7,  
             'image_url': 'cars/vw-touran.png',
             'web_url': 'https://www.volkswagen.de/de/konfigurator.html/__app/touran/touran/comfortline.app?buildabilityStatus-app=buildable&category-app=private&carlineId-app=31000&salesGroupId-app=32600&trimName-app=Comfortline&modelId-app=5T13PZ%24GYORYOR&modelVersion-app=3&modelYear-app=2022&exteriorId-app=F14+5K5K&interiorId-app=F56+++++VE&options-app=MSTD7B2-GPG4PG4-MESSU9C-GPJ9PJ9-GPF6PF6-GPKJPKJ-GPLLPLL-MHKAKH7-GWLLWLL-GWL2WL2-GPM3PM3-GRBDRBD-MTRW3CX-MKSUKA1-MSAB4X4-GP19P19-GWQ1WQ1-GWWCWWC',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': touran_testdrive,
             'hide': False
            }
           )
cars.append({'label': 'VW Touran',
             'acquisition_cost': 38074.19,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'kurzzeit',
             'delivery_time': 20,
             'interest_rate': 1.91,
             'rest_value': 7000,
             'insurance_yearly': 426.01,
             'taxes_yearly': 87,
             'consumption': 7.4,
             'power': 150,
             'seats': '7',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 500,  # Wartungsvertrag plus Winterreifen
             'millage_yearly': 15000,
             'holding_period': 7,  
             'image_url': 'cars/vw-touran.png',
             'web_url': 'https://www.volkswagen.de/de/konfigurator.html/__app/touran/touran/comfortline.app?buildabilityStatus-app=buildable&category-app=private&carlineId-app=31000&salesGroupId-app=32600&trimName-app=Comfortline&modelId-app=5T13PZ%24GYORYOR&modelVersion-app=3&modelYear-app=2022&exteriorId-app=F14+5K5K&interiorId-app=F56+++++VE&options-app=MSTD7B2-GPG4PG4-MESSU9C-GPJ9PJ9-GPF6PF6-GPKJPKJ-GPLLPLL-MHKAKH7-GWLLWLL-GWL2WL2-GPM3PM3-GRBDRBD-MTRW3CX-MKSUKA1-MSAB4X4-GP19P19-GWQ1WQ1-GWWCWWC',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': touran_testdrive,
             'hide': False
            }
           )
cars.append({'label': 'VW Touran',
             'acquisition_cost': 38973.99,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'tageszulassung',
             'delivery_time': 20,
             'interest_rate': 1.91,
             'rest_value': 7000,
             'insurance_yearly': 317.53,
             'taxes_yearly': 87,
             'consumption': 7.4,
             'power': 150,
             'seats': '7',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 500,  # Wartungsvertrag plus Winterreifen
             'millage_yearly': 15000,
             'holding_period': 7,  
             'image_url': 'cars/vw-touran.png',
             'web_url': 'https://www.volkswagen.de/de/konfigurator.html/__app/touran/touran/comfortline.app?buildabilityStatus-app=buildable&category-app=private&carlineId-app=31000&salesGroupId-app=32600&trimName-app=Comfortline&modelId-app=5T13PZ%24GYORYOR&modelVersion-app=3&modelYear-app=2022&exteriorId-app=F14+5K5K&interiorId-app=F56+++++VE&options-app=MSTD7B2-GPG4PG4-MESSU9C-GPJ9PJ9-GPF6PF6-GPKJPKJ-GPLLPLL-MHKAKH7-GWLLWLL-GWL2WL2-GPM3PM3-GRBDRBD-MTRW3CX-MKSUKA1-MSAB4X4-GP19P19-GWQ1WQ1-GWWCWWC',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': touran_testdrive,
             'hide': False
            }
           )
cars.append({'label': 'VW Touran',
             'acquisition_cost': 41850.35,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 8000,
             'insurance_yearly': 373.39,
             'taxes_yearly': 232,
             'consumption': 6.3,
             'power': 150,
             'seats': '7',
             'fuel_price': d_0,
             'fuel_type': 'Diesel',
             'fuel_unit': 'l',
             'repairs_yearly': 30.59*12 + 1200/7,  # Wartungsvertrag plus Winterreifen
             'millage_yearly': 15000,
             'holding_period': 7,  
             'image_url': 'cars/vw-touran-neu-benzin.png',
             'web_url': 'https://www.volkswagen.de/de/konfigurator.html/__app/touran/touran/highline.app?buildabilityStatus-app=buildable&category-app=private&carlineId-app=31000&salesGroupId-app=32600&trimName-app=Highline&modelId-app=5T146Z%24GYORYOR&modelVersion-app=1&modelYear-app=2022&exteriorId-app=F14+0Q0Q&interiorId-app=F56+++++BG&options-app=GWBGWBG-GPG3PG3-MAHV1M6-GPF9PF9-GRBDRBD-MKSUKA1-MSSH4KF-GP19P19-MVTV9IJ-GWQ1WQ1',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': touran_testdrive,
             'hide': True
            }
           )
cars.append({'label': 'VW Tiguan Allspace',
             'acquisition_cost': 47445.12,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 9500,
             'insurance_yearly': 331.72,
             'taxes_yearly': 304,
             'consumption': 7.4,
             'power': 200,
             'seats': '7',
             'fuel_price': d_0,
             'fuel_type': 'Diesel',
             'fuel_unit': 'l',
             'repairs_yearly': 32.39*12 + 1200/7,  # Wartungsvertrag plus Winterreifen
             'millage_yearly': 15000,
             'holding_period': 7,  
             'image_url': 'cars/vw-tiguan-diesel.png',
             'web_url': 'https://www.volkswagen.de/de/konfigurator.html/__app/der-neue-tiguan-allspace/der-tiguan-allspace---standardmodelle/elegance.app?buildabilityStatus-app=buildable&category-app=private&carlineId-app=31160&salesGroupId-app=32700&trimName-app=Elegance&modelId-app=BJ247T%24GYORYOR&modelVersion-app=2&modelYear-app=2022&exteriorId-app=F14+0Q0Q&interiorId-app=F56+++++BG&options-app=GWBAWBA-GPG4PG4-MAHV1M6-GPFCPFC-GRBDRBD-MKSUKA2',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': [(0, 0), [r'', r'']],
             'hide': True
            }
           )
cars.append({'label': 'VW Tiguan Allspace',
             'acquisition_cost': 44398.11,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 9000,
             'insurance_yearly': 315.99,
             'taxes_yearly': 197,
             'consumption': 10.7,
             'power': 190,
             'seats': '7',
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 32.39*12 + 1200/7,  # Wartungsvertrag plus Winterreifen
             'millage_yearly': 15000,
             'holding_period': 7,  
             'image_url': 'cars/vw-tiguan-diesel.png',
             'web_url': 'https://www.volkswagen.de/de/konfigurator.html/__app/der-neue-tiguan-allspace/der-tiguan-allspace---standardmodelle/elegance.app?buildabilityStatus-app=buildable&category-app=private&carlineId-app=31160&salesGroupId-app=32700&trimName-app=Elegance&modelId-app=BJ247T%24GYORYOR&modelVersion-app=2&modelYear-app=2022&exteriorId-app=F14+0Q0Q&interiorId-app=F56+++++BG&options-app=GWBAWBA-GPG4PG4-MAHV1M6-GPFCPFC-GRBDRBD-MKSUKA2',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': True,
             'test_drive': [(0, 0), [r'', r'']],
             'hide': True
            }
           )
cars.append({'label': 'Skoda Superb',
             'acquisition_cost': 45490,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 10000,
             'insurance_yearly': 452.10,
             'taxes_yearly': 224,
             'consumption': 6.3,
             'power': 150,
             'seats': '5',
             'fuel_price': d_0,
             'fuel_type': 'Diesel',
             'fuel_unit': 'l',
             'repairs_yearly': 1000,  # Wartungsvertrag plus Winterreifen
             'millage_yearly': 15000,
             'holding_period': 7,  
             'image_url': 'cars/skoda-superb-neu.png',
             'web_url': 'https://cc.skoda-auto.com/deu/de-DE/summary-scenic?activePage=trimlines&color=M3M3&configurationId=C7JJPPH3&extraEquipments=MKSUKA2%7CMEPH7X2%7CGPB5PB5%7CGWD6WD6%7CGWD3WD3%7CGYOZYOZ&id=DEU%3Bskoda%3B2022%3B3V5R4D%3B1%3BMSNRSI1%5CGYO2YO2%3Bmda20220204020232%3Bde-DE%3B%3B63504%3B63564&interior=EX&modifiedPages=&snapshotVersion=e7313c2a-56a9-4fca-9893-113f5d9c9495&trimline=3VR%7CSportline6356463504&visitedPages=',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': [(0, 0), [r'', r'']],
             'hide': True
            }
           )
cars.append({'label': 'Skoda Kodiaq',
             'acquisition_cost': 44490,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'vehicle_registration': 'neu',
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 10000,
             'insurance_yearly': 343.81,
             'taxes_yearly': 252,
             'consumption': 6.75,
             'power': 150,
             'seats': '7',
             'fuel_price': d_0,
             'fuel_type': 'Diesel',
             'fuel_unit': 'l',
             'repairs_yearly': 1000,  # Wartungsvertrag plus Winterreifen
             'millage_yearly': 15000,
             'holding_period': 7,  
             'image_url': 'cars/skoda-kodiaq-neu.png',
             'web_url': 'https://cc.skoda-auto.com/deu/de-DE/summary-scenic?activePage=summary&color=M3M3&configurationId=C7JJQ31L&extraEquipments=GPB3PB3%7CGPHBPHB%7CGPXGPXG%7CGPZBPZB%7CGWD1WD1%7CGYOZYOZ%7CMEPH7X2%7CGPWFPWF&id=DEU%3Bskoda%3B2022%3BNS7R3D%3B1%3BGYO2YO2%3Bmda20220204020232%3Bde-DE%3B%3B62004%3B62184&interior=HG&modifiedPages=trimlines%7Ccolors%7Cengines%7Cextraequipments&snapshotVersion=7da1da0b-dc09-4983-955f-ad97327f6f35&trimline=NSR%7CSportline6218462004&visitedPages=trimlines%7Ccolors%7Cwheels%7Cinteriors%7Cengines%7Cextraequipments%7Cservices',
             'buy': True,  # else lease
             'fuel_estimated': True,
             'price_estimated': False,
             'test_drive': [(0, 9), [r'', r'Sehr großes und schönes Auto. Guter Fahrwerkskomfort. Sehr viel Platz. Sitze wenig seitenhalt, keine variablen Sitzwangen lieferbar.']],
             'hide': True
            }
           )

for car in cars:
    if car['buy']:
        factor = .5**(car['holding_period']/3)
        car['rest_value_thumb_value'] = r'Restwert nach Faustformel (Kaufpreis $\times$ %.1f\%%): %.2f \euro{}' % \
        (factor*100, car['acquisition_cost'] * factor)
    else:
        car['rest_value_thumb_value'] = r'Kein Restwert, da Leasingfahrzeug'

# %%
latex = ''

overview = pd.DataFrame()
overview.name='Monatliche Kosten im Verlgeich'

comparison_columns = ['Klasse', 'Preis Netto', 'Kredit', 'Antrieb', 'Leistung', 'Sitze', 'Lieferzeit',
                      'Baujahr', 'km Kauf', 'km Verkauf', 'Alter Verkauf',
                      'Raten', 'Vers.', 'Steuern', 'Repar.', 'Verbr.',
                      'Summe', 'Anzahlung', 'Restwert', 'Gesamtsumme', 'N', 'G']
comparison = pd.DataFrame(columns=comparison_columns)
comparison.index.name='Fahrzeug'

for car in cars:
    if car['hide'] and not SHOW_ALL:
        continue
        
    label=car['label']
    offer_class = car['vehicle_registration'][0] + \
                  str(car['power']) + \
                  ('k' if car['buy'] else 'l') + \
                  car['fuel_type'][0] + \
                  ('5' if car['seats'] == '5' else '7')
    
    if car['buy']:
        title = label + ', ' + car['vehicle_registration'] + ', ' + car['fuel_type'] + ', Kredit'
        bk_inputs = {key: car[key] for key in ['acquisition_cost', 
                                               'government_funding',
                                               'down_payment',
                                               'holding_period',
                                               'millage_yearly',
                                               'consumption',
                                               'fuel_price',
                                               'repairs_yearly',  # bis hierher Hauptkosten
                                               'interest_rate',
                                               'taxes_yearly',
                                               'insurance_yearly',
                                               'rest_value']}
        (input_values, calc_values) = Operating_Cost.buy(**bk_inputs).get_frames()
    else:
        
        title = label + ', ' + car['fuel_type'] + ', Leasing'
        bk_inputs = {key: car[key] for key in ['instalment', 
                                               'government_funding',
                                               'down_payment',
                                               'holding_period',
                                               'millage_yearly',
                                               'consumption',
                                               'fuel_price',
                                               'repairs_yearly',  # bis hierher Hauptkosten
                                               'taxes_yearly',
                                               'insurance_yearly']}
        (input_values, calc_values) = Operating_Cost.lease(**bk_inputs).get_frames()
        
    # pepper = sha256(car)[:12]
    input_values_path = images_path / (slugify(label) + '-' + offer_class + '-boundaries_' + '.png')
    calc_df_path = images_path / (slugify(label) + '-' + offer_class + '-calc_df_' + '.png')
    
    comparison = comparison.append(pd.DataFrame(data=[[offer_class,
                                                       car['acquisition_cost']-car['government_funding'],
                                                       (car['acquisition_cost']-car['down_payment']) * car['buy'],
                                                       car['fuel_type'],
                                                       car['power'],
                                                       car['seats'],
                                                       car['delivery_time'],
                                                       car['car_year'],
                                                       car['odometer'],
                                                       car['odometer'] + input_values.loc['Gesamtlaufleistung [km]', 'Randbedingungen'],
                                                       input_values.loc['Haltedauer [a]', 'Randbedingungen'] + 2022 - car['car_year'],
                                                       calc_values.loc['Raten', 'Monatlich'],
                                                       calc_values.loc['Versicherung', 'Monatlich'],
                                                       calc_values.loc['Steuern', 'Monatlich'],
                                                       calc_values.loc['Reparaturen', 'Monatlich'],
                                                       calc_values.loc['Verbrauch', 'Monatlich'],
                                                       calc_values.loc['Summe', 'Monatlich'],
                                                       calc_values.loc['Anzahlung', 'Monatlich'],
                                                       calc_values.loc['Restwert', 'Monatlich'],
                                                       calc_values.loc['Gesamtsumme', 'Monatlich'],
                                                       car['test_drive'][0][0],
                                                       car['test_drive'][0][1]
                                                      ]
                                                     ],
                                                columns=comparison_columns,
                                                index=[label]))
    if 'test_drive' in car:
        test_drive = r"""\begin{small}
\emph{Meinung Nataliya:} %d/10: %s
        
\emph{Meinung Grzegorz:} %d/10: %s
\end{small}""" % (car['test_drive'][0][0],
                  car['test_drive'][1][0],
                  car['test_drive'][0][1],
                  car['test_drive'][1][1]
                 )
    else:
        test_drive = r''
        
        
    if car['fuel_estimated']:
        fuel_estimated_string = r'\emph{Gesch\"atzter}'
    else:
        fuel_estimated_string = r'\emph{Realer}'
        
    
    latex = r"""%s
\twocolumn

\section*{%s}
\begin{center}
\includegraphics[width=0.5\textheight]{%s}
\null
\vspace{0.5cm}
\includegraphics[width=0.5\textheight]{%s}
\end{center}

\pagebreak
\begin{center}
\includegraphics[width=0.9\columnwidth]{%s}

# %s
\end{center}

\begin{itemize}
    \item LL/BJ: %d/%d, %s-Sitzer $\rightarrow$ Laufzeit: %.0f Jahre
    \item \href{%s}{Weblink}
    \item %s Spritpreis \"uber Haltedauer: %.2f \euro{}/%s
    \item Antrieb: %s, mit %d PS
    \item %s
\end{itemize}

# %s

\pagebreak

""" %(latex,
      title,
      input_values_path.as_posix(),
      calc_df_path.as_posix(),
      car['image_url'],
      label,
      car['odometer'],
      car['car_year'],
      car['seats'],
      car['holding_period'],
      car['web_url'].replace('#', '\#'),
      fuel_estimated_string,
      car['fuel_price'],
      car['fuel_unit'],
      car['fuel_type'],
      car['power'],
      car['rest_value_thumb_value'],
      test_drive
     )
    
    overview[label] = calc_values['Monatlich']
    
    input_values_path.parent.mkdir(parents=True, exist_ok=True)
    
    bold_row = pd.IndexSlice[calc_values.index[(calc_values.index == "Summe") | (calc_values.index == "Gesamtsumme")], :]
    light_row = pd.IndexSlice[calc_values.index[6:], :]
    
    dfi.export(input_values.round(2), str(input_values_path))
    dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#    display(input_values.round(2))
#    display(calc_values.style.applymap(df_style, subset=bold_row)\
#               .applymap(light_style, subset=light_row).set_precision(2))
#
# Out:
# C:\Users\Grzegorz\AppData\Local\Temp/ipykernel_12844/1140875974.py:162: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\

# %%
comparison_caption = r"""Vergleich der monatlichen Kosten bei \euro{} %.2f Anzahlung bei Kreditfinanzierung und \euro{} %.2f bei Leasing.

Gesch\"atzer Kraftstoffpreis: %.2f \euro{}/l Benzin, %.2f \euro{}/l Diesel bzw. %.2f \euro{}/kWh

""" % (
    down_payment_buy,
    down_payment_lease,
    b_0,
    d_0,
    e_0
)

#comparison.round(2)

# %%
comparison = comparison.reset_index().rename(columns={'index':'Fahrzeug'})
comparison.round(2)
# Out:
#         Fahrzeug   Klasse Preis Netto    Kredit Antrieb Leistung Sitze  \
# 0  Tesla Model 3  n325kS5       37970     22970   Strom      325     5
# 1      VW Touran  n150kB7    39986.31  24986.31  Benzin      150     7
# 2      VW Touran  k150kB7    38074.19  23074.19  Benzin      150     7
# 3      VW Touran  t150kB7    38973.99  23973.99  Benzin      150     7
#
#   Lieferzeit Baujahr km Kauf  ...  Vers.  Steuern  Repar.  Verbr.   Summe  \
# 0         16    2022       0  ...  45.33     0.00   21.43   58.12  417.24
# 1         20    2022       0  ...  26.46     7.25   41.67  151.70  545.10
# 2         20    2022       0  ...  35.50     7.25   41.67  151.70  529.80
# 3         20    2022       0  ...  26.46     7.25   41.67  151.70  532.21
#
#    Anzahlung  Restwert  Gesamtsumme  N  G
# 0     178.57   -101.19       494.62  0  0
# 1     178.57    -89.29       634.38  9  9
# 2     178.57    -83.33       625.04  9  9
# 3     178.57    -83.33       627.45  9  9
#
# ...

# %%
bold_column = pd.IndexSlice[comparison.index , ['Summe']]
index_column = pd.IndexSlice[comparison.index , ['Fahrzeug']]
light_column = pd.IndexSlice[comparison.index, 'Anzahlung':'Gesamtsumme']
#light_row = pd.IndexSlice[['BMW 318d Kredit', 'Nissan Micra Kredit', 'VW up! Leasing'], :]
format_column0 = pd.IndexSlice[comparison.index, 'Preis Netto':'Kredit']
format_column1 = pd.IndexSlice[comparison.index, 'Raten':'Gesamtsumme']
format_column2 = pd.IndexSlice[comparison.index, 'km Kauf':'Alter Verkauf']
format_column3 = pd.IndexSlice[comparison.index, 'N':'G']

overview_path_1 = images_path / 'overview1.png'

dfi.export(comparison.sort_values('Summe',
                                  ascending=True).style.applymap(df_style, subset=bold_column)\
                                                        .applymap(light_style, subset=light_column)\
                                                        .applymap(index_style, subset=index_column)\
                                                        .format('{:.2f}', subset=format_column0)\
                                                        .format('{:.2f}', subset=format_column1)\
                                                        .format('{:.0f}', subset=format_column2)\
                                                        .format('{:.0f}', subset=format_column3)\
                                                        .hide_index(),
           overview_path_1.as_posix())

#display(comparison.sort_values(comparison_columns[9],
#                               ascending=True).style.applymap(df_style, subset=bold_column)\
#                                                     .applymap(light_style, subset=light_column)\
#                                                     .format('{:.2f}', subset=format_column))

latex = r"""%s

\pagebreak

\onecolumn
\begin{figure}
\centering
# %s
\vspace{1em}
\includegraphics[width=0.95\columnwidth]{%s}
\end{figure}
\vfill 

""" % (latex,
       comparison_caption,
       overview_path_1.as_posix())

# %%
tex_file = r'report.tex'
with open(tex_file, 'w', encoding='utf-8') as fid:
    fid.write(r"""
\documentclass[landscape, DIV=99, 14pt]{scrartcl}

\renewcommand*{\familydefault}{\sfdefault}

\RequirePackage{graphicx}
\RequirePackage[utf8]{inputenc}
\RequirePackage{hyperref}
\RequirePackage[gen]{eurosym}
\RequirePackage{multirow}
\RequirePackage{booktabs}
\RequirePackage[table]{xcolor}
\RequirePackage{siunitx}
\RequirePackage{etoolbox}
\RequirePackage{etoolbox}

\setlength{\parindent}{0cm}

\robustify\bfseries
\robustify\itshape

\begin{document}
\sisetup{detect-all = true}

\twocolumn
\section*{Zusammenfassung BMW Kosten}
\null
\vspace{1cm}
\begin{center}
%%                           trim={<left> <lower> <right> <upper>}
\includegraphics[width=10cm, trim={4cm 0 4cm 5cm}]{images0/kosten_verteilung.png}
\end{center}

\includegraphics[width=1.4\columnwidth]{images0/kosten_maximus.png}

\pagebreak

\begin{itemize}
    \item Wertverlust
    \begin{itemize}
        \item Kaufpreis minus Verkaufspreis
    \end{itemize}
    \item Kraftstoffe
    \begin{itemize}
        \item Summe aller Tankstellenbesuche
    \end{itemize}
    \item Wartung und Reparatur
    \begin{itemize}
        \item Regul\"are Wartungsarbeiten (\"Olwechsel, etc)
        \item Reparaturen Aufgrund technischer Defekte
        \item Unfallsch\"aden
    \end{itemize}
    \item Versicherung
    \begin{itemize}
        \item J\"ahrlicher Versicherungsbeitrag
        \item Mobilit\"ats-Service
    \end{itemize}
    \item Steuern
    \begin{itemize}
            \item J\"ahrliche KFZ-Steuer
    \end{itemize}
\end{itemize}

# %s

\end{document}
""" % (latex))

# %%
os.system('pdflatex.exe %s' % (tex_file))
os.system('pdflatex.exe %s' % (tex_file))
os.system('start %spdf' % (tex_file[:-3]))
# Out:
# 0

# %%
#with open('test_table.html', 'w') as fid:
#    fid.write(calc_values.style.applymap(df_style, subset=bold_row)\
#              .applymap(light_style, subset=light_row).set_precision(2)\
#              .to_html())
#
