# %%
from bk import Operating_Cost
import pandas as pd
import dataframe_image as dfi
from slugify import slugify
from pathlib import Path

overview = pd.DataFrame()
overview.name='Monatliche Kosten im Verlgeich'

def df_style(val):
    # return "font-weight: bold; background: yellow"
    return "font-weight: bold;"

def light_style(val):
    return "color: grey"

# %%
#d_0 = 1.52  # Aktueller Dieselpreis 3.1.2022: 1.52
b_0 = 1.70  # Aktueller Benzinpreis 3.1.2022: 1.56
e_0 = 0.31  # Aktueller Strompreis 3.1.2022: 0.31 €/kWh

cars = []          
cars.append({'label': 'Tesla Model Y',
             'acquisition_cost': 52970,
             'government_funding': 5000,
             'down_payment': 15000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 9000,
             'insurance_yearly': 541.02,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-y.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': True  # else lease
})             
cars.append({'label': 'Tesla Model Y',
             'instalment': 379,
             'government_funding': 5000,
             'down_payment': 15000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 9000,
             'insurance_yearly': 541.02,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 4.0,   
             'image_url': 'cars/tesla-model-y.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': False  # else lease
})             
cars.append({'label': 'Tesla Model 3',
             'acquisition_cost': 43970,
             'government_funding': 6000,
             'down_payment': 13000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 8500,
             'insurance_yearly': 601.02,
             'taxes_yearly': 0,
             'consumption': 15.,
             'power': 325,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-3.jpg',
             'web_url': 'https://www.tesla.com/de_de/model3/design#overview',
             'buy': True  # else lease
})          
cars.append({'label': 'Tesla Model 3',
             'instalment': 272,
             'government_funding': 6000,
             'down_payment': 13000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 8500,
             'insurance_yearly': 601.02,
             'taxes_yearly': 0,
             'consumption': 15.,
             'power': 325,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 4.0,   
             'image_url': 'cars/tesla-model-3.jpg',
             'web_url': 'https://www.tesla.com/de_de/model3/design#overview',
             'buy': False  # else lease
})
cars.append({'label': 'Mazda 6',
             'acquisition_cost': 30643.19,
             'government_funding': 0,
             'down_payment': 10000,
             'car_year': 2022,
             'delivery_time': 20,
             'interest_rate': 2.,
             'rest_value': 6000,
             'insurance_yearly': 601.16,
             'taxes_yearly': 136,
             'consumption': 8.,
             'power': 192,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,  
             'image_url': 'cars/mazda-6-neu.png',
             'web_url': 'https://konfigurator.meinauto.de/mazda/neuwagen/48-6/angebote/6-kombi/konfigurator/#!/extras/exclusive-line/8846370/10,11/private/65352-5416-204698/984/61c9aa657e74c/cash-purchase/32545--287374/48,0,10000,0,0,0,0,0,',
             'buy': True  # else lease
})
cars.append({'label': 'Mazda 6',
             'instalment': 284.70,
             'government_funding': 0,
             'down_payment': 3000,
             'car_year': 2022,
             'delivery_time': 60,
             'interest_rate': 3.,
             'rest_value': 3000,
             'insurance_yearly': 601.16,
             'taxes_yearly': 136,
             'consumption': 8.,
             'power': 192,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3,  
             'image_url': 'cars/mazda-6-neu.png',
             'web_url': 'https://konfigurator.meinauto.de/mazda/neuwagen/48-6/angebote/6-kombi/konfigurator/#!/extras/exclusive-line/8846370/10,11,15/private/65352-5416-204698/984/61c9aa657e74c/leasing/16040--249432/36,3000,15000,0,0,0,0,0,',
             'buy': False  # else lease
})
cars.append({'label': 'Kia ceed',
             'acquisition_cost': 25209.43,
             'government_funding': 0,
             'down_payment': 10000,
             'car_year': 2022,
             'delivery_time': 52,
             'interest_rate': 3.,
             'rest_value': 5000,
             'insurance_yearly': 381.08,
             'taxes_yearly': 136,
             'consumption': 7.,
             'power': 160,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,
             'image_url': 'cars/kia-ceed-sportswagon.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/extras/spirit/8865371/3,11,27/private/109347-4167-291321/1321/61d21ce73c5db/cash-purchase/109348-8088-291322/48,0,10000,0,0,0,0,0,',
             'buy': True  # else lease
})
cars.append({'label': 'Kia ceed',
             'instalment': 227.42,
             'government_funding': 0,
             'down_payment': 3000,
             'car_year': 2022,
             'delivery_time': 52,
             'interest_rate': 3.,
             'rest_value': 3000,
             'insurance_yearly': 381.08,
             'taxes_yearly': 136,
             'consumption': 7.,
             'power': 160,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3.0,
             'image_url': 'cars/kia-ceed-sportswagon.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/extras/spirit/8865371/3,11,27/private/109347-4167-291321/1321/61d21ce73c5db/leasing/109348-8088-291322/36,3000,15000,0,0,0,0,0,',
             'buy': False  # else lease
})

# %%
latex = ''
for car in cars:
    if car['buy']:
        label=car['label'] + ' Kaufen'
        bk_inputs = {key: car[key] for key in ['acquisition_cost', 
                                               'government_funding',
                                               'down_payment',
                                               'holding_period',
                                               'millage_yearly',
                                               'consumption',
                                               'fuel_price',
                                               'repairs_yearly',  # bis hierher Hauptkosten
                                               'interest_rate',
                                               'taxes_yearly',
                                               'insurance_yearly',
                                               'rest_value']}
        (input_values, calc_values) = Operating_Cost.buy(**bk_inputs).get_frames()
    else:
        label=car['label'] + ' Leasing'
        bk_inputs = {key: car[key] for key in ['instalment', 
                                               'government_funding',
                                               'down_payment',
                                               'holding_period',
                                               'millage_yearly',
                                               'consumption',
                                               'fuel_price',
                                               'repairs_yearly',  # bis hierher Hauptkosten
                                               'taxes_yearly',
                                               'insurance_yearly']}
        (input_values, calc_values) = Operating_Cost.lease(**bk_inputs).get_frames()
        
    input_values_path = Path('images/' + slugify(label) + '-boundaries.png')
    calc_df_path = Path('images/' + slugify(label) + '-calc_df.png')
    
    latex = r"""%s
\twocolumn

\section*{%s}
\begin{center}
\includegraphics[width=0.5\textheight]{%s}
\null
\vspace{0.5cm}
\includegraphics[width=0.5\textheight]{%s}
\end{center}

\pagebreak
\null
\vspace{2cm}
\begin{center}
\includegraphics[width=0.9\columnwidth]{%s}

# %s
\end{center}

\begin{itemize}
    \item Baujahr: %d $\rightarrow$ Laufzeit: %.0f Jahre
    \item \href{%s}{Weblink}
    \item \emph{Gesch\"atzter} Spritpreis \"uber Haltedauer: %.2f \euro{}/l
    \item Antrieb: %s, mit %d PS
\end{itemize}

\pagebreak

""" %(latex,
      label,
      input_values_path.as_posix(),
      calc_df_path.as_posix(),
      car['image_url'],
      label,
      car['car_year'],
      car['holding_period'],
      car['web_url'].replace('#', '\#'),
      car['fuel_price'],
      car['fuel_type'],
      car['power']
     )

    # calc_values.loc['Lieferzeit', :] = car['delivery_time']
    # calc_values.loc['Kraftstoffsorte', :] = car['fuel_type']
    # calc_values = calc_values.reindex(index = ['Lieferzeit',
    #                                            'Kraftstoffsorte',
    #                                            'Anschaffungskosten',
    #                                            'Zinsen',
    #                                            'Versicherung',
    #                                            'Steuern',
    #                                            'Reparaturen',
    #                                            'Verbrauch',
    #                                            'SUMME',
    #                                            'Restwert',
    #                                            'Summe mit Restwert'
    #                                           ])
    
    overview[label] = calc_values['Monatlich']
    
    input_values_path.parent.mkdir(parents=True, exist_ok=True)
    
    bold_row = pd.IndexSlice[calc_values.index[(calc_values.index == "Summe") | (calc_values.index == "Gesamtsumme")], :]
    light_row = pd.IndexSlice[calc_values.index[6:], :]
    
    dfi.export(input_values.round(2), str(input_values_path))
    dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
    #display(input_values.round(2))
    #display(calc_values.style.applymap(df_style, subset=sum_row).set_precision(2))
# Out:
# <ipython-input-52-ba261a9ff8c5>:101: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\

# %%
brk = 8

overview_path_1 = 'images/overview1.png'
overview_path_2 = 'images/overview2.png'

# sum_row = pd.IndexSlice[calc_values.index[(calc_values.index == "Summe") | (calc_values.index == "Gesamtsumme")], :]

dfi.export(overview.iloc[:, 0:brk ].style.applymap(df_style, subset=sum_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2), overview_path_1)
dfi.export(overview.iloc[:, brk: ].style.applymap(df_style, subset=sum_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2), overview_path_2)

display(overview.iloc[:, 0:brk ].style.applymap(df_style, subset=sum_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2))
display(overview.iloc[:, brk: ].style.applymap(df_style, subset=sum_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2))

latex = r"""%s

\pagebreak

\onecolumn
\null
\vfill 
\begin{center}
\includegraphics[width=0.95\columnwidth]{%s}
\null
\vspace{0.5cm}
%% \includegraphics[width=0.95\columnwidth]{%s}
\end{center}
\vfill 
""" % (latex,
      overview_path_1,
      overview_path_2)
# Out:
# <ipython-input-53-4cf19acd9d19>:8: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(overview.iloc[:, 0:brk ].style.applymap(df_style, subset=sum_row)\
# <ipython-input-53-4cf19acd9d19>:10: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(overview.iloc[:, brk: ].style.applymap(df_style, subset=sum_row)\
# <ipython-input-53-4cf19acd9d19>:13: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(overview.iloc[:, 0:brk ].style.applymap(df_style, subset=sum_row)\
# <style type="text/css">
# #T_0978f_row5_col0, #T_0978f_row5_col1, #T_0978f_row5_col2, #T_0978f_row5_col3, #T_0978f_row5_col4, #T_0978f_row5_col5, #T_0978f_row5_col6, #T_0978f_row5_col7 {
#   font-weight: bold;
# }
# #T_0978f_row6_col0, #T_0978f_row6_col1, #T_0978f_row6_col2, #T_0978f_row6_col3, #T_0978f_row6_col4, #T_0978f_row6_col5, #T_0978f_row6_col6, #T_0978f_row6_col7, #T_0978f_row7_col0, #T_0978f_row7_col1, #T_0978f_row7_col2, #T_0978f_row7_col3, #T_0978f_row7_col4, #T_0978f_row7_col5, #T_0978f_row7_col6, #T_0978f_row7_col7 {
#   color: grey;
# }
# #T_0978f_row8_col0, #T_0978f_row8_col1, #T_0978f_row8_col2, #T_0978f_row8_col3, #T_0978f_row8_col4, #T_0978f_row8_col5, #T_0978f_row8_col6, #T_0978f_row8_col7 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_0978f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Tesla Model Y Kaufen</th>
#       <th class="col_heading level0 col1" >Tesla Model Y Leasing</th>
#       <th class="col_heading level0 col2" >Tesla Model 3 Kaufen</th>
#       <th class="col_heading level0 col3" >Tesla Model 3 Leasing</th>
#       <th class="col_heading level0 col4" >Mazda 6 Kaufen</th>
#       <th class="col_heading level0 col5" >Mazda 6 Leasing</th>
#       <th class="col_heading level0 col6" >Kia ceed Kaufen</th>
#       <th class="col_heading level0 col7" >Kia ceed Leasing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0978f_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_0978f_row0_col0" class="data row0 col0" >484.78</td>
#       <td id="T_0978f_row0_col1" class="data row0 col1" >379.00</td>
#       <td id="T_0978f_row0_col2" class="data row0 col2" >395.41</td>
#       <td id="T_0978f_row0_col3" class="data row0 col3" >272.00</td>
#       <td id="T_0978f_row0_col4" class="data row0 col4" >263.56</td>
#       <td id="T_0978f_row0_col5" class="data row0 col5" >284.70</td>
#       <td id="T_0978f_row0_col6" class="data row0 col6" >200.97</td>
#       <td id="T_0978f_row0_col7" class="data row0 col7" >227.42</td>
#     </tr>
#     <tr>
#       <th id="T_0978f_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_0978f_row1_col0" class="data row1 col0" >45.09</td>
#       <td id="T_0978f_row1_col1" class="data row1 col1" >45.09</td>
#       <td id="T_0978f_row1_col2" class="data row1 col2" >50.08</td>
#       <td id="T_0978f_row1_col3" class="data row1 col3" >50.09</td>
#       <td id="T_0978f_row1_col4" class="data row1 col4" >50.10</td>
#       <td id="T_0978f_row1_col5" class="data row1 col5" >50.10</td>
#       <td id="T_0978f_row1_col6" class="data row1 col6" >31.76</td>
#       <td id="T_0978f_row1_col7" class="data row1 col7" >31.76</td>
#     </tr>
#     <tr>
#       <th id="T_0978f_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_0978f_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_0978f_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_0978f_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_0978f_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_0978f_row2_col4" class="data row2 col4" >11.33</td>
#       <td id="T_0978f_row2_col5" class="data row2 col5" >11.33</td>
#       <td id="T_0978f_row2_col6" class="data row2 col6" >11.33</td>
#       <td id="T_0978f_row2_col7" class="data row2 col7" >11.33</td>
#     </tr>
#     <tr>
#       <th id="T_0978f_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_0978f_row3_col0" class="data row3 col0" >41.67</td>
#       <td id="T_0978f_row3_col1" class="data row3 col1" >41.67</td>
#       <td id="T_0978f_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_0978f_row3_col3" class="data row3 col3" >41.67</td>
#       <td id="T_0978f_row3_col4" class="data row3 col4" >75.00</td>
#       <td id="T_0978f_row3_col5" class="data row3 col5" >75.00</td>
#       <td id="T_0978f_row3_col6" class="data row3 col6" >75.00</td>
#       <td id="T_0978f_row3_col7" class="data row3 col7" >75.00</td>
#     </tr>
#     <tr>
#       <th id="T_0978f_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_0978f_row4_col0" class="data row4 col0" >62.00</td>
#       <td id="T_0978f_row4_col1" class="data row4 col1" >62.00</td>
#       <td id="T_0978f_row4_col2" class="data row4 col2" >58.12</td>
#       <td id="T_0978f_row4_col3" class="data row4 col3" >58.12</td>
#       <td id="T_0978f_row4_col4" class="data row4 col4" >170.00</td>
#       <td id="T_0978f_row4_col5" class="data row4 col5" >170.00</td>
#       <td id="T_0978f_row4_col6" class="data row4 col6" >148.75</td>
#       <td id="T_0978f_row4_col7" class="data row4 col7" >148.75</td>
#     </tr>
#     <tr>
#       <th id="T_0978f_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_0978f_row5_col0" class="data row5 col0" >633.53</td>
#       <td id="T_0978f_row5_col1" class="data row5 col1" >527.75</td>
#       <td id="T_0978f_row5_col2" class="data row5 col2" >545.28</td>
#       <td id="T_0978f_row5_col3" class="data row5 col3" >421.88</td>
#       <td id="T_0978f_row5_col4" class="data row5 col4" >569.99</td>
#       <td id="T_0978f_row5_col5" class="data row5 col5" >591.13</td>
#       <td id="T_0978f_row5_col6" class="data row5 col6" >467.81</td>
#       <td id="T_0978f_row5_col7" class="data row5 col7" >494.26</td>
#     </tr>
#     <tr>
#       <th id="T_0978f_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_0978f_row6_col0" class="data row6 col0" >119.05</td>
#       <td id="T_0978f_row6_col1" class="data row6 col1" >208.33</td>
#       <td id="T_0978f_row6_col2" class="data row6 col2" >83.33</td>
#       <td id="T_0978f_row6_col3" class="data row6 col3" >145.83</td>
#       <td id="T_0978f_row6_col4" class="data row6 col4" >119.05</td>
#       <td id="T_0978f_row6_col5" class="data row6 col5" >83.33</td>
#       <td id="T_0978f_row6_col6" class="data row6 col6" >119.05</td>
#       <td id="T_0978f_row6_col7" class="data row6 col7" >83.33</td>
#     </tr>
#     <tr>
#       <th id="T_0978f_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_0978f_row7_col0" class="data row7 col0" >-107.14</td>
#       <td id="T_0978f_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_0978f_row7_col2" class="data row7 col2" >-101.19</td>
#       <td id="T_0978f_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_0978f_row7_col4" class="data row7 col4" >-71.43</td>
#       <td id="T_0978f_row7_col5" class="data row7 col5" >0.00</td>
#       <td id="T_0978f_row7_col6" class="data row7 col6" >-59.52</td>
#       <td id="T_0978f_row7_col7" class="data row7 col7" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_0978f_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_0978f_row8_col0" class="data row8 col0" >645.44</td>
#       <td id="T_0978f_row8_col1" class="data row8 col1" >736.09</td>
#       <td id="T_0978f_row8_col2" class="data row8 col2" >527.43</td>
#       <td id="T_0978f_row8_col3" class="data row8 col3" >567.71</td>
#       <td id="T_0978f_row8_col4" class="data row8 col4" >617.61</td>
#       <td id="T_0978f_row8_col5" class="data row8 col5" >674.46</td>
#       <td id="T_0978f_row8_col6" class="data row8 col6" >527.33</td>
#       <td id="T_0978f_row8_col7" class="data row8 col7" >577.59</td>
#     </tr>
#   </tbody>
# </table>
# <ipython-input-53-4cf19acd9d19>:15: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   display(overview.iloc[:, brk: ].style.applymap(df_style, subset=sum_row)\
# <style type="text/css">
# </style>
# <table id="T_06465_">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06465_level0_row0" class="row_heading level0 row0" >Raten</th>
#     </tr>
#     <tr>
#       <th id="T_06465_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#     </tr>
#     <tr>
#       <th id="T_06465_level0_row2" class="row_heading level0 row2" >Steuern</th>
#     </tr>
#     <tr>
#       <th id="T_06465_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#     </tr>
#     <tr>
#       <th id="T_06465_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#     </tr>
#     <tr>
#       <th id="T_06465_level0_row5" class="row_heading level0 row5" >Summe</th>
#     </tr>
#     <tr>
#       <th id="T_06465_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#     </tr>
#     <tr>
#       <th id="T_06465_level0_row7" class="row_heading level0 row7" >Restwert</th>
#     </tr>
#     <tr>
#       <th id="T_06465_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#     </tr>
#   </tbody>
# </table>

# %%
with open('report_l.tex', 'w') as fid:
    fid.write(r"""
\documentclass[landscape, DIV=99, 14pt]{scrartcl}

\renewcommand*{\familydefault}{\sfdefault}

\RequirePackage{graphicx}
\RequirePackage{hyperref}
\RequirePackage[gen]{eurosym}

\begin{document}

# %s

\end{document}
""" % (latex))
