# %%
import os
import pandas as pd
import dataframe_image as dfi
from slugify import slugify
from pathlib import Path
from bk import Operating_Cost

def df_style(val):
    # return "font-weight: bold; background: yellow"
    return "font-weight: bold;"

def light_style(val):
    return "color: grey"

# %%
#d_0 = 1.52  # Aktueller Dieselpreis 3.1.2022: 1.52
b_0 = 1.70  # Aktueller Benzinpreis 3.1.2022: 1.56
e_0 = 0.31  # Aktueller Strompreis 3.1.2022: 0.31 €/kWh
# e_0 = 0.79  # Superchargin worst case

down_payment_buy = 15000
down_payment_lease = 3000


cars = []       
cars.append({'label': 'BMW 318d 2011',
             'acquisition_cost': 16903,
             'government_funding': 0,
             'down_payment': 0,
             'car_year': 2011,
             'odometer': 253640,
             'delivery_time': 0,
             'interest_rate': 0.,
             'rest_value': 3000,
             'insurance_yearly': 775,
             'taxes_yearly': 230,
             'consumption': 6.38,
             'power': 137,
             'fuel_price': 1.19,  # Durchschnittlicher Dieselpreis seit 2015
             'fuel_type': 'Diesel',
             'fuel_unit': 'l',
             'repairs_yearly': 2016.32,
             'millage_yearly': 26000,
             'holding_period': 6.85,
             'image_url': 'cars/bmw-3er-maximus.png',
             'web_url': 'https://de.wikipedia.org/wiki/BMW_E90',
             'buy': True,  # else lease
             'estimate': False
            }
           )
cars.append({'label': 'Nissan Micra 2010',
             'acquisition_cost': 3300,
             'government_funding': 0,
             'down_payment': 3300,
             'car_year': 2011,
             'odometer': 122000,
             'delivery_time': 0,
             'interest_rate': 0.,
             'rest_value': 2000,
             'insurance_yearly': 361.76,
             'taxes_yearly': 64,
             'consumption': 6.6,
             'power': 65,
             'fuel_price': 1.36,  # Durchschnittlicher Dieselpreis seit 2016
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 395.40,
             'millage_yearly': 3216,
             'holding_period': 5.5,  
             'image_url': 'cars/nissan-micra.jpg',
             'web_url': 'https://de.wikipedia.org/wiki/Nissan_Micra#Micra_(K12,_2003%E2%80%932010)',
             'buy': True,  # else lease
             'estimate': False
            }
           )
cars.append({'label': 'Tesla Model Y',
             'acquisition_cost': 52970,
             'government_funding': 5000,
             'down_payment': down_payment_buy + 5000,
             'car_year': 2022,
             'odometer': 0,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 10000,
             'insurance_yearly': 459.78,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-y.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Tesla Model Y',
             'acquisition_cost': 52970,
             'instalment': 533,
             'government_funding': 5000,
             'down_payment': down_payment_lease + 5000,
             'car_year': 2022,
             'odometer': 0,
             'delivery_time': 4,
             'rest_value': 9000,
             'insurance_yearly': 566.90,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 4.0,   
             'image_url': 'cars/tesla-model-y-leasing.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Tesla Model 3',
             'acquisition_cost': 43970,
             'government_funding': 6000,
             'down_payment': down_payment_buy + 6000,
             'car_year': 2022,
             'odometer': 0,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 8500,
             'insurance_yearly': 544,
             'taxes_yearly': 0,
             'consumption': 15.,
             'power': 325,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-3.jpg',
             'web_url': 'https://www.tesla.com/de_de/model3/design#overview',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Tesla Model 3',
             'acquisition_cost': 43970,
             'instalment': 360,
             'government_funding': 6000,
             'down_payment': down_payment_lease + 6000,
             'car_year': 2022,
             'odometer': 0,
             'delivery_time': 4,
             'insurance_yearly': 673.60,
             'taxes_yearly': 0,
             'consumption': 15.,
             'power': 325,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 4.0,   
             'image_url': 'cars/tesla-model-3-leasing.jpg',
             'web_url': 'https://www.tesla.com/de_de/model3/design#overview',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Hyundai Ioniq 5',
             'acquisition_cost': 48536.05,
             'government_funding': 6000,
             'down_payment': down_payment_buy + 6000,
             'car_year': 2022,
             'odometer': 0,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 8500,
             'insurance_yearly': 497.86+9.6,
             'taxes_yearly': 0,
             'consumption': 26.1,
             'power': 231,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/hyundai-ioniq-5.png',
             'web_url': 'https://konfigurator.meinauto.de/hyundai/neuwagen/ioniq/angebote/ioniq-5/konfigurator/#!/extras/-/8865700/14,19,41/private/104690-6897-293274/4864/61e90b0c48e55/cash-purchase/104690-6897-293274/24,9000,15000,0,0,0,0,0,',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Hyundai Ioniq 5',
             'acquisition_cost': 48536.05,
             'instalment': 455.10,
             'government_funding': 6000,
             'down_payment': down_payment_lease + 6000,
             'car_year': 2022,
             'odometer': 0,
             'delivery_time': 4,
             'insurance_yearly': 624.53,
             'taxes_yearly': 0,
             'consumption': 26.1,
             'power': 231,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 2.0,   
             'image_url': 'cars/hyundai-ioniq-5.png',
             'web_url': 'https://konfigurator.meinauto.de/hyundai/neuwagen/ioniq/angebote/ioniq-5/konfigurator/#!/extras/-/8865700/14,19,41/private/104690-6897-293274/4864/61e90b0c48e55/leasing/104690-6897-293274/24,9000,15000,0,0,0,0,0,',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Kia ceed',
             'acquisition_cost': 25209.43,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'odometer': 0,
             'delivery_time': 52,
             'interest_rate': 2.,
             'rest_value': 5000,
             'insurance_yearly': 325.99,
             'taxes_yearly': 107,
             'consumption': 7.,
             'power': 160,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,
             'image_url': 'cars/kia-ceed-sportswagon.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/extras/spirit/8865371/3,11,27/private/109347-4167-291321/1321/61d21ce73c5db/cash-purchase/109348-8088-291322/48,0,10000,0,0,0,0,0,',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Kia ceed',
             'acquisition_cost': 25209.43,
             'instalment': 227.42,
             'government_funding': 0,
             'down_payment': down_payment_lease,
             'car_year': 2022,
             'odometer': 0,
             'delivery_time': 52,
             'rest_value': 3000,
             'insurance_yearly': 395.58,
             'taxes_yearly': 107,
             'consumption': 7.,
             'power': 160,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3.0,
             'image_url': 'cars/kia-ceed-sportswagon-leasing.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/extras/spirit/8865371/3,11,27/private/109347-4167-291321/1321/61d21ce73c5db/leasing/109348-8088-291322/36,3000,15000,0,0,0,0,0,',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'VW Passat',
             'acquisition_cost': 30230.0,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2021,
             'odometer': 24800,
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 6000,
             'insurance_yearly': 351.35,
             'taxes_yearly': 98,
             'consumption': 7.5,
             'power': 150,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,
             'image_url': 'cars/vw-passat.jpg',
             'web_url': 'https://www.autosuche.de/auto/REVVNDQ3NjgwMjc5NzI=?t_manuf=BQ&t_petr=B&t_model=BQBM&t_gear=A&t_ez_fr=2020&t_pe_fr=35000&sort=PRICE_SALE&sortdirection=ASC&viewMode=tile',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'VW Passat',
             'acquisition_cost': 30230.0,
             'instalment': 194.18 + 4557.50/36,
             'government_funding': 0,
             'down_payment': down_payment_lease,
             'car_year': 2021,
             'odometer': 24800,
             'delivery_time': 0,
             'rest_value': 3000,
             'insurance_yearly': 423.07,
             'taxes_yearly': 98,
             'consumption': 7.5,
             'power': 150,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3.0,
             'image_url': 'cars/vw-passat-leasing.jpg',
             'web_url': 'https://www.autosuche.de/auto/REVVNDQ3NjgwMjc5NzI=?t_manuf=BQ&t_petr=B&t_model=BQBM&t_gear=A&t_ez_fr=2020&t_pe_fr=35000&sort=PRICE_SALE&sortdirection=ASC&viewMode=tile',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Mercedes C 200',
             'acquisition_cost': 27690,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2019,
             'odometer': 54128,
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 5500,
             'insurance_yearly': 533.68,
             'taxes_yearly': 144,
             'consumption': 8.45,
             'power': 184,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 4.0,  
             'image_url': 'cars/mercedes-c-200-t-leasing.png',
             'web_url': 'https://suchen.mobile.de/fahrzeuge/details.html?action=parkItem&id=327113608',
             'buy': True,  # else lease
             'estimate': True
            }
           )     


for car in cars:
    if car['buy']:
        factor = .5**(car['holding_period']/3)
        car['rest_value_thumb_value'] = r'Restwert nach Faustformel (Neupreis $\times$ %.1f\%%): %.2f \euro{}' % \
        (factor*100, car['acquisition_cost'] * factor)
    else:
        car['rest_value_thumb_value'] = r'Kein Restwert, da Leasingfahrzeug'

# %%
latex = ''

overview = pd.DataFrame()
overview.name='Monatliche Kosten im Verlgeich'

comparison_columns = ['Preis Netto', 'Baujahr', 'Kilometerstand', 'Antrieb', 
                      'Raten', 'Versicherung', 'Steuern', 'Reparaturen', 'Verbrauch',
                      'Summe', 'Anzahlung', 'Restwert', 'Gesamtsumme']
comparison = pd.DataFrame(columns=comparison_columns)
comparison.index.name='Fahrzeug'

for car in cars:
    if car['estimate']:
        estimate_string = r'\emph{Gesch\"atzter}'
    else:
        estimate_string = r'\emph{Realer}'
        
    if car['buy']:
        label=car['label'] + ' Kredit'
        bk_inputs = {key: car[key] for key in ['acquisition_cost', 
                                               'government_funding',
                                               'down_payment',
                                               'holding_period',
                                               'millage_yearly',
                                               'consumption',
                                               'fuel_price',
                                               'repairs_yearly',  # bis hierher Hauptkosten
                                               'interest_rate',
                                               'taxes_yearly',
                                               'insurance_yearly',
                                               'rest_value']}
        (input_values, calc_values) = Operating_Cost.buy(**bk_inputs).get_frames()
    else:
        label=car['label'] + ' Leasing'
        bk_inputs = {key: car[key] for key in ['instalment', 
                                               'government_funding',
                                               'down_payment',
                                               'holding_period',
                                               'millage_yearly',
                                               'consumption',
                                               'fuel_price',
                                               'repairs_yearly',  # bis hierher Hauptkosten
                                               'taxes_yearly',
                                               'insurance_yearly']}
        (input_values, calc_values) = Operating_Cost.lease(**bk_inputs).get_frames()
        
    input_values_path = Path('images/' + slugify(label) + '-boundaries.png')
    calc_df_path = Path('images/' + slugify(label) + '-calc_df.png')
    
    comparison = comparison.append(pd.DataFrame(data=[[car['acquisition_cost'],
                                                      car['car_year'],
                                                      car['odometer'],
                                                      car['fuel_type'],
                                                      calc_values.loc['Raten', 'Monatlich'],
                                                      calc_values.loc['Versicherung', 'Monatlich'],
                                                      calc_values.loc['Steuern', 'Monatlich'],
                                                      calc_values.loc['Reparaturen', 'Monatlich'],
                                                      calc_values.loc['Verbrauch', 'Monatlich'],
                                                      calc_values.loc['Summe', 'Monatlich'],
                                                      calc_values.loc['Anzahlung', 'Monatlich'],
                                                      calc_values.loc['Restwert', 'Monatlich'],
                                                      calc_values.loc['Gesamtsumme', 'Monatlich']]],
                                                columns=comparison_columns,
                                                index=[label]))

    latex = r"""%s
\twocolumn

\section*{%s}
\begin{center}
\includegraphics[width=0.5\textheight]{%s}
\null
\vspace{0.5cm}
\includegraphics[width=0.5\textheight]{%s}
\end{center}

\pagebreak
\null
\vspace{2cm}
\begin{center}
\includegraphics[width=0.9\columnwidth]{%s}

# %s
\end{center}

\begin{itemize}
    \item Baujahr: %d $\rightarrow$ Laufzeit: %.0f Jahre
    \item \href{%s}{Weblink}
    \item %s Spritpreis \"uber Haltedauer: %.2f \euro{}/%s
    \item Antrieb: %s, mit %d PS
    \item %s
\end{itemize}

\pagebreak

""" %(latex,
      label,
      input_values_path.as_posix(),
      calc_df_path.as_posix(),
      car['image_url'],
      label,
      car['car_year'],
      car['holding_period'],
      car['web_url'].replace('#', '\#'),
      estimate_string,
      car['fuel_price'],
      car['fuel_unit'],
      car['fuel_type'],
      car['power'],
      car['rest_value_thumb_value']
     )

    # calc_values.loc['Lieferzeit', :] = car['delivery_time']
    # calc_values.loc['Kraftstoffsorte', :] = car['fuel_type']
    # calc_values = calc_values.reindex(index = ['Lieferzeit',
    #                                            'Kraftstoffsorte',
    #                                            'Anschaffungskosten',
    #                                            'Zinsen',
    #                                            'Versicherung',
    #                                            'Steuern',
    #                                            'Reparaturen',
    #                                            'Verbrauch',
    #                                            'SUMME',
    #                                            'Restwert',
    #                                            'Summe mit Restwert'
    #                                           ])
    
    overview[label] = calc_values['Monatlich']
    
    input_values_path.parent.mkdir(parents=True, exist_ok=True)
    
    bold_row = pd.IndexSlice[calc_values.index[(calc_values.index == "Summe") | (calc_values.index == "Gesamtsumme")], :]
    light_row = pd.IndexSlice[calc_values.index[6:], :]
    
    dfi.export(input_values.round(2), str(input_values_path))
    dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#    display(input_values.round(2))
#    display(calc_values.style.applymap(df_style, subset=bold_row)\
#               .applymap(light_style, subset=light_row).set_precision(2))
#
# Out:
# <ipython-input-51-2821a586fd93>:136: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\

# %%
comparison
# Out:
#                          Preis Netto Baujahr Kilometerstand Antrieb  \
# BMW 318d 2011 Kredit           16903    2011         253640  Diesel
# Nissan Micra 2010 Kredit        3300    2011         122000  Benzin
# Tesla Model Y Kredit           52970    2022              0   Strom
# Tesla Model Y Leasing          52970    2022              0   Strom
# Tesla Model 3 Kredit           43970    2022              0   Strom
# Tesla Model 3 Leasing          43970    2022              0   Strom
# Hyundai Ioniq 5 Kredit      48536.05    2022              0   Strom
# Hyundai Ioniq 5 Leasing     48536.05    2022              0   Strom
# Kia ceed Kredit             25209.43    2022              0  Benzin
# Kia ceed Leasing            25209.43    2022              0  Benzin
# VW Passat Kredit             30230.0    2021          24800  Benzin
# VW Passat Leasing            30230.0    2021          24800  Benzin
# Mercedes C 200 Kredit          27690    2019          54128  Benzin
#
#                                Raten  Versicherung    Steuern  Reparaturen  \
# BMW 318d 2011 Kredit      205.632603     64.583333  19.166667   168.026667
# Nissan Micra 2010 Kredit    0.000000     30.146667   5.333333    32.950000
# Tesla Model Y Kredit      420.942333     38.315000   0.000000    41.666667
# Tesla Model Y Leasing     533.000000     47.241667   0.000000    41.666667
# Tesla Model 3 Kredit      293.267983     45.333333   0.000000    41.666667
# Tesla Model 3 Leasing     360.000000     56.133333   0.000000    41.666667
# Hyundai Ioniq 5 Kredit    351.564730     42.288333   0.000000    41.666667
# Hyundai Ioniq 5 Leasing   455.100000     52.044167   0.000000    41.666667
# Kia ceed Kredit           130.348234     27.165833   8.916667    75.000000
# Kia ceed Leasing          227.420000     32.965000   8.916667    75.000000
# VW Passat Kredit          194.448036     29.279167   8.166667    75.000000
# VW Passat Leasing         320.777222     35.255833   8.166667    75.000000
# Mercedes C 200 Kredit     275.311119     44.473333  12.000000    75.000000
#
#                            Verbrauch       Summe   Anzahlung    Restwert  \
# BMW 318d 2011 Kredit      164.497667  621.906937    0.000000  -36.496350
# Nissan Micra 2010 Kredit   24.055680   92.485680   50.000000  -30.303030
# Tesla Model Y Kredit       62.000000  562.924000  178.571429 -119.047619
# Tesla Model Y Leasing      62.000000  683.908333   62.500000    0.000000
# Tesla Model 3 Kredit       58.125000  438.392983  178.571429 -101.190476
# Tesla Model 3 Leasing      58.125000  515.925000   62.500000    0.000000
# Hyundai Ioniq 5 Kredit    101.137500  536.657230  178.571429 -101.190476
# Hyundai Ioniq 5 Leasing   101.137500  649.948333  125.000000    0.000000
# Kia ceed Kredit           148.750000  390.180734  178.571429  -59.523810
# Kia ceed Leasing          148.750000  493.051667   83.333333    0.000000
# VW Passat Kredit          159.375000  466.268869  178.571429  -71.428571
# VW Passat Leasing         159.375000  598.574722   83.333333    0.000000
# Mercedes C 200 Kredit     179.562500  586.346952  312.500000 -114.583333
#
#                           Gesamtsumme
# BMW 318d 2011 Kredit       585.410586
# Nissan Micra 2010 Kredit   112.182650
# Tesla Model Y Kredit       622.447810
# Tesla Model Y Leasing      746.408333
# Tesla Model 3 Kredit       515.773935
# Tesla Model 3 Leasing      578.425000
# Hyundai Ioniq 5 Kredit     614.038182
# Hyundai Ioniq 5 Leasing    774.948333
# Kia ceed Kredit            509.228353
# Kia ceed Leasing           576.385000
# VW Passat Kredit           573.411726
# VW Passat Leasing          681.908056
# Mercedes C 200 Kredit      784.263619

# %%
bold_column = pd.IndexSlice[comparison.index , comparison_columns[9]]
light_column = pd.IndexSlice[comparison.index, comparison_columns[10:]]
format_column = pd.IndexSlice[comparison.index, [comparison_columns[0]] + comparison_columns[4:]]
overview_path_1 = 'images/overview1.png'

dfi.export(comparison.sort_values(comparison_columns[9],
                                  ascending=True).style.applymap(df_style, subset=bold_column)\
                                                        .applymap(light_style, subset=light_column)\
                                                        .format('{:.2f}', subset=format_column),
           overview_path_1)

display(comparison.sort_values(comparison_columns[9],
                               ascending=True).style.applymap(df_style, subset=bold_column)\
                                                     .applymap(light_style, subset=light_column)\
                                                     .format('{:.2f}', subset=format_column))

latex = r"""%s

\pagebreak

\onecolumn
\null
\vfill 
\includegraphics[width=0.95\columnwidth]{%s}
\vfill 

""" % (latex,
      overview_path_1)
# Out:
# <style type="text/css">
# #T_acaee_row0_col9, #T_acaee_row1_col9, #T_acaee_row2_col9, #T_acaee_row3_col9, #T_acaee_row4_col9, #T_acaee_row5_col9, #T_acaee_row6_col9, #T_acaee_row7_col9, #T_acaee_row8_col9, #T_acaee_row9_col9, #T_acaee_row10_col9, #T_acaee_row11_col9, #T_acaee_row12_col9 {
#   font-weight: bold;
# }
# #T_acaee_row0_col10, #T_acaee_row0_col11, #T_acaee_row0_col12, #T_acaee_row1_col10, #T_acaee_row1_col11, #T_acaee_row1_col12, #T_acaee_row2_col10, #T_acaee_row2_col11, #T_acaee_row2_col12, #T_acaee_row3_col10, #T_acaee_row3_col11, #T_acaee_row3_col12, #T_acaee_row4_col10, #T_acaee_row4_col11, #T_acaee_row4_col12, #T_acaee_row5_col10, #T_acaee_row5_col11, #T_acaee_row5_col12, #T_acaee_row6_col10, #T_acaee_row6_col11, #T_acaee_row6_col12, #T_acaee_row7_col10, #T_acaee_row7_col11, #T_acaee_row7_col12, #T_acaee_row8_col10, #T_acaee_row8_col11, #T_acaee_row8_col12, #T_acaee_row9_col10, #T_acaee_row9_col11, #T_acaee_row9_col12, #T_acaee_row10_col10, #T_acaee_row10_col11, #T_acaee_row10_col12, #T_acaee_row11_col10, #T_acaee_row11_col11, #T_acaee_row11_col12, #T_acaee_row12_col10, #T_acaee_row12_col11, #T_acaee_row12_col12 {
#   color: grey;
# }
# </style>
# <table id="T_acaee_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Preis Netto</th>
#       <th class="col_heading level0 col1" >Baujahr</th>
#       <th class="col_heading level0 col2" >Kilometerstand</th>
#       <th class="col_heading level0 col3" >Antrieb</th>
#       <th class="col_heading level0 col4" >Raten</th>
#       <th class="col_heading level0 col5" >Versicherung</th>
#       <th class="col_heading level0 col6" >Steuern</th>
#       <th class="col_heading level0 col7" >Reparaturen</th>
#       <th class="col_heading level0 col8" >Verbrauch</th>
#       <th class="col_heading level0 col9" >Summe</th>
#       <th class="col_heading level0 col10" >Anzahlung</th>
#       <th class="col_heading level0 col11" >Restwert</th>
#       <th class="col_heading level0 col12" >Gesamtsumme</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_acaee_level0_row0" class="row_heading level0 row0" >Nissan Micra 2010 Kredit</th>
#       <td id="T_acaee_row0_col0" class="data row0 col0" >3300.00</td>
#       <td id="T_acaee_row0_col1" class="data row0 col1" >2011</td>
#       <td id="T_acaee_row0_col2" class="data row0 col2" >122000</td>
#       <td id="T_acaee_row0_col3" class="data row0 col3" >Benzin</td>
#       <td id="T_acaee_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_acaee_row0_col5" class="data row0 col5" >30.15</td>
#       <td id="T_acaee_row0_col6" class="data row0 col6" >5.33</td>
#       <td id="T_acaee_row0_col7" class="data row0 col7" >32.95</td>
#       <td id="T_acaee_row0_col8" class="data row0 col8" >24.06</td>
#       <td id="T_acaee_row0_col9" class="data row0 col9" >92.49</td>
#       <td id="T_acaee_row0_col10" class="data row0 col10" >50.00</td>
#       <td id="T_acaee_row0_col11" class="data row0 col11" >-30.30</td>
#       <td id="T_acaee_row0_col12" class="data row0 col12" >112.18</td>
#     </tr>
#     <tr>
#       <th id="T_acaee_level0_row1" class="row_heading level0 row1" >Kia ceed Kredit</th>
#       <td id="T_acaee_row1_col0" class="data row1 col0" >25209.43</td>
#       <td id="T_acaee_row1_col1" class="data row1 col1" >2022</td>
#       <td id="T_acaee_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_acaee_row1_col3" class="data row1 col3" >Benzin</td>
#       <td id="T_acaee_row1_col4" class="data row1 col4" >130.35</td>
#       <td id="T_acaee_row1_col5" class="data row1 col5" >27.17</td>
#       <td id="T_acaee_row1_col6" class="data row1 col6" >8.92</td>
#       <td id="T_acaee_row1_col7" class="data row1 col7" >75.00</td>
#       <td id="T_acaee_row1_col8" class="data row1 col8" >148.75</td>
#       <td id="T_acaee_row1_col9" class="data row1 col9" >390.18</td>
#       <td id="T_acaee_row1_col10" class="data row1 col10" >178.57</td>
#       <td id="T_acaee_row1_col11" class="data row1 col11" >-59.52</td>
#       <td id="T_acaee_row1_col12" class="data row1 col12" >509.23</td>
#     </tr>
#     <tr>
#       <th id="T_acaee_level0_row2" class="row_heading level0 row2" >Tesla Model 3 Kredit</th>
#       <td id="T_acaee_row2_col0" class="data row2 col0" >43970.00</td>
#       <td id="T_acaee_row2_col1" class="data row2 col1" >2022</td>
#       <td id="T_acaee_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_acaee_row2_col3" class="data row2 col3" >Strom</td>
#       <td id="T_acaee_row2_col4" class="data row2 col4" >293.27</td>
#       <td id="T_acaee_row2_col5" class="data row2 col5" >45.33</td>
#       <td id="T_acaee_row2_col6" class="data row2 col6" >0.00</td>
#       <td id="T_acaee_row2_col7" class="data row2 col7" >41.67</td>
#       <td id="T_acaee_row2_col8" class="data row2 col8" >58.12</td>
#       <td id="T_acaee_row2_col9" class="data row2 col9" >438.39</td>
#       <td id="T_acaee_row2_col10" class="data row2 col10" >178.57</td>
#       <td id="T_acaee_row2_col11" class="data row2 col11" >-101.19</td>
#       <td id="T_acaee_row2_col12" class="data row2 col12" >515.77</td>
#     </tr>
#     <tr>
#       <th id="T_acaee_level0_row3" class="row_heading level0 row3" >VW Passat Kredit</th>
#       <td id="T_acaee_row3_col0" class="data row3 col0" >30230.00</td>
#       <td id="T_acaee_row3_col1" class="data row3 col1" >2021</td>
#       <td id="T_acaee_row3_col2" class="data row3 col2" >24800</td>
#       <td id="T_acaee_row3_col3" class="data row3 col3" >Benzin</td>
#       <td id="T_acaee_row3_col4" class="data row3 col4" >194.45</td>
#       <td id="T_acaee_row3_col5" class="data row3 col5" >29.28</td>
#       <td id="T_acaee_row3_col6" class="data row3 col6" >8.17</td>
#       <td id="T_acaee_row3_col7" class="data row3 col7" >75.00</td>
#       <td id="T_acaee_row3_col8" class="data row3 col8" >159.38</td>
#       <td id="T_acaee_row3_col9" class="data row3 col9" >466.27</td>
#       <td id="T_acaee_row3_col10" class="data row3 col10" >178.57</td>
#       <td id="T_acaee_row3_col11" class="data row3 col11" >-71.43</td>
#       <td id="T_acaee_row3_col12" class="data row3 col12" >573.41</td>
#     </tr>
#     <tr>
#       <th id="T_acaee_level0_row4" class="row_heading level0 row4" >Kia ceed Leasing</th>
#       <td id="T_acaee_row4_col0" class="data row4 col0" >25209.43</td>
#       <td id="T_acaee_row4_col1" class="data row4 col1" >2022</td>
#       <td id="T_acaee_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_acaee_row4_col3" class="data row4 col3" >Benzin</td>
#       <td id="T_acaee_row4_col4" class="data row4 col4" >227.42</td>
#       <td id="T_acaee_row4_col5" class="data row4 col5" >32.96</td>
#       <td id="T_acaee_row4_col6" class="data row4 col6" >8.92</td>
#       <td id="T_acaee_row4_col7" class="data row4 col7" >75.00</td>
#       <td id="T_acaee_row4_col8" class="data row4 col8" >148.75</td>
#       <td id="T_acaee_row4_col9" class="data row4 col9" >493.05</td>
#       <td id="T_acaee_row4_col10" class="data row4 col10" >83.33</td>
#       <td id="T_acaee_row4_col11" class="data row4 col11" >0.00</td>
#       <td id="T_acaee_row4_col12" class="data row4 col12" >576.38</td>
#     </tr>
#     <tr>
#       <th id="T_acaee_level0_row5" class="row_heading level0 row5" >Tesla Model 3 Leasing</th>
#       <td id="T_acaee_row5_col0" class="data row5 col0" >43970.00</td>
#       <td id="T_acaee_row5_col1" class="data row5 col1" >2022</td>
#       <td id="T_acaee_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_acaee_row5_col3" class="data row5 col3" >Strom</td>
#       <td id="T_acaee_row5_col4" class="data row5 col4" >360.00</td>
#       <td id="T_acaee_row5_col5" class="data row5 col5" >56.13</td>
#       <td id="T_acaee_row5_col6" class="data row5 col6" >0.00</td>
#       <td id="T_acaee_row5_col7" class="data row5 col7" >41.67</td>
#       <td id="T_acaee_row5_col8" class="data row5 col8" >58.12</td>
#       <td id="T_acaee_row5_col9" class="data row5 col9" >515.93</td>
#       <td id="T_acaee_row5_col10" class="data row5 col10" >62.50</td>
#       <td id="T_acaee_row5_col11" class="data row5 col11" >0.00</td>
#       <td id="T

# %%
tex_file = r'report_l.tex'
with open(tex_file, 'w') as fid:
    fid.write(r"""
\documentclass[landscape, DIV=99, 14pt]{scrartcl}

\renewcommand*{\familydefault}{\sfdefault}

\RequirePackage{graphicx}
\RequirePackage{hyperref}
\RequirePackage[gen]{eurosym}
\RequirePackage{multirow}
\RequirePackage{booktabs}
\RequirePackage[table]{xcolor}
\RequirePackage{siunitx}
\RequirePackage{etoolbox}
\RequirePackage{etoolbox}

\robustify\bfseries
\robustify\itshape

\begin{document}
\sisetup{detect-all = true}

\twocolumn
\section*{Zusammenfassung BMW Kosten}
\null
\vspace{1cm}
\begin{center}
%%                           trim={<left> <lower> <right> <upper>}
\includegraphics[width=10cm, trim={4cm 0 4cm 5cm}]{images/kosten_verteilung.png}
\end{center}

\includegraphics[width=1.4\columnwidth]{images/kosten_maximus.png}

\pagebreak

\begin{itemize}
    \item Wertverlust
    \begin{itemize}
        \item Kaufpreis minus Verkaufspreis
    \end{itemize}
    \item Kraftstoffe
    \begin{itemize}
        \item Summe aller Tankstellenbesuche
    \end{itemize}
    \item Wartung und Reparatur
    \begin{itemize}
        \item Regul\"are Wartungsarbeiten (\"Olwechsel, etc)
        \item Reparaturen Aufgrund technischer Defekte
        \item Unfallsch\"aden
    \end{itemize}
    \item Versicherung
    \begin{itemize}
        \item J\"ahrlicher Versicherungsbeitrag
        \item Mobilit\"ats-Service
    \end{itemize}
    \item Steuern
    \begin{itemize}
            \item J\"ahrliche KFZ-Steuer
    \end{itemize}
\end{itemize}

# %s

\end{document}
""" % (latex))

# %%
os.system('pdflatex.exe .\%s' % (tex_file))
os.system('pdflatex.exe .\%s' % (tex_file))
os.system('start .\%spdf' % (tex_file[:-3]))
# Out:
# 0

# %%
#with open('test_table.html', 'w') as fid:
#    fid.write(calc_values.style.applymap(df_style, subset=bold_row)\
#              .applymap(light_style, subset=light_row).set_precision(2)\
#              .to_html())
#
