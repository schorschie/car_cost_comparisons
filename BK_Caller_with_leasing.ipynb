# %%
import os
import pandas as pd
import dataframe_image as dfi
from slugify import slugify
from pathlib import Path
from bk import Operating_Cost

overview = pd.DataFrame()
overview.name='Monatliche Kosten im Verlgeich'

def df_style(val):
    # return "font-weight: bold; background: yellow"
    return "font-weight: bold;"

def light_style(val):
    return "color: grey"

# %%
#d_0 = 1.52  # Aktueller Dieselpreis 3.1.2022: 1.52
b_0 = 1.70  # Aktueller Benzinpreis 3.1.2022: 1.56
e_0 = 0.31  # Aktueller Strompreis 3.1.2022: 0.31 €/kWh
# e_0 = 0.79  # Superchargin worst case

down_payment_buy = 15000
down_payment_lease = 3000


cars = []       
cars.append({'label': 'BMW 318d 2011',
             'acquisition_cost': 16903,
             'government_funding': 0,
             'down_payment': 0,
             'car_year': 2011,
             'delivery_time': 0,
             'interest_rate': 0.,
             'rest_value': 3000,
             'insurance_yearly': 775,
             'taxes_yearly': 230,
             'consumption': 6.38,
             'power': 137,
             'fuel_price': 1.19,  # Durchschnittlicher Dieselpreis seit 2015
             'fuel_type': 'Diesel',
             'fuel_unit': 'l',
             'repairs_yearly': 2016.32,
             'millage_yearly': 26000,
             'holding_period': 6.85,
             'image_url': 'cars/bmw-3er-maximus.png',
             'web_url': 'https://de.wikipedia.org/wiki/BMW_E90',
             'buy': True,  # else lease
             'estimate': False
            }
           )
cars.append({'label': 'Nissan Micra 2010',
             'acquisition_cost': 3300,
             'government_funding': 0,
             'down_payment': 3300,
             'car_year': 2011,
             'delivery_time': 0,
             'interest_rate': 0.,
             'rest_value': 2000,
             'insurance_yearly': 361.76,
             'taxes_yearly': 64,
             'consumption': 6.6,
             'power': 65,
             'fuel_price': 1.36,  # Durchschnittlicher Dieselpreis seit 2016
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 395.40,
             'millage_yearly': 3216,
             'holding_period': 5.5,  
             'image_url': 'cars/nissan-micra.jpg',
             'web_url': 'https://de.wikipedia.org/wiki/Nissan_Micra#Micra_(K12,_2003%E2%80%932010)',
             'buy': True,  # else lease
             'estimate': False
            }
           )
cars.append({'label': 'Tesla Model Y',
             'acquisition_cost': 52970,
             'government_funding': 5000,
             'down_payment': down_payment_buy + 5000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 10000,
             'insurance_yearly': 459.78,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-y.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Tesla Model Y',
             'instalment': 533,
             'government_funding': 5000,
             'down_payment': down_payment_lease + 5000,
             'car_year': 2022,
             'delivery_time': 4,
             'rest_value': 9000,
             'insurance_yearly': 566.90,
             'taxes_yearly': 0,
             'consumption': 16.,
             'power': 514,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 4.0,   
             'image_url': 'cars/tesla-model-y-leasing.jpg',
             'web_url': 'https://www.tesla.com/de_de/modely/design#overview',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Tesla Model 3',
             'acquisition_cost': 43970,
             'government_funding': 6000,
             'down_payment': down_payment_buy + 6000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 8500,
             'insurance_yearly': 544,
             'taxes_yearly': 0,
             'consumption': 15.,
             'power': 325,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/tesla-model-3.jpg',
             'web_url': 'https://www.tesla.com/de_de/model3/design#overview',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Tesla Model 3',
             'instalment': 360,
             'government_funding': 6000,
             'down_payment': down_payment_lease + 6000,
             'car_year': 2022,
             'delivery_time': 4,
             'insurance_yearly': 673.60,
             'taxes_yearly': 0,
             'consumption': 15.,
             'power': 325,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 4.0,   
             'image_url': 'cars/tesla-model-3-leasing.jpg',
             'web_url': 'https://www.tesla.com/de_de/model3/design#overview',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Hyundai Ioniq 5',
             'acquisition_cost': 48536.05,
             'government_funding': 6000,
             'down_payment': down_payment_buy + 6000,
             'car_year': 2022,
             'delivery_time': 4,
             'interest_rate': 2.,
             'rest_value': 8500,
             'insurance_yearly': 497.86+9.6,
             'taxes_yearly': 0,
             'consumption': 26.1,
             'power': 231,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 7.0,   
             'image_url': 'cars/hyundai-ioniq-5.png',
             'web_url': 'https://konfigurator.meinauto.de/hyundai/neuwagen/ioniq/angebote/ioniq-5/konfigurator/#!/extras/-/8865700/14,19,41/private/104690-6897-293274/4864/61e90b0c48e55/cash-purchase/104690-6897-293274/24,9000,15000,0,0,0,0,0,',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Hyundai Ioniq 5',
             'instalment': 455.10,
             'government_funding': 6000,
             'down_payment': down_payment_lease + 6000,
             'car_year': 2022,
             'delivery_time': 4,
             'insurance_yearly': 624.53,
             'taxes_yearly': 0,
             'consumption': 26.1,
             'power': 231,
             'fuel_price': e_0,
             'fuel_type': 'Strom',
             'fuel_unit': 'kWh',
             'repairs_yearly': 500,
             'millage_yearly': 15000,
             'holding_period': 2.0,   
             'image_url': 'cars/hyundai-ioniq-5.png',
             'web_url': 'https://konfigurator.meinauto.de/hyundai/neuwagen/ioniq/angebote/ioniq-5/konfigurator/#!/extras/-/8865700/14,19,41/private/104690-6897-293274/4864/61e90b0c48e55/leasing/104690-6897-293274/24,9000,15000,0,0,0,0,0,',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Mazda 6',
             'acquisition_cost': 30643.19,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'delivery_time': 20,
             'interest_rate': 2.,
             'rest_value': 6000,
             'insurance_yearly': 510.90,
             'taxes_yearly': 156,
             'consumption': 8.,
             'power': 192,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,  
             'image_url': 'cars/mazda-6-neu.png',
             'web_url': 'https://konfigurator.meinauto.de/mazda/neuwagen/48-6/angebote/6-kombi/konfigurator/#!/extras/exclusive-line/8846370/10,11/private/65352-5416-204698/984/61c9aa657e74c/cash-purchase/32545--287374/48,0,10000,0,0,0,0,0,',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Mazda 6',
             'instalment': 284.70,
             'government_funding': 0,
             'down_payment': down_payment_lease,
             'car_year': 2022,
             'delivery_time': 60,
             'rest_value': 3000,
             'insurance_yearly': 629.91,
             'taxes_yearly': 156,
             'consumption': 8.,
             'power': 192,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3,  
             'image_url': 'cars/mazda-6-leasing.png',
             'web_url': 'https://konfigurator.meinauto.de/mazda/neuwagen/48-6/angebote/6-kombi/konfigurator/#!/extras/exclusive-line/8846370/10,11,15/private/65352-5416-204698/984/61c9aa657e74c/leasing/16040--249432/36,3000,15000,0,0,0,0,0,',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Kia ceed',
             'acquisition_cost': 25209.43,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'delivery_time': 52,
             'interest_rate': 2.,
             'rest_value': 5000,
             'insurance_yearly': 325.99,
             'taxes_yearly': 107,
             'consumption': 7.,
             'power': 160,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,
             'image_url': 'cars/kia-ceed-sportswagon.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/extras/spirit/8865371/3,11,27/private/109347-4167-291321/1321/61d21ce73c5db/cash-purchase/109348-8088-291322/48,0,10000,0,0,0,0,0,',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Kia ceed',
             'instalment': 227.42,
             'government_funding': 0,
             'down_payment': down_payment_lease,
             'car_year': 2022,
             'delivery_time': 52,
             'rest_value': 3000,
             'insurance_yearly': 395.58,
             'taxes_yearly': 107,
             'consumption': 7.,
             'power': 160,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3.0,
             'image_url': 'cars/kia-ceed-sportswagon-leasing.png',
             'web_url': 'https://konfigurator.meinauto.de/kia/neuwagen/cee-d/angebote/cee-d-sporty-wagon/konfigurator/#!/extras/spirit/8865371/3,11,27/private/109347-4167-291321/1321/61d21ce73c5db/leasing/109348-8088-291322/36,3000,15000,0,0,0,0,0,',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'VW Passat',
             'acquisition_cost': 30230.0,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2021,
             'delivery_time': 0,
             'interest_rate': 2.,
             'rest_value': 6000,
             'insurance_yearly': 351.35,
             'taxes_yearly': 98,
             'consumption': 7.5,
             'power': 150,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,
             'image_url': 'cars/vw-passat.jpg',
             'web_url': 'https://www.autosuche.de/auto/REVVNDQ3NjgwMjc5NzI=?t_manuf=BQ&t_petr=B&t_model=BQBM&t_gear=A&t_ez_fr=2020&t_pe_fr=35000&sort=PRICE_SALE&sortdirection=ASC&viewMode=tile',
             'buy': True,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'VW Passat',
             'instalment': 194.18 + 4557.50/36,
             'government_funding': 0,
             'down_payment': down_payment_lease,
             'car_year': 2022,
             'delivery_time': 0,
             'rest_value': 3000,
             'insurance_yearly': 423.07,
             'taxes_yearly': 98,
             'consumption': 7.5,
             'power': 150,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3.0,
             'image_url': 'cars/vw-passat-leasing.jpg',
             'web_url': 'https://www.autosuche.de/auto/REVVNDQ3NjgwMjc5NzI=?t_manuf=BQ&t_petr=B&t_model=BQBM&t_gear=A&t_ez_fr=2020&t_pe_fr=35000&sort=PRICE_SALE&sortdirection=ASC&viewMode=tile',
             'buy': False,  # else lease
             'estimate': True
            }
           )
cars.append({'label': 'Mercedes C 180',
             'acquisition_cost': 42755.83,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'delivery_time': 60,
             'interest_rate': 2.,
             'rest_value': 8000,
             'insurance_yearly': 533.68,
             'taxes_yearly': 136,
             'consumption': 7.,
             'power': 170,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,  
             'image_url': 'cars/mercedes-c-180-t.png',
             'web_url': 'https://konfigurator.meinauto.de/mercedes/neuwagen/c-klasse/angebote/c-klasse-t-modell/konfigurator/#!/preisvergleich/-/8866563/2,47,74,81/private/43735-7309-290394/349/61d36ce4c3067/cash-purchase/73169--190162/48,0,10000,0,0,0,0,0,',
             'buy': True,  # else lease
             'estimate': True
            }
           )  
cars.append({'label': 'Mercedes C 180',
             'instalment': 494.30,
             'government_funding': 0,
             'down_payment': down_payment_lease,
             'car_year': 2022,
             'delivery_time': 60,
             'rest_value': 8000,
             'insurance_yearly': 663.76,
             'taxes_yearly': 136,
             'consumption': 7.,
             'power': 170,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 3.0,  
             'image_url': 'cars/mercedes-c-180-t.png',
             'web_url': 'https://konfigurator.meinauto.de/mercedes/neuwagen/c-klasse/angebote/c-klasse-t-modell/konfigurator/#!/preisvergleich/-/8866563/2,47,74,81/private/43735-7309-290394/349/61d36ce4c3067/cash-purchase/73169--190162/48,0,10000,0,0,0,0,0,',
             'buy': False,  # else lease
             'estimate': True
            }
           )  
cars.append({'label': 'Skoda Scala',
             'acquisition_cost': 27619.05,
             'government_funding': 0,
             'down_payment': down_payment_buy,
             'car_year': 2022,
             'delivery_time': 60,
             'interest_rate': 2.,
             'rest_value': 5500,
             'insurance_yearly': 308.52,
             'taxes_yearly': 68,
             'consumption': 6.3,
             'power': 150,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 7.0,  
             'image_url': 'cars/skoda-scala.png',
             'web_url': 'https://konfigurator.meinauto.de/skoda/neuwagen/scala/angebote/scala-tour/konfigurator/#!/preisvergleich/tour/8868635/7,35,37,46/private/109429--291462/5217/61e95cad08f55/cash-purchase/109433--291466/48,0,10000,0,0,0,0,0,',
             'buy': True,  # else lease
             'estimate': True
            }
           )  
cars.append({'label': 'Skoda Scala',
             'instalment': 267.16,
             'government_funding': 0,
             'down_payment': down_payment_lease,
             'car_year': 2022,
             'delivery_time': 60,
             'rest_value': 8000,
             'insurance_yearly': 369.83,
             'taxes_yearly': 68,
             'consumption': 6.3,
             'power': 150,
             'fuel_price': b_0,
             'fuel_type': 'Benzin',
             'fuel_unit': 'l',
             'repairs_yearly': 900,
             'millage_yearly': 15000,
             'holding_period': 4.0,  
             'image_url': 'cars/skoda-scala-leasing.png',
             'web_url': 'https://konfigurator.meinauto.de/skoda/neuwagen/scala/angebote/scala-tour/konfigurator/#!/preisvergleich/tour/8868635/7,35,37,46/private/109429--291462/5217/61e95cad08f55/leasing/109433--291466/36,3000,15000,0,0,0,0,0,',
             'buy': False,  # else lease
             'estimate': True
            }
           )  


for car in cars:
    if car['buy']:
        factor = .5**(car['holding_period']/3)
        car['rest_value_thumb_value'] = r'Restwert nach Faustformel (Neupreis $\times$ %.1f\%%): %.2f \euro{}' % \
        (factor*100, car['acquisition_cost'] * factor)
    else:
        car['rest_value_thumb_value'] = r'Kein Restwert, da Leasingfahrzeug'

# %%
latex = ''
for car in cars:
    if car['estimate']:
        estimate_string = r'\emph{Gesch\"atzter}'
    else:
        estimate_string = r'\emph{Realer}'
        
    if car['buy']:
        label=car['label'] + ' Kaufen'
        bk_inputs = {key: car[key] for key in ['acquisition_cost', 
                                               'government_funding',
                                               'down_payment',
                                               'holding_period',
                                               'millage_yearly',
                                               'consumption',
                                               'fuel_price',
                                               'repairs_yearly',  # bis hierher Hauptkosten
                                               'interest_rate',
                                               'taxes_yearly',
                                               'insurance_yearly',
                                               'rest_value']}
        (input_values, calc_values) = Operating_Cost.buy(**bk_inputs).get_frames()
    else:
        label=car['label'] + ' Leasing'
        bk_inputs = {key: car[key] for key in ['instalment', 
                                               'government_funding',
                                               'down_payment',
                                               'holding_period',
                                               'millage_yearly',
                                               'consumption',
                                               'fuel_price',
                                               'repairs_yearly',  # bis hierher Hauptkosten
                                               'taxes_yearly',
                                               'insurance_yearly']}
        (input_values, calc_values) = Operating_Cost.lease(**bk_inputs).get_frames()
        
    input_values_path = Path('images/' + slugify(label) + '-boundaries.png')
    calc_df_path = Path('images/' + slugify(label) + '-calc_df.png')
    
    latex = r"""%s
\twocolumn

\section*{%s}
\begin{center}
\includegraphics[width=0.5\textheight]{%s}
\null
\vspace{0.5cm}
\includegraphics[width=0.5\textheight]{%s}
\end{center}

\pagebreak
\null
\vspace{2cm}
\begin{center}
\includegraphics[width=0.9\columnwidth]{%s}

# %s
\end{center}

\begin{itemize}
    \item Baujahr: %d $\rightarrow$ Laufzeit: %.0f Jahre
    \item \href{%s}{Weblink}
    \item %s Spritpreis \"uber Haltedauer: %.2f \euro{}/%s
    \item Antrieb: %s, mit %d PS
    \item %s
\end{itemize}

\pagebreak

""" %(latex,
      label,
      input_values_path.as_posix(),
      calc_df_path.as_posix(),
      car['image_url'],
      label,
      car['car_year'],
      car['holding_period'],
      car['web_url'].replace('#', '\#'),
      estimate_string,
      car['fuel_price'],
      car['fuel_unit'],
      car['fuel_type'],
      car['power'],
      car['rest_value_thumb_value']
     )

    # calc_values.loc['Lieferzeit', :] = car['delivery_time']
    # calc_values.loc['Kraftstoffsorte', :] = car['fuel_type']
    # calc_values = calc_values.reindex(index = ['Lieferzeit',
    #                                            'Kraftstoffsorte',
    #                                            'Anschaffungskosten',
    #                                            'Zinsen',
    #                                            'Versicherung',
    #                                            'Steuern',
    #                                            'Reparaturen',
    #                                            'Verbrauch',
    #                                            'SUMME',
    #                                            'Restwert',
    #                                            'Summe mit Restwert'
    #                                           ])
    
    overview[label] = calc_values['Monatlich']
    
    input_values_path.parent.mkdir(parents=True, exist_ok=True)
    
    bold_row = pd.IndexSlice[calc_values.index[(calc_values.index == "Summe") | (calc_values.index == "Gesamtsumme")], :]
    light_row = pd.IndexSlice[calc_values.index[6:], :]
    
    dfi.export(input_values.round(2), str(input_values_path))
    dfi.export(calc_values.style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
    display(input_values.round(2))
    display(calc_values.style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2))
# Out:
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     16903.00
# Anzahlung [€]                                                  0.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                            0.00
# Finanzierungszins [%]                                          0.00
# Restwert [€]                                                3000.00
# Versicherungskosten [€/a]                                    775.00
# Steuern [€/a]                                                230.00
# Verbrauch in l/100 km                                          6.38
# Durchschnittlicher Spritpreis über Haltedauer [...             1.19
# Reparatur und Wartungskosten [€/a]                          2016.32
# Jahreslaufleistung [km]                                    26000.00
# Haltedauer [a]                                                 6.85
# Gesamtlaufleistung [km]                                   178100.00
# Finanzierungsbetrag [€]                                    16903.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_b637d_row5_col0, #T_b637d_row5_col1, #T_b637d_row5_col2, #T_b637d_row5_col3 {
#   font-weight: bold;
# }
# #T_b637d_row6_col0, #T_b637d_row6_col1, #T_b637d_row6_col2, #T_b637d_row6_col3, #T_b637d_row7_col0, #T_b637d_row7_col1, #T_b637d_row7_col2, #T_b637d_row7_col3 {
#   color: grey;
# }
# #T_b637d_row8_col0, #T_b637d_row8_col1, #T_b637d_row8_col2, #T_b637d_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_b637d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b637d_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_b637d_row0_col0" class="data row0 col0" >16903.00</td>
#       <td id="T_b637d_row0_col1" class="data row0 col1" >2467.59</td>
#       <td id="T_b637d_row0_col2" class="data row0 col2" >205.63</td>
#       <td id="T_b637d_row0_col3" class="data row0 col3" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_b637d_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_b637d_row1_col0" class="data row1 col0" >5308.75</td>
#       <td id="T_b637d_row1_col1" class="data row1 col1" >775.00</td>
#       <td id="T_b637d_row1_col2" class="data row1 col2" >64.58</td>
#       <td id="T_b637d_row1_col3" class="data row1 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_b637d_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_b637d_row2_col0" class="data row2 col0" >1575.50</td>
#       <td id="T_b637d_row2_col1" class="data row2 col1" >230.00</td>
#       <td id="T_b637d_row2_col2" class="data row2 col2" >19.17</td>
#       <td id="T_b637d_row2_col3" class="data row2 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_b637d_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_b637d_row3_col0" class="data row3 col0" >13811.79</td>
#       <td id="T_b637d_row3_col1" class="data row3 col1" >2016.32</td>
#       <td id="T_b637d_row3_col2" class="data row3 col2" >168.03</td>
#       <td id="T_b637d_row3_col3" class="data row3 col3" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_b637d_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_b637d_row4_col0" class="data row4 col0" >13521.71</td>
#       <td id="T_b637d_row4_col1" class="data row4 col1" >1973.97</td>
#       <td id="T_b637d_row4_col2" class="data row4 col2" >164.50</td>
#       <td id="T_b637d_row4_col3" class="data row4 col3" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_b637d_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_b637d_row5_col0" class="data row5 col0" >51120.75</td>
#       <td id="T_b637d_row5_col1" class="data row5 col1" >7462.88</td>
#       <td id="T_b637d_row5_col2" class="data row5 col2" >621.91</td>
#       <td id="T_b637d_row5_col3" class="data row5 col3" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_b637d_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_b637d_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_b637d_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_b637d_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_b637d_row6_col3" class="data row6 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_b637d_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_b637d_row7_col0" class="data row7 col0" >-3000.00</td>
#       <td id="T_b637d_row7_col1" class="data row7 col1" >-437.96</td>
#       <td id="T_b637d_row7_col2" class="data row7 col2" >-36.50</td>
#       <td id="T_b637d_row7_col3" class="data row7 col3" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_b637d_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_b637d_row8_col0" class="data row8 col0" >48120.75</td>
#       <td id="T_b637d_row8_col1" class="data row8 col1" >7024.93</td>
#       <td id="T_b637d_row8_col2" class="data row8 col2" >585.41</td>
#       <td id="T_b637d_row8_col3" class="data row8 col3" >0.27</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                      3300.00
# Anzahlung [€]                                               3300.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                         3300.00
# Finanzierungszins [%]                                          0.00
# Restwert [€]                                                2000.00
# Versicherungskosten [€/a]                                    361.76
# Steuern [€/a]                                                 64.00
# Verbrauch in l/100 km                                          6.60
# Durchschnittlicher Spritpreis über Haltedauer [...             1.36
# Reparatur und Wartungskosten [€/a]                           395.40
# Jahreslaufleistung [km]                                     3216.00
# Haltedauer [a]                                                 5.50
# Gesamtlaufleistung [km]                                    17688.00
# Finanzierungsbetrag [€]                                        0.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_bb494_row5_col0, #T_bb494_row5_col1, #T_bb494_row5_col2, #T_bb494_row5_col3 {
#   font-weight: bold;
# }
# #T_bb494_row6_col0, #T_bb494_row6_col1, #T_bb494_row6_col2, #T_bb494_row6_col3, #T_bb494_row7_col0, #T_bb494_row7_col1, #T_bb494_row7_col2, #T_bb494_row7_col3 {
#   color: grey;
# }
# #T_bb494_row8_col0, #T_bb494_row8_col1, #T_bb494_row8_col2, #T_bb494_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_bb494_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb494_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_bb494_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_bb494_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_bb494_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_bb494_row0_col3" class="data row0 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_bb494_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_bb494_row1_col0" class="data row1 col0" >1989.68</td>
#       <td id="T_bb494_row1_col1" class="data row1 col1" >361.76</td>
#       <td id="T_bb494_row1_col2" class="data row1 col2" >30.15</td>
#       <td id="T_bb494_row1_col3" class="data row1 col3" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_bb494_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_bb494_row2_col0" class="data row2 col0" >352.00</td>
#       <td id="T_bb494_row2_col1" class="data row2 col1" >64.00</td>
#       <td id="T_bb494_row2_col2" class="data row2 col2" >5.33</td>
#       <td id="T_bb494_row2_col3" class="data row2 col3" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_bb494_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_bb494_row3_col0" class="data row3 col0" >2174.70</td>
#       <td id="T_bb494_row3_col1" class="data row3 col1" >395.40</td>
#       <td id="T_bb494_row3_col2" class="data row3 col2" >32.95</td>
#       <td id="T_bb494_row3_col3" class="data row3 col3" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_bb494_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_bb494_row4_col0" class="data row4 col0" >1587.67</td>
#       <td id="T_bb494_row4_col1" class="data row4 col1" >288.67</td>
#       <td id="T_bb494_row4_col2" class="data row4 col2" >24.06</td>
#       <td id="T_bb494_row4_col3" class="data row4 col3" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_bb494_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_bb494_row5_col0" class="data row5 col0" >6104.05</td>
#       <td id="T_bb494_row5_col1" class="data row5 col1" >1109.83</td>
#       <td id="T_bb494_row5_col2" class="data row5 col2" >92.49</td>
#       <td id="T_bb494_row5_col3" class="data row5 col3" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_bb494_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_bb494_row6_col0" class="data row6 col0" >3300.00</td>
#       <td id="T_bb494_row6_col1" class="data row6 col1" >600.00</td>
#       <td id="T_bb494_row6_col2" class="data row6 col2" >50.00</td>
#       <td id="T_bb494_row6_col3" class="data row6 col3" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_bb494_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_bb494_row7_col0" class="data row7 col0" >-2000.00</td>
#       <td id="T_bb494_row7_col1" class="data row7 col1" >-363.64</td>
#       <td id="T_bb494_row7_col2" class="data row7 col2" >-30.30</td>
#       <td id="T_bb494_row7_col3" class="data row7 col3" >-0.11</td>
#     </tr>
#     <tr>
#       <th id="T_bb494_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_bb494_row8_col0" class="data row8 col0" >7404.05</td>
#       <td id="T_bb494_row8_col1" class="data row8 col1" >1346.19</td>
#       <td id="T_bb494_row8_col2" class="data row8 col2" >112.18</td>
#       <td id="T_bb494_row8_col3" class="data row8 col3" >0.42</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     52970.00
# Anzahlung [€]                                              20000.00
# davon staatliche Förderung [€]                              5000.00
# Reale Anzahlung [€]                                        15000.00
# Finanzierungszins [%]                                          2.00
# Restwert [€]                                               10000.00
# Versicherungskosten [€/a]                                    459.78
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         16.00
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    32970.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_a942f_row5_col0, #T_a942f_row5_col1, #T_a942f_row5_col2, #T_a942f_row5_col3 {
#   font-weight: bold;
# }
# #T_a942f_row6_col0, #T_a942f_row6_col1, #T_a942f_row6_col2, #T_a942f_row6_col3, #T_a942f_row7_col0, #T_a942f_row7_col1, #T_a942f_row7_col2, #T_a942f_row7_col3 {
#   color: grey;
# }
# #T_a942f_row8_col0, #T_a942f_row8_col1, #T_a942f_row8_col2, #T_a942f_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_a942f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a942f_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_a942f_row0_col0" class="data row0 col0" >35359.16</td>
#       <td id="T_a942f_row0_col1" class="data row0 col1" >5051.31</td>
#       <td id="T_a942f_row0_col2" class="data row0 col2" >420.94</td>
#       <td id="T_a942f_row0_col3" class="data row0 col3" >0.34</td>
#     </tr>
#     <tr>
#       <th id="T_a942f_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_a942f_row1_col0" class="data row1 col0" >3218.46</td>
#       <td id="T_a942f_row1_col1" class="data row1 col1" >459.78</td>
#       <td id="T_a942f_row1_col2" class="data row1 col2" >38.32</td>
#       <td id="T_a942f_row1_col3" class="data row1 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_a942f_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_a942f_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_a942f_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_a942f_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_a942f_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_a942f_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_a942f_row3_col0" class="data row3 col0" >3500.00</td>
#       <td id="T_a942f_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_a942f_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_a942f_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_a942f_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_a942f_row4_col0" class="data row4 col0" >5208.00</td>
#       <td id="T_a942f_row4_col1" class="data row4 col1" >744.00</td>
#       <td id="T_a942f_row4_col2" class="data row4 col2" >62.00</td>
#       <td id="T_a942f_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_a942f_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_a942f_row5_col0" class="data row5 col0" >47285.62</td>
#       <td id="T_a942f_row5_col1" class="data row5 col1" >6755.09</td>
#       <td id="T_a942f_row5_col2" class="data row5 col2" >562.92</td>
#       <td id="T_a942f_row5_col3" class="data row5 col3" >0.45</td>
#     </tr>
#     <tr>
#       <th id="T_a942f_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_a942f_row6_col0" class="data row6 col0" >15000.00</td>
#       <td id="T_a942f_row6_col1" class="data row6 col1" >2142.86</td>
#       <td id="T_a942f_row6_col2" class="data row6 col2" >178.57</td>
#       <td id="T_a942f_row6_col3" class="data row6 col3" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_a942f_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_a942f_row7_col0" class="data row7 col0" >-10000.00</td>
#       <td id="T_a942f_row7_col1" class="data row7 col1" >-1428.57</td>
#       <td id="T_a942f_row7_col2" class="data row7 col2" >-119.05</td>
#       <td id="T_a942f_row7_col3" class="data row7 col3" >-0.10</td>
#     </tr>
#     <tr>
#       <th id="T_a942f_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_a942f_row8_col0" class="data row8 col0" >52285.62</td>
#       <td id="T_a942f_row8_col1" class="data row8 col1" >7469.37</td>
#       <td id="T_a942f_row8_col2" class="data row8 col2" >622.45</td>
#       <td id="T_a942f_row8_col3" class="data row8 col3" >0.50</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Leasingrate [€]                                              533.00
# Anzahlung [€]                                               8000.00
# davon staatliche Förderung [€]                              5000.00
# Reale Anzahlung [€]                                         3000.00
# Versicherungskosten [€/a]                                    566.90
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         16.00
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 4.00
# Gesamtlaufleistung [km]                                    60000.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_6b371_row5_col0, #T_6b371_row5_col1, #T_6b371_row5_col2, #T_6b371_row5_col3 {
#   font-weight: bold;
# }
# #T_6b371_row6_col0, #T_6b371_row6_col1, #T_6b371_row6_col2, #T_6b371_row6_col3, #T_6b371_row7_col0, #T_6b371_row7_col1, #T_6b371_row7_col2, #T_6b371_row7_col3 {
#   color: grey;
# }
# #T_6b371_row8_col0, #T_6b371_row8_col1, #T_6b371_row8_col2, #T_6b371_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_6b371_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b371_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_6b371_row0_col0" class="data row0 col0" >25584.00</td>
#       <td id="T_6b371_row0_col1" class="data row0 col1" >6396.00</td>
#       <td id="T_6b371_row0_col2" class="data row0 col2" >533.00</td>
#       <td id="T_6b371_row0_col3" class="data row0 col3" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_6b371_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_6b371_row1_col0" class="data row1 col0" >2267.60</td>
#       <td id="T_6b371_row1_col1" class="data row1 col1" >566.90</td>
#       <td id="T_6b371_row1_col2" class="data row1 col2" >47.24</td>
#       <td id="T_6b371_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_6b371_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_6b371_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_6b371_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_6b371_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_6b371_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6b371_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_6b371_row3_col0" class="data row3 col0" >2000.00</td>
#       <td id="T_6b371_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_6b371_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_6b371_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_6b371_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_6b371_row4_col0" class="data row4 col0" >2976.00</td>
#       <td id="T_6b371_row4_col1" class="data row4 col1" >744.00</td>
#       <td id="T_6b371_row4_col2" class="data row4 col2" >62.00</td>
#       <td id="T_6b371_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_6b371_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_6b371_row5_col0" class="data row5 col0" >32827.60</td>
#       <td id="T_6b371_row5_col1" class="data row5 col1" >8206.90</td>
#       <td id="T_6b371_row5_col2" class="data row5 col2" >683.91</td>
#       <td id="T_6b371_row5_col3" class="data row5 col3" >0.55</td>
#     </tr>
#     <tr>
#       <th id="T_6b371_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_6b371_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_6b371_row6_col1" class="data row6 col1" >750.00</td>
#       <td id="T_6b371_row6_col2" class="data row6 col2" >62.50</td>
#       <td id="T_6b371_row6_col3" class="data row6 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_6b371_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_6b371_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_6b371_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_6b371_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_6b371_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6b371_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_6b371_row8_col0" class="data row8 col0" >35827.60</td>
#       <td id="T_6b371_row8_col1" class="data row8 col1" >8956.90</td>
#       <td id="T_6b371_row8_col2" class="data row8 col2" >746.41</td>
#       <td id="T_6b371_row8_col3" class="data row8 col3" >0.60</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     43970.00
# Anzahlung [€]                                              21000.00
# davon staatliche Förderung [€]                              6000.00
# Reale Anzahlung [€]                                        15000.00
# Finanzierungszins [%]                                          2.00
# Restwert [€]                                                8500.00
# Versicherungskosten [€/a]                                    544.00
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         15.00
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    22970.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_9aa91_row5_col0, #T_9aa91_row5_col1, #T_9aa91_row5_col2, #T_9aa91_row5_col3 {
#   font-weight: bold;
# }
# #T_9aa91_row6_col0, #T_9aa91_row6_col1, #T_9aa91_row6_col2, #T_9aa91_row6_col3, #T_9aa91_row7_col0, #T_9aa91_row7_col1, #T_9aa91_row7_col2, #T_9aa91_row7_col3 {
#   color: grey;
# }
# #T_9aa91_row8_col0, #T_9aa91_row8_col1, #T_9aa91_row8_col2, #T_9aa91_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_9aa91_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9aa91_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_9aa91_row0_col0" class="data row0 col0" >24634.51</td>
#       <td id="T_9aa91_row0_col1" class="data row0 col1" >3519.22</td>
#       <td id="T_9aa91_row0_col2" class="data row0 col2" >293.27</td>
#       <td id="T_9aa91_row0_col3" class="data row0 col3" >0.23</td>
#     </tr>
#     <tr>
#       <th id="T_9aa91_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_9aa91_row1_col0" class="data row1 col0" >3808.00</td>
#       <td id="T_9aa91_row1_col1" class="data row1 col1" >544.00</td>
#       <td id="T_9aa91_row1_col2" class="data row1 col2" >45.33</td>
#       <td id="T_9aa91_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_9aa91_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_9aa91_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_9aa91_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_9aa91_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_9aa91_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_9aa91_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_9aa91_row3_col0" class="data row3 col0" >3500.00</td>
#       <td id="T_9aa91_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_9aa91_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_9aa91_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_9aa91_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_9aa91_row4_col0" class="data row4 col0" >4882.50</td>
#       <td id="T_9aa91_row4_col1" class="data row4 col1" >697.50</td>
#       <td id="T_9aa91_row4_col2" class="data row4 col2" >58.12</td>
#       <td id="T_9aa91_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_9aa91_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_9aa91_row5_col0" class="data row5 col0" >36825.01</td>
#       <td id="T_9aa91_row5_col1" class="data row5 col1" >5260.72</td>
#       <td id="T_9aa91_row5_col2" class="data row5 col2" >438.39</td>
#       <td id="T_9aa91_row5_col3" class="data row5 col3" >0.35</td>
#     </tr>
#     <tr>
#       <th id="T_9aa91_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_9aa91_row6_col0" class="data row6 col0" >15000.00</td>
#       <td id="T_9aa91_row6_col1" class="data row6 col1" >2142.86</td>
#       <td id="T_9aa91_row6_col2" class="data row6 col2" >178.57</td>
#       <td id="T_9aa91_row6_col3" class="data row6 col3" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_9aa91_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_9aa91_row7_col0" class="data row7 col0" >-8500.00</td>
#       <td id="T_9aa91_row7_col1" class="data row7 col1" >-1214.29</td>
#       <td id="T_9aa91_row7_col2" class="data row7 col2" >-101.19</td>
#       <td id="T_9aa91_row7_col3" class="data row7 col3" >-0.08</td>
#     </tr>
#     <tr>
#       <th id="T_9aa91_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_9aa91_row8_col0" class="data row8 col0" >43325.01</td>
#       <td id="T_9aa91_row8_col1" class="data row8 col1" >6189.29</td>
#       <td id="T_9aa91_row8_col2" class="data row8 col2" >515.77</td>
#       <td id="T_9aa91_row8_col3" class="data row8 col3" >0.41</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Leasingrate [€]                                              360.00
# Anzahlung [€]                                               9000.00
# davon staatliche Förderung [€]                              6000.00
# Reale Anzahlung [€]                                         3000.00
# Versicherungskosten [€/a]                                    673.60
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         15.00
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 4.00
# Gesamtlaufleistung [km]                                    60000.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_96a8b_row5_col0, #T_96a8b_row5_col1, #T_96a8b_row5_col2, #T_96a8b_row5_col3 {
#   font-weight: bold;
# }
# #T_96a8b_row6_col0, #T_96a8b_row6_col1, #T_96a8b_row6_col2, #T_96a8b_row6_col3, #T_96a8b_row7_col0, #T_96a8b_row7_col1, #T_96a8b_row7_col2, #T_96a8b_row7_col3 {
#   color: grey;
# }
# #T_96a8b_row8_col0, #T_96a8b_row8_col1, #T_96a8b_row8_col2, #T_96a8b_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_96a8b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96a8b_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_96a8b_row0_col0" class="data row0 col0" >17280.00</td>
#       <td id="T_96a8b_row0_col1" class="data row0 col1" >4320.00</td>
#       <td id="T_96a8b_row0_col2" class="data row0 col2" >360.00</td>
#       <td id="T_96a8b_row0_col3" class="data row0 col3" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_96a8b_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_96a8b_row1_col0" class="data row1 col0" >2694.40</td>
#       <td id="T_96a8b_row1_col1" class="data row1 col1" >673.60</td>
#       <td id="T_96a8b_row1_col2" class="data row1 col2" >56.13</td>
#       <td id="T_96a8b_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_96a8b_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_96a8b_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_96a8b_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_96a8b_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_96a8b_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_96a8b_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_96a8b_row3_col0" class="data row3 col0" >2000.00</td>
#       <td id="T_96a8b_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_96a8b_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_96a8b_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_96a8b_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_96a8b_row4_col0" class="data row4 col0" >2790.00</td>
#       <td id="T_96a8b_row4_col1" class="data row4 col1" >697.50</td>
#       <td id="T_96a8b_row4_col2" class="data row4 col2" >58.12</td>
#       <td id="T_96a8b_row4_col3" class="data row4 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_96a8b_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_96a8b_row5_col0" class="data row5 col0" >24764.40</td>
#       <td id="T_96a8b_row5_col1" class="data row5 col1" >6191.10</td>
#       <td id="T_96a8b_row5_col2" class="data row5 col2" >515.93</td>
#       <td id="T_96a8b_row5_col3" class="data row5 col3" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_96a8b_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_96a8b_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_96a8b_row6_col1" class="data row6 col1" >750.00</td>
#       <td id="T_96a8b_row6_col2" class="data row6 col2" >62.50</td>
#       <td id="T_96a8b_row6_col3" class="data row6 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_96a8b_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_96a8b_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_96a8b_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_96a8b_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_96a8b_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_96a8b_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_96a8b_row8_col0" class="data row8 col0" >27764.40</td>
#       <td id="T_96a8b_row8_col1" class="data row8 col1" >6941.10</td>
#       <td id="T_96a8b_row8_col2" class="data row8 col2" >578.43</td>
#       <td id="T_96a8b_row8_col3" class="data row8 col3" >0.46</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     48536.05
# Anzahlung [€]                                              21000.00
# davon staatliche Förderung [€]                              6000.00
# Reale Anzahlung [€]                                        15000.00
# Finanzierungszins [%]                                          2.00
# Restwert [€]                                                8500.00
# Versicherungskosten [€/a]                                    507.46
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         26.10
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    27536.05
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_e4cdc_row5_col0, #T_e4cdc_row5_col1, #T_e4cdc_row5_col2, #T_e4cdc_row5_col3 {
#   font-weight: bold;
# }
# #T_e4cdc_row6_col0, #T_e4cdc_row6_col1, #T_e4cdc_row6_col2, #T_e4cdc_row6_col3, #T_e4cdc_row7_col0, #T_e4cdc_row7_col1, #T_e4cdc_row7_col2, #T_e4cdc_row7_col3 {
#   color: grey;
# }
# #T_e4cdc_row8_col0, #T_e4cdc_row8_col1, #T_e4cdc_row8_col2, #T_e4cdc_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_e4cdc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4cdc_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_e4cdc_row0_col0" class="data row0 col0" >29531.44</td>
#       <td id="T_e4cdc_row0_col1" class="data row0 col1" >4218.78</td>
#       <td id="T_e4cdc_row0_col2" class="data row0 col2" >351.56</td>
#       <td id="T_e4cdc_row0_col3" class="data row0 col3" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_e4cdc_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_e4cdc_row1_col0" class="data row1 col0" >3552.22</td>
#       <td id="T_e4cdc_row1_col1" class="data row1 col1" >507.46</td>
#       <td id="T_e4cdc_row1_col2" class="data row1 col2" >42.29</td>
#       <td id="T_e4cdc_row1_col3" class="data row1 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_e4cdc_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_e4cdc_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_e4cdc_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_e4cdc_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_e4cdc_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e4cdc_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_e4cdc_row3_col0" class="data row3 col0" >3500.00</td>
#       <td id="T_e4cdc_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_e4cdc_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_e4cdc_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_e4cdc_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_e4cdc_row4_col0" class="data row4 col0" >8495.55</td>
#       <td id="T_e4cdc_row4_col1" class="data row4 col1" >1213.65</td>
#       <td id="T_e4cdc_row4_col2" class="data row4 col2" >101.14</td>
#       <td id="T_e4cdc_row4_col3" class="data row4 col3" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_e4cdc_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_e4cdc_row5_col0" class="data row5 col0" >45079.21</td>
#       <td id="T_e4cdc_row5_col1" class="data row5 col1" >6439.89</td>
#       <td id="T_e4cdc_row5_col2" class="data row5 col2" >536.66</td>
#       <td id="T_e4cdc_row5_col3" class="data row5 col3" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_e4cdc_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_e4cdc_row6_col0" class="data row6 col0" >15000.00</td>
#       <td id="T_e4cdc_row6_col1" class="data row6 col1" >2142.86</td>
#       <td id="T_e4cdc_row6_col2" class="data row6 col2" >178.57</td>
#       <td id="T_e4cdc_row6_col3" class="data row6 col3" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_e4cdc_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_e4cdc_row7_col0" class="data row7 col0" >-8500.00</td>
#       <td id="T_e4cdc_row7_col1" class="data row7 col1" >-1214.29</td>
#       <td id="T_e4cdc_row7_col2" class="data row7 col2" >-101.19</td>
#       <td id="T_e4cdc_row7_col3" class="data row7 col3" >-0.08</td>
#     </tr>
#     <tr>
#       <th id="T_e4cdc_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_e4cdc_row8_col0" class="data row8 col0" >51579.21</td>
#       <td id="T_e4cdc_row8_col1" class="data row8 col1" >7368.46</td>
#       <td id="T_e4cdc_row8_col2" class="data row8 col2" >614.04</td>
#       <td id="T_e4cdc_row8_col3" class="data row8 col3" >0.49</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Leasingrate [€]                                              455.10
# Anzahlung [€]                                               9000.00
# davon staatliche Förderung [€]                              6000.00
# Reale Anzahlung [€]                                         3000.00
# Versicherungskosten [€/a]                                    624.53
# Steuern [€/a]                                                  0.00
# Verbrauch in l/100 km                                         26.10
# Durchschnittlicher Spritpreis über Haltedauer [...             0.31
# Reparatur und Wartungskosten [€/a]                           500.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 2.00
# Gesamtlaufleistung [km]                                    30000.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_1b49b_row5_col0, #T_1b49b_row5_col1, #T_1b49b_row5_col2, #T_1b49b_row5_col3 {
#   font-weight: bold;
# }
# #T_1b49b_row6_col0, #T_1b49b_row6_col1, #T_1b49b_row6_col2, #T_1b49b_row6_col3, #T_1b49b_row7_col0, #T_1b49b_row7_col1, #T_1b49b_row7_col2, #T_1b49b_row7_col3 {
#   color: grey;
# }
# #T_1b49b_row8_col0, #T_1b49b_row8_col1, #T_1b49b_row8_col2, #T_1b49b_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_1b49b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b49b_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_1b49b_row0_col0" class="data row0 col0" >10922.40</td>
#       <td id="T_1b49b_row0_col1" class="data row0 col1" >5461.20</td>
#       <td id="T_1b49b_row0_col2" class="data row0 col2" >455.10</td>
#       <td id="T_1b49b_row0_col3" class="data row0 col3" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_1b49b_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_1b49b_row1_col0" class="data row1 col0" >1249.06</td>
#       <td id="T_1b49b_row1_col1" class="data row1 col1" >624.53</td>
#       <td id="T_1b49b_row1_col2" class="data row1 col2" >52.04</td>
#       <td id="T_1b49b_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_1b49b_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_1b49b_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_1b49b_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_1b49b_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_1b49b_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1b49b_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_1b49b_row3_col0" class="data row3 col0" >1000.00</td>
#       <td id="T_1b49b_row3_col1" class="data row3 col1" >500.00</td>
#       <td id="T_1b49b_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_1b49b_row3_col3" class="data row3 col3" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_1b49b_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_1b49b_row4_col0" class="data row4 col0" >2427.30</td>
#       <td id="T_1b49b_row4_col1" class="data row4 col1" >1213.65</td>
#       <td id="T_1b49b_row4_col2" class="data row4 col2" >101.14</td>
#       <td id="T_1b49b_row4_col3" class="data row4 col3" >0.08</td>
#     </tr>
#     <tr>
#       <th id="T_1b49b_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_1b49b_row5_col0" class="data row5 col0" >15598.76</td>
#       <td id="T_1b49b_row5_col1" class="data row5 col1" >7799.38</td>
#       <td id="T_1b49b_row5_col2" class="data row5 col2" >649.95</td>
#       <td id="T_1b49b_row5_col3" class="data row5 col3" >0.52</td>
#     </tr>
#     <tr>
#       <th id="T_1b49b_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_1b49b_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_1b49b_row6_col1" class="data row6 col1" >1500.00</td>
#       <td id="T_1b49b_row6_col2" class="data row6 col2" >125.00</td>
#       <td id="T_1b49b_row6_col3" class="data row6 col3" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_1b49b_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_1b49b_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_1b49b_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_1b49b_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_1b49b_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1b49b_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_1b49b_row8_col0" class="data row8 col0" >18598.76</td>
#       <td id="T_1b49b_row8_col1" class="data row8 col1" >9299.38</td>
#       <td id="T_1b49b_row8_col2" class="data row8 col2" >774.95</td>
#       <td id="T_1b49b_row8_col3" class="data row8 col3" >0.62</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     30643.19
# Anzahlung [€]                                              15000.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                        15000.00
# Finanzierungszins [%]                                          2.00
# Restwert [€]                                                6000.00
# Versicherungskosten [€/a]                                    510.90
# Steuern [€/a]                                                156.00
# Verbrauch in l/100 km                                          8.00
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    15643.19
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_b5741_row5_col0, #T_b5741_row5_col1, #T_b5741_row5_col2, #T_b5741_row5_col3 {
#   font-weight: bold;
# }
# #T_b5741_row6_col0, #T_b5741_row6_col1, #T_b5741_row6_col2, #T_b5741_row6_col3, #T_b5741_row7_col0, #T_b5741_row7_col1, #T_b5741_row7_col2, #T_b5741_row7_col3 {
#   color: grey;
# }
# #T_b5741_row8_col0, #T_b5741_row8_col1, #T_b5741_row8_col2, #T_b5741_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_b5741_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5741_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_b5741_row0_col0" class="data row0 col0" >16776.77</td>
#       <td id="T_b5741_row0_col1" class="data row0 col1" >2396.68</td>
#       <td id="T_b5741_row0_col2" class="data row0 col2" >199.72</td>
#       <td id="T_b5741_row0_col3" class="data row0 col3" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_b5741_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_b5741_row1_col0" class="data row1 col0" >3576.30</td>
# ...
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 3.00
# Gesamtlaufleistung [km]                                    45000.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_c7fb3_row5_col0, #T_c7fb3_row5_col1, #T_c7fb3_row5_col2, #T_c7fb3_row5_col3 {
#   font-weight: bold;
# }
# #T_c7fb3_row6_col0, #T_c7fb3_row6_col1, #T_c7fb3_row6_col2, #T_c7fb3_row6_col3, #T_c7fb3_row7_col0, #T_c7fb3_row7_col1, #T_c7fb3_row7_col2, #T_c7fb3_row7_col3 {
#   color: grey;
# }
# #T_c7fb3_row8_col0, #T_c7fb3_row8_col1, #T_c7fb3_row8_col2, #T_c7fb3_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_c7fb3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7fb3_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_c7fb3_row0_col0" class="data row0 col0" >17794.80</td>
#       <td id="T_c7fb3_row0_col1" class="data row0 col1" >5931.60</td>
#       <td id="T_c7fb3_row0_col2" class="data row0 col2" >494.30</td>
#       <td id="T_c7fb3_row0_col3" class="data row0 col3" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_c7fb3_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_c7fb3_row1_col0" class="data row1 col0" >1991.28</td>
#       <td id="T_c7fb3_row1_col1" class="data row1 col1" >663.76</td>
#       <td id="T_c7fb3_row1_col2" class="data row1 col2" >55.31</td>
#       <td id="T_c7fb3_row1_col3" class="data row1 col3" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_c7fb3_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_c7fb3_row2_col0" class="data row2 col0" >408.00</td>
#       <td id="T_c7fb3_row2_col1" class="data row2 col1" >136.00</td>
#       <td id="T_c7fb3_row2_col2" class="data row2 col2" >11.33</td>
#       <td id="T_c7fb3_row2_col3" class="data row2 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_c7fb3_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_c7fb3_row3_col0" class="data row3 col0" >2700.00</td>
#       <td id="T_c7fb3_row3_col1" class="data row3 col1" >900.00</td>
#       <td id="T_c7fb3_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_c7fb3_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_c7fb3_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_c7fb3_row4_col0" class="data row4 col0" >5355.00</td>
#       <td id="T_c7fb3_row4_col1" class="data row4 col1" >1785.00</td>
#       <td id="T_c7fb3_row4_col2" class="data row4 col2" >148.75</td>
#       <td id="T_c7fb3_row4_col3" class="data row4 col3" >0.12</td>
#     </tr>
#     <tr>
#       <th id="T_c7fb3_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_c7fb3_row5_col0" class="data row5 col0" >28249.08</td>
#       <td id="T_c7fb3_row5_col1" class="data row5 col1" >9416.36</td>
#       <td id="T_c7fb3_row5_col2" class="data row5 col2" >784.70</td>
#       <td id="T_c7fb3_row5_col3" class="data row5 col3" >0.63</td>
#     </tr>
#     <tr>
#       <th id="T_c7fb3_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_c7fb3_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_c7fb3_row6_col1" class="data row6 col1" >1000.00</td>
#       <td id="T_c7fb3_row6_col2" class="data row6 col2" >83.33</td>
#       <td id="T_c7fb3_row6_col3" class="data row6 col3" >0.07</td>
#     </tr>
#     <tr>
#       <th id="T_c7fb3_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_c7fb3_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_c7fb3_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_c7fb3_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_c7fb3_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_c7fb3_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_c7fb3_row8_col0" class="data row8 col0" >31249.08</td>
#       <td id="T_c7fb3_row8_col1" class="data row8 col1" >10416.36</td>
#       <td id="T_c7fb3_row8_col2" class="data row8 col2" >868.03</td>
#       <td id="T_c7fb3_row8_col3" class="data row8 col3" >0.69</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Anschaffungskosten [€]                                     27619.05
# Anzahlung [€]                                              15000.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                        15000.00
# Finanzierungszins [%]                                          2.00
# Restwert [€]                                                5500.00
# Versicherungskosten [€/a]                                    308.52
# Steuern [€/a]                                                 68.00
# Verbrauch in l/100 km                                          6.30
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 7.00
# Gesamtlaufleistung [km]                                   105000.00
# Finanzierungsbetrag [€]                                    12619.05
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_7c789_row5_col0, #T_7c789_row5_col1, #T_7c789_row5_col2, #T_7c789_row5_col3 {
#   font-weight: bold;
# }
# #T_7c789_row6_col0, #T_7c789_row6_col1, #T_7c789_row6_col2, #T_7c789_row6_col3, #T_7c789_row7_col0, #T_7c789_row7_col1, #T_7c789_row7_col2, #T_7c789_row7_col3 {
#   color: grey;
# }
# #T_7c789_row8_col0, #T_7c789_row8_col1, #T_7c789_row8_col2, #T_7c789_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_7c789_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c789_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_7c789_row0_col0" class="data row0 col0" >13533.48</td>
#       <td id="T_7c789_row0_col1" class="data row0 col1" >1933.35</td>
#       <td id="T_7c789_row0_col2" class="data row0 col2" >161.11</td>
#       <td id="T_7c789_row0_col3" class="data row0 col3" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_7c789_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_7c789_row1_col0" class="data row1 col0" >2159.64</td>
#       <td id="T_7c789_row1_col1" class="data row1 col1" >308.52</td>
#       <td id="T_7c789_row1_col2" class="data row1 col2" >25.71</td>
#       <td id="T_7c789_row1_col3" class="data row1 col3" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_7c789_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_7c789_row2_col0" class="data row2 col0" >476.00</td>
#       <td id="T_7c789_row2_col1" class="data row2 col1" >68.00</td>
#       <td id="T_7c789_row2_col2" class="data row2 col2" >5.67</td>
#       <td id="T_7c789_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_7c789_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_7c789_row3_col0" class="data row3 col0" >6300.00</td>
#       <td id="T_7c789_row3_col1" class="data row3 col1" >900.00</td>
#       <td id="T_7c789_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_7c789_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_7c789_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_7c789_row4_col0" class="data row4 col0" >11245.50</td>
#       <td id="T_7c789_row4_col1" class="data row4 col1" >1606.50</td>
#       <td id="T_7c789_row4_col2" class="data row4 col2" >133.88</td>
#       <td id="T_7c789_row4_col3" class="data row4 col3" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_7c789_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_7c789_row5_col0" class="data row5 col0" >33714.62</td>
#       <td id="T_7c789_row5_col1" class="data row5 col1" >4816.37</td>
#       <td id="T_7c789_row5_col2" class="data row5 col2" >401.36</td>
#       <td id="T_7c789_row5_col3" class="data row5 col3" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_7c789_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_7c789_row6_col0" class="data row6 col0" >15000.00</td>
#       <td id="T_7c789_row6_col1" class="data row6 col1" >2142.86</td>
#       <td id="T_7c789_row6_col2" class="data row6 col2" >178.57</td>
#       <td id="T_7c789_row6_col3" class="data row6 col3" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_7c789_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_7c789_row7_col0" class="data row7 col0" >-5500.00</td>
#       <td id="T_7c789_row7_col1" class="data row7 col1" >-785.71</td>
#       <td id="T_7c789_row7_col2" class="data row7 col2" >-65.48</td>
#       <td id="T_7c789_row7_col3" class="data row7 col3" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_7c789_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_7c789_row8_col0" class="data row8 col0" >43214.62</td>
#       <td id="T_7c789_row8_col1" class="data row8 col1" >6173.52</td>
#       <td id="T_7c789_row8_col2" class="data row8 col2" >514.46</td>
#       <td id="T_7c789_row8_col3" class="data row8 col3" >0.41</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:111: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2), str(calc_df_path))
#                                                     Randbedingungen
# Leasingrate [€]                                              267.16
# Anzahlung [€]                                               3000.00
# davon staatliche Förderung [€]                                 0.00
# Reale Anzahlung [€]                                         3000.00
# Versicherungskosten [€/a]                                    369.83
# Steuern [€/a]                                                 68.00
# Verbrauch in l/100 km                                          6.30
# Durchschnittlicher Spritpreis über Haltedauer [...             1.70
# Reparatur und Wartungskosten [€/a]                           900.00
# Jahreslaufleistung [km]                                    15000.00
# Haltedauer [a]                                                 4.00
# Gesamtlaufleistung [km]                                    60000.00
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/3734843737.py:114: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2))
# <style type="text/css">
# #T_ccdec_row5_col0, #T_ccdec_row5_col1, #T_ccdec_row5_col2, #T_ccdec_row5_col3 {
#   font-weight: bold;
# }
# #T_ccdec_row6_col0, #T_ccdec_row6_col1, #T_ccdec_row6_col2, #T_ccdec_row6_col3, #T_ccdec_row7_col0, #T_ccdec_row7_col1, #T_ccdec_row7_col2, #T_ccdec_row7_col3 {
#   color: grey;
# }
# #T_ccdec_row8_col0, #T_ccdec_row8_col1, #T_ccdec_row8_col2, #T_ccdec_row8_col3 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_ccdec_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Gesamt</th>
#       <th class="col_heading level0 col1" >Jährlich</th>
#       <th class="col_heading level0 col2" >Monatlich</th>
#       <th class="col_heading level0 col3" >per KM</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ccdec_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_ccdec_row0_col0" class="data row0 col0" >12823.68</td>
#       <td id="T_ccdec_row0_col1" class="data row0 col1" >3205.92</td>
#       <td id="T_ccdec_row0_col2" class="data row0 col2" >267.16</td>
#       <td id="T_ccdec_row0_col3" class="data row0 col3" >0.21</td>
#     </tr>
#     <tr>
#       <th id="T_ccdec_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_ccdec_row1_col0" class="data row1 col0" >1479.32</td>
#       <td id="T_ccdec_row1_col1" class="data row1 col1" >369.83</td>
#       <td id="T_ccdec_row1_col2" class="data row1 col2" >30.82</td>
#       <td id="T_ccdec_row1_col3" class="data row1 col3" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_ccdec_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_ccdec_row2_col0" class="data row2 col0" >272.00</td>
#       <td id="T_ccdec_row2_col1" class="data row2 col1" >68.00</td>
#       <td id="T_ccdec_row2_col2" class="data row2 col2" >5.67</td>
#       <td id="T_ccdec_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ccdec_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_ccdec_row3_col0" class="data row3 col0" >3600.00</td>
#       <td id="T_ccdec_row3_col1" class="data row3 col1" >900.00</td>
#       <td id="T_ccdec_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_ccdec_row3_col3" class="data row3 col3" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_ccdec_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_ccdec_row4_col0" class="data row4 col0" >6426.00</td>
#       <td id="T_ccdec_row4_col1" class="data row4 col1" >1606.50</td>
#       <td id="T_ccdec_row4_col2" class="data row4 col2" >133.88</td>
#       <td id="T_ccdec_row4_col3" class="data row4 col3" >0.11</td>
#     </tr>
#     <tr>
#       <th id="T_ccdec_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_ccdec_row5_col0" class="data row5 col0" >24601.00</td>
#       <td id="T_ccdec_row5_col1" class="data row5 col1" >6150.25</td>
#       <td id="T_ccdec_row5_col2" class="data row5 col2" >512.52</td>
#       <td id="T_ccdec_row5_col3" class="data row5 col3" >0.41</td>
#     </tr>
#     <tr>
#       <th id="T_ccdec_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_ccdec_row6_col0" class="data row6 col0" >3000.00</td>
#       <td id="T_ccdec_row6_col1" class="data row6 col1" >750.00</td>
#       <td id="T_ccdec_row6_col2" class="data row6 col2" >62.50</td>
#       <td id="T_ccdec_row6_col3" class="data row6 col3" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_ccdec_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_ccdec_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_ccdec_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_ccdec_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_ccdec_row7_col3" class="data row7 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ccdec_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_ccdec_row8_col0" class="data row8 col0" >27601.00</td>
#       <td id="T_ccdec_row8_col1" class="data row8 col1" >6900.25</td>
#       <td id="T_ccdec_row8_col2" class="data row8 col2" >575.02</td>
#       <td id="T_ccdec_row8_col3" class="data row8 col3" >0.46</td>
#     </tr>
#   </tbody>
# </table>

# %%
brk = 8

overview_path_1 = 'images/overview1.png'
overview_path_2 = 'images/overview2.png'

# sum_row = pd.IndexSlice[calc_values.index[(calc_values.index == "Summe") | (calc_values.index == "Gesamtsumme")], :]

dfi.export(overview.iloc[:, 0:brk ].style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2), overview_path_1)
dfi.export(overview.iloc[:, brk: ].style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2), overview_path_2)

display(overview.iloc[:, 0:brk ].style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2))
display(overview.iloc[:, brk: ].style.applymap(df_style, subset=bold_row)\
               .applymap(light_style, subset=light_row).set_precision(2).set_precision(2))

latex = r"""%s

\pagebreak

\onecolumn
\null
\vfill 
%% \includegraphics[height=6cm]
\includegraphics[width=0.95\columnwidth]{%s}

\null
\vspace{0.8cm}
%% \includegraphics[height=6cm]
\includegraphics[width=0.95\columnwidth]{%s}
\vfill 
""" % (latex,
      overview_path_1,
      overview_path_2)
# Out:
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/183672034.py:9: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2).set_precision(2), overview_path_1)
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/183672034.py:11: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2).set_precision(2), overview_path_2)
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/183672034.py:14: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2).set_precision(2))
# <style type="text/css">
# #T_d2ec8_row5_col0, #T_d2ec8_row5_col1, #T_d2ec8_row5_col2, #T_d2ec8_row5_col3, #T_d2ec8_row5_col4, #T_d2ec8_row5_col5, #T_d2ec8_row5_col6, #T_d2ec8_row5_col7 {
#   font-weight: bold;
# }
# #T_d2ec8_row6_col0, #T_d2ec8_row6_col1, #T_d2ec8_row6_col2, #T_d2ec8_row6_col3, #T_d2ec8_row6_col4, #T_d2ec8_row6_col5, #T_d2ec8_row6_col6, #T_d2ec8_row6_col7, #T_d2ec8_row7_col0, #T_d2ec8_row7_col1, #T_d2ec8_row7_col2, #T_d2ec8_row7_col3, #T_d2ec8_row7_col4, #T_d2ec8_row7_col5, #T_d2ec8_row7_col6, #T_d2ec8_row7_col7 {
#   color: grey;
# }
# #T_d2ec8_row8_col0, #T_d2ec8_row8_col1, #T_d2ec8_row8_col2, #T_d2ec8_row8_col3, #T_d2ec8_row8_col4, #T_d2ec8_row8_col5, #T_d2ec8_row8_col6, #T_d2ec8_row8_col7 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_d2ec8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >BMW 318d 2011 Kaufen</th>
#       <th class="col_heading level0 col1" >Nissan Micra 2010 Kaufen</th>
#       <th class="col_heading level0 col2" >Tesla Model Y Kaufen</th>
#       <th class="col_heading level0 col3" >Tesla Model Y Leasing</th>
#       <th class="col_heading level0 col4" >Tesla Model 3 Kaufen</th>
#       <th class="col_heading level0 col5" >Tesla Model 3 Leasing</th>
#       <th class="col_heading level0 col6" >Hyundai Ioniq 5 Kaufen</th>
#       <th class="col_heading level0 col7" >Hyundai Ioniq 5 Leasing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2ec8_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_d2ec8_row0_col0" class="data row0 col0" >205.63</td>
#       <td id="T_d2ec8_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_d2ec8_row0_col2" class="data row0 col2" >420.94</td>
#       <td id="T_d2ec8_row0_col3" class="data row0 col3" >533.00</td>
#       <td id="T_d2ec8_row0_col4" class="data row0 col4" >293.27</td>
#       <td id="T_d2ec8_row0_col5" class="data row0 col5" >360.00</td>
#       <td id="T_d2ec8_row0_col6" class="data row0 col6" >351.56</td>
#       <td id="T_d2ec8_row0_col7" class="data row0 col7" >455.10</td>
#     </tr>
#     <tr>
#       <th id="T_d2ec8_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_d2ec8_row1_col0" class="data row1 col0" >64.58</td>
#       <td id="T_d2ec8_row1_col1" class="data row1 col1" >30.15</td>
#       <td id="T_d2ec8_row1_col2" class="data row1 col2" >38.32</td>
#       <td id="T_d2ec8_row1_col3" class="data row1 col3" >47.24</td>
#       <td id="T_d2ec8_row1_col4" class="data row1 col4" >45.33</td>
#       <td id="T_d2ec8_row1_col5" class="data row1 col5" >56.13</td>
#       <td id="T_d2ec8_row1_col6" class="data row1 col6" >42.29</td>
#       <td id="T_d2ec8_row1_col7" class="data row1 col7" >52.04</td>
#     </tr>
#     <tr>
#       <th id="T_d2ec8_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_d2ec8_row2_col0" class="data row2 col0" >19.17</td>
#       <td id="T_d2ec8_row2_col1" class="data row2 col1" >5.33</td>
#       <td id="T_d2ec8_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_d2ec8_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_d2ec8_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_d2ec8_row2_col5" class="data row2 col5" >0.00</td>
#       <td id="T_d2ec8_row2_col6" class="data row2 col6" >0.00</td>
#       <td id="T_d2ec8_row2_col7" class="data row2 col7" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d2ec8_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_d2ec8_row3_col0" class="data row3 col0" >168.03</td>
#       <td id="T_d2ec8_row3_col1" class="data row3 col1" >32.95</td>
#       <td id="T_d2ec8_row3_col2" class="data row3 col2" >41.67</td>
#       <td id="T_d2ec8_row3_col3" class="data row3 col3" >41.67</td>
#       <td id="T_d2ec8_row3_col4" class="data row3 col4" >41.67</td>
#       <td id="T_d2ec8_row3_col5" class="data row3 col5" >41.67</td>
#       <td id="T_d2ec8_row3_col6" class="data row3 col6" >41.67</td>
#       <td id="T_d2ec8_row3_col7" class="data row3 col7" >41.67</td>
#     </tr>
#     <tr>
#       <th id="T_d2ec8_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_d2ec8_row4_col0" class="data row4 col0" >164.50</td>
#       <td id="T_d2ec8_row4_col1" class="data row4 col1" >24.06</td>
#       <td id="T_d2ec8_row4_col2" class="data row4 col2" >62.00</td>
#       <td id="T_d2ec8_row4_col3" class="data row4 col3" >62.00</td>
#       <td id="T_d2ec8_row4_col4" class="data row4 col4" >58.12</td>
#       <td id="T_d2ec8_row4_col5" class="data row4 col5" >58.12</td>
#       <td id="T_d2ec8_row4_col6" class="data row4 col6" >101.14</td>
#       <td id="T_d2ec8_row4_col7" class="data row4 col7" >101.14</td>
#     </tr>
#     <tr>
#       <th id="T_d2ec8_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_d2ec8_row5_col0" class="data row5 col0" >621.91</td>
#       <td id="T_d2ec8_row5_col1" class="data row5 col1" >92.49</td>
#       <td id="T_d2ec8_row5_col2" class="data row5 col2" >562.92</td>
#       <td id="T_d2ec8_row5_col3" class="data row5 col3" >683.91</td>
#       <td id="T_d2ec8_row5_col4" class="data row5 col4" >438.39</td>
#       <td id="T_d2ec8_row5_col5" class="data row5 col5" >515.93</td>
#       <td id="T_d2ec8_row5_col6" class="data row5 col6" >536.66</td>
#       <td id="T_d2ec8_row5_col7" class="data row5 col7" >649.95</td>
#     </tr>
#     <tr>
#       <th id="T_d2ec8_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_d2ec8_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_d2ec8_row6_col1" class="data row6 col1" >50.00</td>
#       <td id="T_d2ec8_row6_col2" class="data row6 col2" >178.57</td>
#       <td id="T_d2ec8_row6_col3" class="data row6 col3" >62.50</td>
#       <td id="T_d2ec8_row6_col4" class="data row6 col4" >178.57</td>
#       <td id="T_d2ec8_row6_col5" class="data row6 col5" >62.50</td>
#       <td id="T_d2ec8_row6_col6" class="data row6 col6" >178.57</td>
#       <td id="T_d2ec8_row6_col7" class="data row6 col7" >125.00</td>
#     </tr>
#     <tr>
#       <th id="T_d2ec8_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_d2ec8_row7_col0" class="data row7 col0" >-36.50</td>
#       <td id="T_d2ec8_row7_col1" class="data row7 col1" >-30.30</td>
#       <td id="T_d2ec8_row7_col2" class="data row7 col2" >-119.05</td>
#       <td id="T_d2ec8_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_d2ec8_row7_col4" class="data row7 col4" >-101.19</td>
#       <td id="T_d2ec8_row7_col5" class="data row7 col5" >0.00</td>
#       <td id="T_d2ec8_row7_col6" class="data row7 col6" >-101.19</td>
#       <td id="T_d2ec8_row7_col7" class="data row7 col7" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_d2ec8_level0_row8" class="row_heading level0 row8" >Gesamtsumme</th>
#       <td id="T_d2ec8_row8_col0" class="data row8 col0" >585.41</td>
#       <td id="T_d2ec8_row8_col1" class="data row8 col1" >112.18</td>
#       <td id="T_d2ec8_row8_col2" class="data row8 col2" >622.45</td>
#       <td id="T_d2ec8_row8_col3" class="data row8 col3" >746.41</td>
#       <td id="T_d2ec8_row8_col4" class="data row8 col4" >515.77</td>
#       <td id="T_d2ec8_row8_col5" class="data row8 col5" >578.43</td>
#       <td id="T_d2ec8_row8_col6" class="data row8 col6" >614.04</td>
#       <td id="T_d2ec8_row8_col7" class="data row8 col7" >774.95</td>
#     </tr>
#   </tbody>
# </table>
# C:\Users\LGI1SGM\AppData\Local\Temp/ipykernel_13964/183672034.py:16: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   .applymap(light_style, subset=light_row).set_precision(2).set_precision(2))
# <style type="text/css">
# #T_738f2_row5_col0, #T_738f2_row5_col1, #T_738f2_row5_col2, #T_738f2_row5_col3, #T_738f2_row5_col4, #T_738f2_row5_col5, #T_738f2_row5_col6, #T_738f2_row5_col7, #T_738f2_row5_col8, #T_738f2_row5_col9 {
#   font-weight: bold;
# }
# #T_738f2_row6_col0, #T_738f2_row6_col1, #T_738f2_row6_col2, #T_738f2_row6_col3, #T_738f2_row6_col4, #T_738f2_row6_col5, #T_738f2_row6_col6, #T_738f2_row6_col7, #T_738f2_row6_col8, #T_738f2_row6_col9, #T_738f2_row7_col0, #T_738f2_row7_col1, #T_738f2_row7_col2, #T_738f2_row7_col3, #T_738f2_row7_col4, #T_738f2_row7_col5, #T_738f2_row7_col6, #T_738f2_row7_col7, #T_738f2_row7_col8, #T_738f2_row7_col9 {
#   color: grey;
# }
# #T_738f2_row8_col0, #T_738f2_row8_col1, #T_738f2_row8_col2, #T_738f2_row8_col3, #T_738f2_row8_col4, #T_738f2_row8_col5, #T_738f2_row8_col6, #T_738f2_row8_col7, #T_738f2_row8_col8, #T_738f2_row8_col9 {
#   font-weight: bold;
#   color: grey;
# }
# </style>
# <table id="T_738f2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Mazda 6 Kaufen</th>
#       <th class="col_heading level0 col1" >Mazda 6 Leasing</th>
#       <th class="col_heading level0 col2" >Kia ceed Kaufen</th>
#       <th class="col_heading level0 col3" >Kia ceed Leasing</th>
#       <th class="col_heading level0 col4" >VW Passat Kaufen</th>
#       <th class="col_heading level0 col5" >VW Passat Leasing</th>
#       <th class="col_heading level0 col6" >Mercedes C 180 Kaufen</th>
#       <th class="col_heading level0 col7" >Mercedes C 180 Leasing</th>
#       <th class="col_heading level0 col8" >Skoda Scala Kaufen</th>
#       <th class="col_heading level0 col9" >Skoda Scala Leasing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_738f2_level0_row0" class="row_heading level0 row0" >Raten</th>
#       <td id="T_738f2_row0_col0" class="data row0 col0" >199.72</td>
#       <td id="T_738f2_row0_col1" class="data row0 col1" >284.70</td>
#       <td id="T_738f2_row0_col2" class="data row0 col2" >130.35</td>
#       <td id="T_738f2_row0_col3" class="data row0 col3" >227.42</td>
#       <td id="T_738f2_row0_col4" class="data row0 col4" >194.45</td>
#       <td id="T_738f2_row0_col5" class="data row0 col5" >320.78</td>
#       <td id="T_738f2_row0_col6" class="data row0 col6" >354.37</td>
#       <td id="T_738f2_row0_col7" class="data row0 col7" >494.30</td>
#       <td id="T_738f2_row0_col8" class="data row0 col8" >161.11</td>
#       <td id="T_738f2_row0_col9" class="data row0 col9" >267.16</td>
#     </tr>
#     <tr>
#       <th id="T_738f2_level0_row1" class="row_heading level0 row1" >Versicherung</th>
#       <td id="T_738f2_row1_col0" class="data row1 col0" >42.57</td>
#       <td id="T_738f2_row1_col1" class="data row1 col1" >52.49</td>
#       <td id="T_738f2_row1_col2" class="data row1 col2" >27.17</td>
#       <td id="T_738f2_row1_col3" class="data row1 col3" >32.96</td>
#       <td id="T_738f2_row1_col4" class="data row1 col4" >29.28</td>
#       <td id="T_738f2_row1_col5" class="data row1 col5" >35.26</td>
#       <td id="T_738f2_row1_col6" class="data row1 col6" >44.47</td>
#       <td id="T_738f2_row1_col7" class="data row1 col7" >55.31</td>
#       <td id="T_738f2_row1_col8" class="data row1 col8" >25.71</td>
#       <td id="T_738f2_row1_col9" class="data row1 col9" >30.82</td>
#     </tr>
#     <tr>
#       <th id="T_738f2_level0_row2" class="row_heading level0 row2" >Steuern</th>
#       <td id="T_738f2_row2_col0" class="data row2 col0" >13.00</td>
#       <td id="T_738f2_row2_col1" class="data row2 col1" >13.00</td>
#       <td id="T_738f2_row2_col2" class="data row2 col2" >8.92</td>
#       <td id="T_738f2_row2_col3" class="data row2 col3" >8.92</td>
#       <td id="T_738f2_row2_col4" class="data row2 col4" >8.17</td>
#       <td id="T_738f2_row2_col5" class="data row2 col5" >8.17</td>
#       <td id="T_738f2_row2_col6" class="data row2 col6" >11.33</td>
#       <td id="T_738f2_row2_col7" class="data row2 col7" >11.33</td>
#       <td id="T_738f2_row2_col8" class="data row2 col8" >5.67</td>
#       <td id="T_738f2_row2_col9" class="data row2 col9" >5.67</td>
#     </tr>
#     <tr>
#       <th id="T_738f2_level0_row3" class="row_heading level0 row3" >Reparaturen</th>
#       <td id="T_738f2_row3_col0" class="data row3 col0" >75.00</td>
#       <td id="T_738f2_row3_col1" class="data row3 col1" >75.00</td>
#       <td id="T_738f2_row3_col2" class="data row3 col2" >75.00</td>
#       <td id="T_738f2_row3_col3" class="data row3 col3" >75.00</td>
#       <td id="T_738f2_row3_col4" class="data row3 col4" >75.00</td>
#       <td id="T_738f2_row3_col5" class="data row3 col5" >75.00</td>
#       <td id="T_738f2_row3_col6" class="data row3 col6" >75.00</td>
#       <td id="T_738f2_row3_col7" class="data row3 col7" >75.00</td>
#       <td id="T_738f2_row3_col8" class="data row3 col8" >75.00</td>
#       <td id="T_738f2_row3_col9" class="data row3 col9" >75.00</td>
#     </tr>
#     <tr>
#       <th id="T_738f2_level0_row4" class="row_heading level0 row4" >Verbrauch</th>
#       <td id="T_738f2_row4_col0" class="data row4 col0" >170.00</td>
#       <td id="T_738f2_row4_col1" class="data row4 col1" >170.00</td>
#       <td id="T_738f2_row4_col2" class="data row4 col2" >148.75</td>
#       <td id="T_738f2_row4_col3" class="data row4 col3" >148.75</td>
#       <td id="T_738f2_row4_col4" class="data row4 col4" >159.38</td>
#       <td id="T_738f2_row4_col5" class="data row4 col5" >159.38</td>
#       <td id="T_738f2_row4_col6" class="data row4 col6" >148.75</td>
#       <td id="T_738f2_row4_col7" class="data row4 col7" >148.75</td>
#       <td id="T_738f2_row4_col8" class="data row4 col8" >133.88</td>
#       <td id="T_738f2_row4_col9" class="data row4 col9" >133.88</td>
#     </tr>
#     <tr>
#       <th id="T_738f2_level0_row5" class="row_heading level0 row5" >Summe</th>
#       <td id="T_738f2_row5_col0" class="data row5 col0" >500.30</td>
#       <td id="T_738f2_row5_col1" class="data row5 col1" >595.19</td>
#       <td id="T_738f2_row5_col2" class="data row5 col2" >390.18</td>
#       <td id="T_738f2_row5_col3" class="data row5 col3" >493.05</td>
#       <td id="T_738f2_row5_col4" class="data row5 col4" >466.27</td>
#       <td id="T_738f2_row5_col5" class="data row5 col5" >598.57</td>
#       <td id="T_738f2_row5_col6" class="data row5 col6" >633.93</td>
#       <td id="T_738f2_row5_col7" class="data row5 col7" >784.70</td>
#       <td id="T_738f2_row5_col8" class="data row5 col8" >401.36</td>
#       <td id="T_738f2_row5_col9" class="data row5 col9" >512.52</td>
#     </tr>
#     <tr>
#       <th id="T_738f2_level0_row6" class="row_heading level0 row6" >Anzahlung</th>
#       <td id="T_738f2_row6_col0" class="data row6 col0" >178.57</td>
#       <td id="T_738f2_row6_col1" class="data row6 col1" >83.33</td>
#       <td id="T_738f2_row6_col2" class="data row6 col2" >178.57</td>
#       <td id="T_738f2_row6_col3" class="data row6 col3" >83.33</td>
#       <td id="T_738f2_row6_col4" class="data row6 col4" >178.57</td>
#       <td id="T_738f2_row6_col5" class="data row6 col5" >83.33</td>
#       <td id="T_738f2_row6_col6" class="data row6 col6" >178.57</td>
#       <td id="T_738f2_row6_col7" class="data row6 col7" >83.33</td>
#       <td id="T_738f2_row6_col8" class="data row6 col8" >178.57</td>
#       <td id="T_738f2_row6_col9" class="data row6 col9" >62.50</td>
#     </tr>
#     <tr>
#       <th id="T_738f2_level0_row7" class="row_heading level0 row7" >Restwert</th>
#       <td id="T_738f2_row7_col0" class="data row7 col0" >-71.43</td>
#       <td id="T_738f2_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_738f2_row7_col2" class="data row7 col2" >-59.52</td>
#       <td id="T_738f2_row7_col3" class="data row7 col3" >0.00</td>
#       <td id="T_738f2_row7_col4" class="data row7 col4" >-71.43</td>
#       <td id="T_738f2_row7_col5" class="data row7 col5" >0.00</td>
#       <td id="T_738f2_row7_col6" class="data row7 col6" >-95.24</td>
#       <td id="T_738f2_row7_col7" class="data row7 col7" >0.00</td>
#       <td id="T_738f2_row7_col8" class="data row7 col8" >-65.48</td>
#       <td id="T_738f2_row7_col9" class="data row7 col9" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_738

# %%
tex_file = 'report_l.tex'
with open(tex_file, 'w') as fid:
    fid.write(r"""
\documentclass[landscape, DIV=99, 14pt]{scrartcl}

\renewcommand*{\familydefault}{\sfdefault}

\RequirePackage{graphicx}
\RequirePackage{hyperref}
\RequirePackage[gen]{eurosym}

\begin{document}

\twocolumn
\section*{Zusammenfassung BMW Kosten}
\null
\vspace{1cm}
\begin{center}
%%                           trim={<left> <lower> <right> <upper>}
\includegraphics[width=10cm, trim={4cm 0 4cm 5cm}]{images/kosten_verteilung.png}
\end{center}

\includegraphics[width=1.4\columnwidth]{images/kosten_maximus.png}

\pagebreak

\begin{itemize}
    \item Wertverlust
    \begin{itemize}
        \item Kaufpreis minus Verkaufspreis
        \item Kraftstoffe
        \item Summe aller Tankstellenbesuche
    \end{itemize}
    \item Wartung und Reparatur
    \begin{itemize}
        \item Regul\"are Wartungsarbeiten (\"Olwechsel, etc)
        \item Reparaturen Aufgrund technischer Defekte
        \item Unfallsch\"aden
    \end{itemize}
    \item Versicherung
    \begin{itemize}
        \item J\"ahrlicher Versicherungsbeitrag
        \item Mobilit\"ats-Service
    \end{itemize}
    \item Steuern
    \begin{itemize}
            \item J\"ahrliche KFZ-Steuer
    \end{itemize}
\end{itemize}

# %s

\end{document}
""" % (latex))

# %%
os.system('pdflatex.exe .\%s' % (tex_file))
os.system('pdflatex.exe .\%s' % (tex_file))
os.system('start .\%spdf' % (tex_file[:-3]))
# Out:
# 0

# %%
#with open('test_table.html', 'w') as fid:
#    fid.write(calc_values.style.applymap(df_style, subset=bold_row)\
#              .applymap(light_style, subset=light_row).set_precision(2)\
#              .to_html())
#
